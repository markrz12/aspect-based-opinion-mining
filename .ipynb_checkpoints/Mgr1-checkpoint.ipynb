# %%
import pandas as pd
import spacy
import steamreviews
import json
import csv
import os
import glob
import json
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import wordcloud
from wordcloud import WordCloud
import re
import plotly
import seaborn as sns
import stanza

# %% [markdown]
# ## Reviews download
# https://pypi.org/project/steamreviews/

# %% [raw]
# list_of_app_ids = [219150, 1172620, 460950, 262060, 250320, 210970, 620, 736260,
#                    219890, 289070, 427520, 257510, 304430, 400, 394360, 550,
#                    632470, 294100, 646570, 1150690, 1341290, 1515210, 860510]
#
# def get_reviews(list_of_app_ids):
#     request_params = dict()
#     request_params['language'] = 'english'
#     request_params['day_range'] = '365'
#     request_params['filter'] = 'all'
#     for app_id in list_of_app_ids:
#         review_dict, query_count = steamreviews.download_reviews_for_app_id(app_id,chosen_request_params=request_params)
#     return review_dict, query_count
# get_reviews(list_of_app_ids);

# %%
dir_name = "data"
reviews_jsons = glob.glob(f"{dir_name}/*")
reviews_jsons
# Out:
# ['data\\review_1150690.json',
#  'data\\review_1172620.json',
#  'data\\review_1341290.json',
#  'data\\review_1515210.json',
#  'data\\review_210970.json',
#  'data\\review_219150.json',
#  'data\\review_219890.json',
#  'data\\review_250320.json',
#  'data\\review_257510.json',
#  'data\\review_262060.json',
#  'data\\review_289070.json',
#  'data\\review_294100.json',
#  'data\\review_304430.json',
#  'data\\review_394360.json',
#  'data\\review_400.json',
#  'data\\review_427520.json',
#  'data\\review_460950.json',
#  'data\\review_550.json',
#  'data\\review_620.json',
#  'data\\review_632470.json',
#  'data\\review_646570.json',
#  'data\\review_736260.json',
#  'data\\review_860510.json']

# %%
title_dict = {"219150": "Hotline Miami",
              "1172620" : "Sea of Thieves",
              "460950" : "Katana ZERO",
              "262060" : "Darkest Dungeon",
              "250320" : "The Wolf Among Us",
              "210970" : "The Witness",
              "620" : "Portal 2",
              "736260" : "Baba Is You",
              "219890" : "Antichamber",
              "289070" : "Sid Meier's Civilization VI",
              "427520" : "Factorio",
              "257510" : "The Talos Principle",
             "304430" : "INSIDE",
             "400" : "Portal",
             "394360" : "Hearts of Iron IV",
             "632470" : "Disco Elysium",
             "294100" : "RimWorld",
              "646570" : "Slay the Spire",
              "1150690" : "Omori",
              "1341290" : "We Were Here Forever",
              "1515210" : "The Past Within",
              "860510" : "Little Nightmares II",
              "550" : "Left 4 Dead 2"}

# %%
genre_dict = {"219150": "A",
              "1172620" : "A",
              "460950" : "A",
              "262060" : "R",
              "250320" : "R",
              "210970" : "P",
              "620" : "P",
              "736260" : "P",
              "219890" : "P",
              "289070" : "S",
              "427520" : "S",
              "257510" : "P",
              "304430" : "P",
             "400" : "P",
             "394360" : "S",
             "632470" : "R",
             "294100" : "S",
             "646570" : "R",
             "1150690" : "R",
             "1341290" : "P",
             "1515210" : "P",
             "860510" : "P",
             "550" : "A"}

# %%
data_list = []
for i in reviews_jsons:
    with open(i, encoding = "utf-8") as json_file:
        json_data = json.load(json_file)
        reviews = json_data['reviews']
        file_name = json_file.name.split('.')[0].split('_')[1]
        for key in reviews.keys():
            data_list.append([title_dict.get(file_name),genre_dict.get(file_name),reviews[key]['author']['steamid'], reviews[key]['votes_up'], 
                          reviews[key]['review'], reviews[key]['weighted_vote_score'], reviews[key]['voted_up'],
                          reviews[key]['author']['num_games_owned'], reviews[key]['author']['playtime_at_review'],
                          reviews[key]['author']['num_reviews'], 
                          reviews[key]["timestamp_created"] ])
df = pd.DataFrame(data_list, columns = ["title", "genre","steamid", "votes_up", "review", "weighted_vote_score", "voted_up",
                                        "num_games_owned", "playtime_at_review", "num_reviews", "timestamp_created"])

# %% [markdown]
# ## Wykresy

# %%
value_counts_title = df["title"].value_counts()
genre_colors = {"A": "mistyrose", "R": "palevioletred", "P": "thistle", "S": "pink"}
df['color'] = df['genre'].map(genre_colors)
colors = [df.loc[df['title'] == title]['color'].iloc[0] for title in value_counts_title.index]

plt.figure(figsize=(12, 6))
x = value_counts_title.plot(kind = "bar", color = colors)
plt.ylabel("Ilość recenzji")
plt.xticks(rotation = 90)
for i, count in enumerate(value_counts_title):
    x.text(i, count, count, va = "bottom", ha = "center")

plt.show()

# %%
value_counts_genre = df["genre"].value_counts()
colors = ["pink", "mistyrose", "palevioletred", "thistle"]
x = plt.pie(value_counts_genre, labels = value_counts_genre.index, colors=colors, autopct='%1.2f%%')
plt.show()

# %%
value_counts_recommendation_genre = df.groupby('genre').voted_up.value_counts().unstack(0)
colors = ["pink", "mistyrose", "palevioletred", "thistle"]
plt.figure(figsize=(12, 6))
x = value_counts_recommendation_genre.plot(kind = "bar", color = colors, mark_right = True)
plt.ylabel("Ilość recenzji")
plt.xlabel("Rekomendacje")
plt.show()

# %%
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 
print(percentage_pos)
print(percentage_neg)
# Out:
# genre
# A    88.619463
# P    96.954239
# R    91.465953
# S    85.354180
# dtype: float64
# genre
# A    11.380537
# P     3.045761
# R     8.534047
# S    14.645820
# dtype: float64

# %%
df.sample(frac=0.3).head()
# Out:
#                              title genre            steamid  votes_up  \
# 27890                     Portal 2     P  76561199349088514       136
# 28456                Disco Elysium     R  76561198044802260         2
# 17170            Hearts of Iron IV     S  76561199180233504         1
# 10917  Sid Meier's Civilization VI     S  76561199034726065         1
# 29141                Disco Elysium     R  76561198087633557         1
#
#                                                   review  \
# 27890                                           PORTAL 3
# 28456  This is the only game where I got a gameover i...
# 17170                  bloody amazing strategy war game!
# 10917  A thinking man's game. it is in depth, but it ...
# 29141                                  o melhor de todos
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 27890   0.88251960277557373      True               39                  69
# 28456  0.545454561710357666      True                0                3312
# 17170  0.509803950786590576      True                0               16398
# 10917  0.523809552192687988      True               31               83027
# 29141  0.523809552192687988      True              202                 821
#
#        num_reviews  timestamp_created          color
# 27890           27         1662665548        thistle
# 28456            3         1667584193  palevioletred
# 17170            3         1670932472           pink
# 10917            1         1667695587           pink
# 29141           11         1674463479  palevioletred

# %%
df['timestamp_created'] = pd.to_datetime(df['timestamp_created'], unit='s')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 1. Braki danych
# 2. Usunięcie duplikatów
# 4. Usunięcie recenzjii krótszych niż 3 słowa
# 9. Usunięcie znaków spcjalnych
# 10. "Text lowering"
# 6. Usunięcie znaków interpunkcyjnych i liczb
# 7. Tokenizacja
# 8. Part-of-speech tagging
# 9. Lematyzacja

# %% [markdown]
# #### Braki danych

# %%
df.isna().sum()
# Out:
# title                  0
# genre                  0
# steamid                0
# votes_up               0
# review                 0
# weighted_vote_score    0
# voted_up               0
# num_games_owned        0
# playtime_at_review     0
# num_reviews            0
# timestamp_created      0
# color                  0
# dtype: int64

# %% [markdown]
# #### Usunięcie duplikatów

# %%
df.duplicated(subset='review').sum()
# Out:
# 2580

# %%
df[df.duplicated(subset='review')].sample(59)
# Out:
#                              title genre            steamid  votes_up  \
# 25319                Left 4 Dead 2     A  76561199141519814         1
# 27141                     Portal 2     P  76561199087752874         1
# 25104                Left 4 Dead 2     A  76561198066035159         1
# 23832                Left 4 Dead 2     A  76561198805108892         1
# 24834                Left 4 Dead 2     A  76561199087663045         1
# 14736                       INSIDE     P  76561199208960068         1
# 18450                       Portal     P  76561198391555571         1
# 23437                Left 4 Dead 2     A  76561197974414834         1
# 18328                       Portal     P  76561198066204929         1
# 19979                     Factorio     S  76561199171711004         1
# 16461            Hearts of Iron IV     S  76561198025402881         1
# 22051                Left 4 Dead 2     A  76561198092033378         2
# 15087            Hearts of Iron IV     S  76561198992589989        75
# 23749                Left 4 Dead 2     A  76561199112346716         1
# 26312                     Portal 2     P  76561199472327288         1
# 4350                Sea of Thieves     A  76561199054277384         2
# 11223  Sid Meier's Civilization VI     S  76561198139098969         2
# 6872               The Past Within     P  76561198929526444         1
# 26323                     Portal 2     P  76561199452673958         1
# 9150               Darkest Dungeon     R  76561198356483977         3
# 13385                     RimWorld     S  76561197973206218         1
# 14153                     RimWorld     S  76561199102004809         1
# 21898                Left 4 Dead 2     A  76561198216123223        10
# 21753                Left 4 Dead 2     A  76561199083085395       235
# 18462                       Portal     P  76561199132419629         1
# 27898                     Portal 2     P  76561198030713412       534
# 301                          Omori     R  76561199274264890         2
# 30502               Slay the Spire     R  76561198039801638         2
# 9783               Darkest Dungeon     R  76561197999630365       106
# 25191                Left 4 Dead 2     A  76561199472608649         1
# 3572                Sea of Thieves     A  76561198160944631         2
# 25485                Left 4 Dead 2     A  76561199455451160         1
# 4444                Sea of Thieves     A  76561198035752229         1
# 25301                Left 4 Dead 2     A  76561198924312377         1
# 4963                Sea of Thieves     A  76561198104891373         1
# 26333                     Portal 2     P  76561199088647826         1
# 27316                     Portal 2     P  76561198151136143         1
# 9514               Darkest Dungeon     R  76561199090169182         1
# 24755                Left 4 Dead 2     A  76561199086914016         1
# 8512             The Wolf Among Us     R  76561198069671264         1
# 3529                Sea of Thieves     A  76561198044642425         1
# 20475                     Factorio     S  76561198345287174         2
# 22603                Left 4 Dead 2     A  76561198009130366         1
# 18405                       Portal     P  76561199219790273         1
# 1855                         Omori     R  76561199036507063         2
# 26071                     Portal 2     P  76561199107704702         1
# 26446                     Portal 2     P  76561198088801460         1
# 20458                     Factorio     S  76561198313322953         1
# 3772                Sea of Thieves     A  76561199216000797         1
# 26519                     Portal 2     P  76561199189793247         1
# 23471                Left 4 Dead 2     A  76561198868037760         1
# 2695                Sea of Thieves     A  76561198306355432         2
# 11850  Sid Meier's Civilization VI     S  76561198020818677       523
# 16083            Hearts of Iron IV     S  76561198164261488         1
# 22322                Left 4 Dead 2     A  76561199215148092         1
# 4851                Sea of Thieves     A  76561198399225855         1
# 10026  Sid Meier's Civilization VI     S  76561198162272725         4
# 10201  Sid Meier's Civilization VI     S  76561198185097825         1
# 22267                Left 4 Dead 2     A  76561198929542990         2
#
#                                                   review  \
# 25319                                         pills here
# 27141                                                yes
# 25104                                          game good
# 23832                     good game to play with friends
# 24834                                            zambies
# 14736                                          Good game
# 18450
# 23437                                          nice game
# 18328                                 This was a triumph
# 19979                                     Best game ever
# 16461                                               good
# 22051                                                 :)
# 15087                                       It's alright
# 23749                                        good game\n
# 26312                                          nice game
# 4350                                           nice game
# 11223                                          shit game
# 6872                                            very fun
# 26323  ⣿⣿⣿⣿⣿⣿⣿⣿⠟⠋⠁⠀⠀⠀⠀⠀⠀⠀⠀⠉⠻⣿\n⣿⣿⣿⣿⣿⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢺...
# 9150                                       i want to die
# 13385                                                 GG
# 14153                                                yes
# 21898  Got a cat here. Friends passing by can touch h...
# 21753  ⣿⣿⣿⣿⣿⣿⣿⣿⠟⠋⠁⠀⠀⠀⠀⠀⠀⠀⠀⠉⠻⣿\n⣿⣿⣿⣿⣿⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢺...
# 18462                                               Best
# 27898                  Buy it. For science. You monster.
# 301                                                 omor
# 30502                                          It's good
# 9783   Remind yourself that overconfidence is a slow ...
# 25191                                          best game
# 3572                                              Pirate
# 25485                                               zomb
# 4444                                              its ok
# 25301                                              yes\n
# 4963                                                yarg
# 26333                                          good game
# 27316                                       I'm a potato
# 9514   Remind yourself that overconfidence is a slow ...
# 24755                                   i love this game
# 8512                                when the wolf is sus
# 3529                                            pirate\n
# 20475                                  factory must grow
# 22603                                             its ok
# 18405                                          good game
# 1855                                                omor
# 26071                                             potato
# 26446                                          very good
# 20458                             The factory must grow.
# 3772                                                cool
# 26519                                              smash
# 23471                                  this game is good
# 2695                                           Good game
# 11850  A week ago I was diagnosed with a terminal ill...
# 16083                                                war
# 22322                                           very fun
# 4851                                    i love this game
# 10026                                               good
# 10201                                                  E
# 22267                                               good
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 25319  0.510736227035522461      True               81                1233
# 27141  0.523809552192687988      True                0                 604
# 25104  0.519403576850891113      True                0                3704
# 23832  0.523809552192687988      True                0                2190
# 24834   0.52173912525177002      True               16                 233
# 14736  0.523809552192687988      True               31                 710
# 18450  0.523809552192687988      True               73                 227
# 23437  0.523809552192687988      True               11                  60
# 18328  0.523809552192687988      True             1180                 112
# 19979  0.523809552192687988      True                6                1987
# 16461  0.523809552192687988      True                0               90823
# 22051  0.545454561710357666      True                0                 621
# 15087  0.812537193298339844      True                0               87575
# 23749  0.523809552192687988      True                0                4499
# 26312  0.523809552192687988      True                0                   9
# 4350   0.523809552192687988      True               67                 593
# 11223  0.518518567085266113     False               25               16021
# 6872   0.523809552192687988      True                0                 326
# 26323  0.523809552192687988      True               31                 275
# 9150   0.563492059707641602      True              120                3007
# 13385  0.523809552192687988      True                0               15344
# 14153  0.509803950786590576      True                0               34031
# 21898  0.569653987884521484      True              834                4170
# 21753  0.852275967597961426      True               50                4773
# 18462  0.523809552192687988      True                0                  61
# 27898   0.87734609842300415      True              760                1519
# 301    0.545454561710357666      True                0                2290
# 30502  0.523809552192687988      True              427                 297
# 9783   0.869712591171264648      True                0                5745
# 25191   0.51754385232925415      True                0                2363
# 3572   0.523809552192687988      True                0                4611
# 25485  0.503636360168457031      True                0                 176
# 4444   0.523809552192687988      True                0               80222
# 25301  0.512195110321044922      True                0                 758
# 4963    0.52173912525177002      True                0                3751
# 26333  0.523809552192687988      True               87                 573
# 27316  0.523809552192687988      True                0                2653
# 9514    0.52173912525177002      True                0                 650
# 24755   0.52173912525177002      True                0                 425
# 8512    0.52173912525177002      True              401                 106
# 3529   0.523809552192687988      True               81                4583
# 20475   0.52173912525177002      True              233                1524
# 22603  0.523809552192687988      True               61               21358
# 18405  0.523809552192687988      True                0                1244
# 1855   0.508928596973419189      True                0                1993
# 26071  0.525862038135528564      True               84                 298
# 26446  0.523809552192687988      True                0                1167
# 20458   0.52173912525177002      True                0                  30
# 3772   0.523809552192687988      True                0                 181
# 26519  0.523809552192687988      True               37                 343
# 23471  0.523809552192687988      True                0                1992
# 2695   0.545454561710357666      True                0                5616
# 11850  0.848479092121124268      True              396                7537
# 16083  0.523809552192687988      True               34                6879
# 22322  0.527559041976928711      True               23                 193
# 4851    0.52173912525177002      True                0                 577
# 10026  0.559228658676147461      True                0               18629
# 10201   0.52702707052230835      True                0                8217
# 22267  0.537572264671325684      True                0                2836
#
#        num_reviews   timestamp_created          color
# 25319           12 2023-01-03 18:55:36      mistyrose
# 27141            4 2022-11-27 21:21:06        thistle
# 25104            3 2023-04-09 15:29:21      mistyrose
# 23832            1 2023-01-09 10:10:21      mistyrose
# 24834            8 2023-01-21 16:55:23      mistyrose
# 14736            6 2022-12-27 01:05:52        thistle
# 18450            5 2023-03-03 20:32:18        thistle
# 23437            2 2023-03-17 13:09:40      mistyrose
# 18328           19 2023-05-01 17:57:24        thistle
# 19979            8 2023-04-22 15:39:58           pink
# 16461            7 2022-10-27 11:51:41           pink
# 22051            4 2023-03-12 13:31:13      mistyrose
# 15087            1 2023-01-30 03:02:42           pink
# 23749            2 2023-01-23 16:57:08      mistyrose
# 26312            2 2023-07-10 12:44:30        thistle
# 4350             2 2022-12-22 10:41:10      mistyrose
# 11223            1 2023-03-01 16:14:07           pink
# 6872            13 2022-11-09 04:35:30        thistle
# 26323            4 2023-07-07 23:26:31        thistle
# 9150            10 2023-01-09 07:45:54  palevioletred
# 13385            7 2022-11-10 19:57:04           pink
# 14153            8 2023-08-20 11:50:14           pink
# 21898           15 2023-05-06 22:26:37      mistyrose
# 21753           10 2023-02-18 00:46:09      mistyrose
# 18462           15 2023-02-28 20:27:10        thistle
# 27898           21 2015-11-17 13:41:02        thistle
# 301              3 2022-12-09 02:32:56  palevioletred
# 30502           19 2023-09-12 13:56:16  palevioletred
# 9783             1 2017-11-26 12:18:04  palevioletred
# 25191            2 2023-02-06 18:07:32      mistyrose
# 3572             3 2023-05-15 04:09:27      mistyrose
# 25485            7 2023-01-27 17:04:45      mistyrose
# 4444             4 2022-11-30 12:40:52      mistyrose
# 25301            4 2022-12-31 01:02:58      mistyrose
# 4963             1 2023-01-21 02:31:25      mistyrose
# 26333            2 2023-07-04 16:08:34        thistle
# 27316           10 2022-10-06 00:32:25        thistle
# 9514             5 2023-03-08 20:34:48  palevioletred
# 24755            1 2023-04-26 23:32:45      mistyrose
# 8512            96 2023-03-07 05:58:06  palevioletred
# 3529            18 2023-05-27 04:13:29      mistyrose
# 20475            8 2023-06-11 20:45:33           pink
# 22603            6 2023-08-23 07:43:06      mistyrose
# 18405            1 2023-03-20 21:41:41        thistle
# 1855             3 2022-12-28 20:55:38  palevioletred
# 26071           22 2022-12-11 03:16:27        thistle
# 26446            1 2023-05-19 03:03:32        thistle
# 20458            1 2023-08-07 03:27:34           pink
# 3772            10 2023-03-30 21:16:30      mistyrose
# 26519           15 2023-04-29 13:38:32        thistle
# 23471           62 2023-03-11 23:37:44      mistyrose
# 2695             1 2022-11-23 04:19:07      mistyrose
# 11850           10 2023-10-23 18:39:26           pink
# 16083            2 2023-02-21 21:00:16           pink
# 22322            6 2023-03-01 13:22:02      mistyrose
# 4851             1 2023-07-10 10:10:19      mistyrose
# 10026            5 2023-01-01 17:20:25           pink
# 10201            4 2022-12-14 01:26:37           pink
# 22267            1 2022-10-30 04:03:18      mistyrose

# %%
(df.duplicated(subset='review') == False).sum()
# Out:
# 29492

# %%
df = df[df.duplicated(subset='review') == False]

# %%
df.duplicated(subset='review').sum()
# Out:
# 0

# %% [markdown]
# #### Długość recenzji

# %%
df["temp_review_len"] = df["review"].apply(lambda x: x.split(" ").__len__())
df["temp_review_len"].describe()
# Out:
# count    29492.000000
# mean        54.191984
# std        135.354534
# min          1.000000
# 25%          5.000000
# 50%         13.000000
# 75%         39.000000
# max       3997.000000
# Name: temp_review_len, dtype: float64

# %%
df[df["temp_review_len"] == df["temp_review_len"].max()]['review'].values
# Out:
# array(['t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r  ...
#       dtype=object)

# %%
df[df["temp_review_len"] < 4].groupby(by=["genre"]).count()
# Out:
#        title  steamid  votes_up  review  weighted_vote_score  voted_up  \
# genre
# A       1659     1659      1659    1659                 1659      1659
# P        852      852       852     852                  852       852
# R        798      798       798     798                  798       798
# S       1140     1140      1140    1140                 1140      1140
#
#        num_games_owned  playtime_at_review  num_reviews  timestamp_created  \
# genre
# A                 1659                1659         1659               1659
# P                  852                 852          852                852
# R                  798                 798          798                798
# S                 1140                1140         1140               1140
#
#        color  temp_review_len
# genre
# A       1659             1659
# P        852              852
# R        798              798
# S       1140             1140

# %%
df = df[df["temp_review_len"] >= 3]

# %%
suma = 0
for i in df["temp_review_len"]:
    suma += i

# %%
print("Ilość słów:", suma,
     "Ilość recenzji:", len(df["temp_review_len"]))
# Out:
# Ilość słów: 1593992 Ilość recenzji: 26663

# %% [markdown]
# ### Wordcloud

# %%
txt = ' '.join(i for i in df["review"])
wordcloud = WordCloud(max_font_size = 180,
                max_words = 120,
                width = 1200,
                height = 800,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "A"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "R"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "P"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "S"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# #### Usunięcie znaków, text lowering

# %%
df["review"] = df["review"].str.replace(r"\[.*?\]|\n|[^\x00-\x7F]+", "", regex=True).str.lower()

# %%
df["review"].sample(10)
# Out:
# 4038                                  everything is fine:)
# 15878                                  you can kill hitler
# 7188                           god this game fucking sucks
# 10226                                       good good good
# 3900     "absoluuttinen leija konnien kanssa"- mcjustus...
# 24439    ksisjdjejeufjejekdjdjdjxjejfjdudjdkjfkdjfjfjdk...
# 7292     where portal has humor and the talos principe ...
# 4302                   so much fun graphics are beautifull
# 7690                        i do like hurting other people
# 27540    amazing story and gameplaydo not have sex thro...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie znaków interpunkcyjnych i liczb

# %%
df["review"] = df["review"].str.replace(r"[0-9]", "", regex=True)

# %%
import string 
df["review"] = df["review"].str.replace('['  + string.punctuation + ']', "", regex =True)

# %%
df["review"].sample(5)
# Out:
# 5338     avast ye theres a person of interest on the po...
# 26347                                         my name jeff
# 26354    a good classic puzzle game with a great story ...
# 16750    youve played for  hours would you recommend th...
# 27213    burned someones house down with lemons and got...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie tytułów gier z recenzji

# %%
lowercased_values = [value.lower() if isinstance(value, str) else value for value in title_dict.values()]

df["review"] = df["review"].apply(lambda x: str.replace(x, "") if x in lowercased_values else x)
df["review"][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [212], line 3
#       1 lowercased_values = [value.lower() if isinstance(value, str) else value for value in title_dict.values()]
# ----> 3 df["review"] = df["review"].apply(lambda x: str.replace(x, "") if x in lowercased_values else x)
#       4 df["review"][0]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In [212], line 3, in <lambda>(x)
#       1 lowercased_values = [value.lower() if isinstance(value, str) else value for value in title_dict.values()]
# ----> 3 df["review"] = df["review"].apply(lambda x: str.replace(x, "") if x in lowercased_values else x)
#       4 df["review"][0]
#
# TypeError: replace expected at least 2 arguments, got 1

# %% [markdown]
# #### Tokenizacja

# %%
import nltk
df["tokenized"] = df["review"].apply(nltk.word_tokenize)

# %%
df["tokenized"].sample(15)

# %% [markdown]
# #### Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
english_stopwords = stopwords.words('english')
english_stopwords_cleaned = [word.replace("'", "") for word in english_stopwords]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marty\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
new_column = []
for row in df["tokenized"]:
    new_row = [word for word in row if word[0] not in english_stopwords_cleaned]
    new_column.append(new_row)
df["final_review"] = new_column

# %% [markdown]
# ## Dependency parser test

# %%
test = [df["final_review"][6543], df["final_review"][4534], df["final_review"][12345], df["final_review"][12354],
        df["final_review"][1925], df["final_review"][1067],df["final_review"][22951],df["final_review"][2231],
       ["gameplay","not","fun"], df["tokenized"][832], df["final_review"][21]]

# %%
import stanza
nlp = stanza.Pipeline('en', tokenize_pretokenized=True) 
doc = nlp(test)
# Out:
# 2024-04-10 10:26:21 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-04-10 10:26:21 INFO: Downloaded file to C:\Users\marty\stanza_resources\resources.json
# 2024-04-10 10:26:23 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-04-10 10:26:23 INFO: Using device: cuda
# 2024-04-10 10:26:23 INFO: Loading: tokenize
# 2024-04-10 10:26:23 INFO: Loading: mwt
# 2024-04-10 10:26:24 INFO: Loading: pos
# 2024-04-10 10:26:24 INFO: Loading: lemma
# 2024-04-10 10:26:24 INFO: Loading: constituency
# 2024-04-10 10:26:25 INFO: Loading: depparse
# 2024-04-10 10:26:26 INFO: Loading: sentiment
# 2024-04-10 10:26:26 INFO: Loading: ner
# 2024-04-10 10:26:27 INFO: Done loading processors!

# %%
dependency_list = []
for dependency in doc.sentences[8].dependencies:
    dependency_list.append([dependency[2].text, dependency[0].id, dependency[1]])
    
for i in range(0, len(dependency_list)):
    if (int(dependency_list[i][1]) != 0):
        dependency_list[i][1] = test[8][(int(dependency_list[i][1]) - 1)]

print(dependency_list)
# Out:
# [['gameplay', 0, 'root'], ['not', 'fun', 'advmod'], ['fun', 'gameplay', 'parataxis']]

# %%
feature_list = []
feature_opinion_list = [] 

for dependency in doc.sentences[7].dependencies:
    if dependency[2].xpos == "RB":
        opinion_word = dependency[2]
        rb_adj = dependency[0]
        
    if (dependency[2].xpos in ["NN", "NNS", "JJ", "JJS", "JJR"]) and (dependency[1] in ["amod"]):
        if dependency[0] == rb_adj or dependency[2] == rb_adj:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}     
        else:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}  

        feature_list.append(dependency[0].lemma)
        feature_opinion_list.append(result_dict)

print(f'Feature list: {feature_list}')
print(f'Feature-opinion list: {feature_opinion_list}')
# Out:
# Feature list: ['horror', 'health']
# Feature-opinion list: [{'feature': 'horror', 'opinion': 'psychological'}, {'feature': 'health', 'opinion': 'proper'}]

# %% [markdown]
# ## Dependency parser final

# %%
feature_list_column = []
feature_opinion_list_column = []

for review in df["final_review"][1722:1735]:
    if isinstance(review, list):
        review = " ".join(review)
        doc = nlp(review)
        feature_list = []
        feature_opinion_list = [] 
        
        if len(doc.sentences) == 0:
            continue
            
        for dependency in doc.sentences[0].dependencies:
            if dependency[2].xpos == "RB":
                opinion_word = dependency[2]
                rb_adj = dependency[0]
            if (dependency[2].xpos in ["JJ", "JJS"]) and (dependency[0].xpos in ["NN", "NNS"]) and (dependency[1] in ["amod"]):

                if dependency[0] == rb_adj or dependency[2] == rb_adj:
                    if dependency[2].xpos in ["JJS", "JJR"]:
                        result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
                    else:
                        result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}     
                else:
                    if dependency[2].xpos in ["JJS", "JJR"]:
                        result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
                    else:
                        result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}  

                feature_list.append(dependency[0].lemma)
                feature_opinion_list.append(result_dict)
        print(feature_opinion_list)
                
    feature_list_column.append(feature_list)
    feature_opinion_list_column.append(feature_opinion_list)
# Out:
# []
# [{'feature': 'undertale', 'opinion': 'earthbound'}, {'feature': 'game', 'opinion': 'great'}, {'feature': 'job', 'opinion': 'favorite'}, {'feature': 'job', 'opinion': 'great'}, {'feature': 'ending', 'opinion': 'crazy'}, {'feature': 'ending', 'opinion': 'complete'}, {'feature': 'nikki', 'opinion': 'earthbound'}, {'feature': 'part', 'opinion': 'favorite'}, {'feature': 'game', 'opinion': 'worth'}]
# []
# [{'feature': 'experience', 'opinion': 'vain'}, {'feature': 'narrative', 'opinion': 'fun'}, {'feature': 'narrative', 'opinion': 'colourful'}, {'feature': 'game', 'opinion': 'psychological'}, {'feature': 'game', 'opinion': 'bright'}, {'feature': 'game', 'opinion': 'cheery'}, {'feature': 'game', 'opinion': 'flat'}, {'feature': 'everyone', 'opinion': 'comfortable'}, {'feature': 'rpg', 'opinion': 'fairly fresh'}, {'feature': 'beating', 'opinion': 'happy'}, {'feature': 'box', 'opinion': 'very unique'}, {'feature': 'hit', 'opinion': 'good'}, {'feature': 'effect', 'opinion': 'unique'}, {'feature': 'combat', 'opinion': 'core'}, {'feature': 'bit', 'opinion': 'fresh'}, {'feature': 'person', 'opinion': 'wrong'}, {'feature': 'eye', 'opinion': 'keen'}, {'feature': 'world', 'opinion': 'even zany'}, {'feature': 'game', 'opinion': 'gamesoverall'}, {'feature': 'game', 'opinion': 'exceptional'}, {'feature': 'version', 'opinion': 'future'}]
# []
# [{'feature': 'game', 'opinion': 'good'}]
# []
# []
# []
# [{'feature': 'journey', 'opinion': 'profound'}, {'feature': 'example', 'opinion': 'really romanticizeglamorize'}, {'feature': 'effect', 'opinion': 'harmful'}, {'feature': 'friend', 'opinion': 'poignant'}, {'feature': 'friend', 'opinion': 'fragile'}, {'feature': 'rpg', 'opinion': 'competent'}, {'feature': 'piece', 'opinion': 'heavy'}, {'feature': 'engine', 'opinion': 'quaint'}, {'feature': 'believe', 'opinion': 'just enough'}, {'feature': 'job', 'opinion': 'great'}, {'feature': 'piece', 'opinion': 'good'}, {'feature': 'bond', 'opinion': 'realistic'}, {'feature': 'bond', 'opinion': 'realistic'}, {'feature': 'feeling', 'opinion': 'real'}, {'feature': 'person', 'opinion': 'hard'}, {'feature': 'way', 'opinion': 'clever'}, {'feature': 'life', 'opinion': 'real'}]
# [{'feature': 'game', 'opinion': 'very unique'}, {'feature': 'experience', 'opinion': 'best'}, {'feature': 'combat', 'opinion': 'unique'}, {'feature': 'combat', 'opinion': 'unique'}, {'feature': 'effect', 'opinion': 'emotional'}, {'feature': 'use', 'opinion': 'certain'}, {'feature': 'color', 'opinion': 'combatthe'}, {'feature': 'color', 'opinion': 'full'}, {'feature': 'character', 'opinion': 'bestorywelcome'}, {'feature': 'play', 'opinion': 'white'}, {'feature': 'lightbulb', 'opinion': 'white'}, {'feature': 'lightbulb', 'opinion': 'black'}, {'feature': 'box', 'opinion': 'warm'}, {'feature': 'hero', 'opinion': 'few'}, {'feature': 'focus', 'opinion': 'central'}, {'feature': 'basil', 'opinion': 'best'}, {'feature': 'worldthe', 'opinion': 'very unique'}, {'feature': 'job', 'opinion': 'great'}, {'feature': 'enemy', 'opinion': 'normal'}, {'feature': 'juice', 'opinion': 'certain'}, {'feature': 'end', 'opinion': 'little'}, {'feature': 'experiment', 'opinion': 'best'}, {'feature': 'party', 'opinion': 'new'}, {'feature': 'energy', 'opinion': 'least'}, {'feature': 'party', 'opinion': 'whole'}, {'feature': 'chunk', 'opinion': 'big'}, {'feature': 'emotionsemotion', 'opinion': 'certain'}, {'feature': 'emotion', 'opinion': 'further'}, {'feature': 'emotion', 'opinion': 'happy'}, {'feature': 'beat', 'opinion': 'happy'}, {'feature': 'level', 'opinion': 'enough'}, {'feature': 'reason', 'opinion': 'regular'}, {'feature': 'emotion', 'opinion': 'present'}, {'feature': 'eye', 'opinion': 'very nice'}, {'feature': 'listen', 'opinion': 'really nice'}, {'feature': 'rpg', 'opinion': 'really unique'}, {'feature': 'rpg', 'opinion': 'unique'}, {'feature': 'experience', 'opinion': 'just worth'}, {'feature': 'review', 'opinion': 'good'}]
# []
# [{'feature': 'gameplay', 'opinion': 'beautiful'}, {'feature': 'gameplay', 'opinion': 'good'}, {'feature': 'gameplay', 'opinion': 'bad'}, {'feature': 'gameplay', 'opinion': 'long'}, {'feature': 'NASA', 'opinion': 'rich'}, {'feature': 'usage', 'opinion': 'hard'}, {'feature': 'need', 'opinion': 'necessary'}, {'feature': 'game', 'opinion': 'good'}, {'feature': 'game', 'opinion': 'lovely'}, {'feature': 'price', 'opinion': 'long worth'}, {'feature': 'game', 'opinion': 'big'}]

# %%
##"VBG", "DT"
