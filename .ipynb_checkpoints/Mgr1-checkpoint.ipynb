# %%
import pandas as pd
import spacy
import steamreviews
import json
import csv
import os
import glob
import json
import matplotlib.pyplot as plt
import nltk
import wordcloud
import re
import plotly
import seaborn as sns
import stanza
import string 
import joblib

from scipy.stats import pearsonr
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import fcluster
from wordcloud import WordCloud
from pandas.io.json import json_normalize
from nltk.corpus import stopwords
from tqdm.notebook import trange, tqdm
from sklearn.cluster import KMeans
from collections import defaultdict
from scipy.stats import pearsonr
from collections import Counter
import matplotlib as mpl
import scikit_posthocs as sp

# %% [markdown]
# ## Reviews download
# https://pypi.org/project/steamreviews/

# %% [raw]
# list_of_app_ids = [219150, 1172620, 460950, 262060, 250320, 210970, 620, 736260,
#                    219890, 289070, 427520, 257510, 304430, 400, 394360, 550,
#                    632470, 294100, 646570, 1150690, 1341290, 1515210, 860510]
#
# def get_reviews(list_of_app_ids):
#     request_params = dict()
#     request_params['language'] = 'english'
#     request_params['day_range'] = '365'
#     request_params['filter'] = 'all'
#     for app_id in list_of_app_ids:
#         review_dict, query_count = steamreviews.download_reviews_for_app_id(app_id,chosen_request_params=request_params)
#     return review_dict, query_count
# get_reviews(list_of_app_ids);

# %%
dir_name = "data"
reviews_jsons = glob.glob(f"{dir_name}/*")
reviews_jsons
# Out:
# ['data\\review_1150690.json',
#  'data\\review_1172620.json',
#  'data\\review_1341290.json',
#  'data\\review_1515210.json',
#  'data\\review_210970.json',
#  'data\\review_219150.json',
#  'data\\review_219890.json',
#  'data\\review_250320.json',
#  'data\\review_257510.json',
#  'data\\review_262060.json',
#  'data\\review_289070.json',
#  'data\\review_294100.json',
#  'data\\review_304430.json',
#  'data\\review_394360.json',
#  'data\\review_400.json',
#  'data\\review_427520.json',
#  'data\\review_460950.json',
#  'data\\review_550.json',
#  'data\\review_620.json',
#  'data\\review_632470.json',
#  'data\\review_646570.json',
#  'data\\review_736260.json',
#  'data\\review_860510.json']

# %%
title_dict = {"219150": "Hotline Miami",
              "1172620" : "Sea of Thieves",
              "460950" : "Katana ZERO",
              "262060" : "Darkest Dungeon",
              "250320" : "The Wolf Among Us",
              "210970" : "The Witness",
              "620" : "Portal 2",
              "736260" : "Baba Is You",
              "219890" : "Antichamber",
              "289070" : "Sid Meier's Civilization VI",
              "427520" : "Factorio",
              "257510" : "The Talos Principle",
             "304430" : "INSIDE",
             "400" : "Portal",
             "394360" : "Hearts of Iron IV",
             "632470" : "Disco Elysium",
             "294100" : "RimWorld",
              "646570" : "Slay the Spire",
              "1150690" : "Omori",
              "1341290" : "We Were Here Forever",
              "1515210" : "The Past Within",
              "860510" : "Little Nightmares II",
              "550" : "Left 4 Dead 2"}

# %%
genre_dict = {"219150": "A",
              "1172620" : "A",
              "460950" : "A",
              "262060" : "R",
              "250320" : "R",
              "210970" : "P",
              "620" : "P",
              "736260" : "P",
              "219890" : "P",
              "289070" : "S",
              "427520" : "S",
              "257510" : "P",
              "304430" : "P",
             "400" : "P",
             "394360" : "S",
             "632470" : "R",
             "294100" : "S",
             "646570" : "R",
             "1150690" : "R",
             "1341290" : "P",
             "1515210" : "P",
             "860510" : "P",
             "550" : "A"}

# %%
data_list = []
for i in reviews_jsons:
    with open(i, encoding = "utf-8") as json_file:
        json_data = json.load(json_file)
        reviews = json_data['reviews']
        file_name = json_file.name.split('.')[0].split('_')[1]
        for key in reviews.keys():
            data_list.append([title_dict.get(file_name),genre_dict.get(file_name),reviews[key]['author']['steamid'], reviews[key]['votes_up'], 
                          reviews[key]['review'], reviews[key]['weighted_vote_score'], reviews[key]['voted_up'],
                          reviews[key]['author']['num_games_owned'], reviews[key]['author']['playtime_at_review'],
                          reviews[key]['author']['num_reviews'], 
                          reviews[key]["timestamp_created"] ])
df = pd.DataFrame(data_list, columns = ["title", "genre","steamid", "votes_up", "review", "weighted_vote_score", "voted_up",
                                        "num_games_owned", "playtime_at_review", "num_reviews", "timestamp_created"])

# %%
df.sample(frac=0.3).head()
# Out:
#                              title genre            steamid  votes_up  \
# 9950   Sid Meier's Civilization VI     S  76561199092845442        16
# 5746                Sea of Thieves     A  76561198289485001         1
# 6003                Sea of Thieves     A  76561198272025079         1
# 23599                Left 4 Dead 2     A  76561198310193641         1
# 16344            Hearts of Iron IV     S  76561199071603583         1
#
#                                                   review  \
# 9950   Still working on that 100% but man this be a g...
# 5746   fucking stupid server. can't enjoy playing wit...
# 6003                                              pirate
# 23599                                      boshin lovely
# 16344         Что такое девушка?\nСколько у неё дивизий?
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 9950    0.65224766731262207      True              276               13696
# 5746   0.505494534969329834     False                0               21115
# 6003                    0.5      True                0                7770
# 23599  0.523809552192687988      True               48                1372
# 16344  0.523809552192687988      True                0                5387
#
#        num_reviews  timestamp_created
# 9950            42         1676856061
# 5746             6         1670242945
# 6003            12         1674114974
# 23599           24         1676388280
# 16344            4         1669654460

# %%
df['timestamp_created'] = pd.to_datetime(df['timestamp_created'], unit='s')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 1. Braki danych
# 2. Usunięcie duplikatów
# 4. Usunięcie recenzjii krótszych niż 3 słowa
# 9. Usunięcie znaków spcjalnych
# 10. "Text lowering"
# 6. Usunięcie znaków interpunkcyjnych i liczb
# 8. Usunięcie tytułów gier z recenzji
# 7. Tokenizacja
# 8. Part-of-speech tagging
# 9. Lematyzacja

# %% [markdown]
# #### Braki danych

# %%
df.isna().sum()
# Out:
# title                  0
# genre                  0
# steamid                0
# votes_up               0
# review                 0
# weighted_vote_score    0
# voted_up               0
# num_games_owned        0
# playtime_at_review     0
# num_reviews            0
# timestamp_created      0
# dtype: int64

# %% [markdown]
# #### Usunięcie duplikatów

# %%
df.duplicated(subset='review').sum()
# Out:
# 2580

# %%
df[df.duplicated(subset='review')].sample(20)
# Out:
#                              title genre            steamid  votes_up  \
# 12637                     RimWorld     S  76561198322238492         1
# 1880                         Omori     R  76561199082962270         2
# 23772                Left 4 Dead 2     A  76561198204684236         1
# 27694                     Portal 2     P  76561199145265518         1
# 12801                     RimWorld     S  76561198005328331         1
# 16502            Hearts of Iron IV     S  76561198121633245         1
# 10900  Sid Meier's Civilization VI     S  76561198234700084         1
# 8674             The Wolf Among Us     R  76561197995704395        28
# 12389                     RimWorld     S  76561198114637562         1
# 2206                         Omori     R  76561198163614699       108
# 30578               Slay the Spire     R  76561198029834312         1
# 18311                       Portal     P  76561198322737909         1
# 14743                       INSIDE     P  76561199139556310         1
# 26493                     Portal 2     P  76561199104635055         1
# 16053            Hearts of Iron IV     S  76561199309622147         1
# 23103                Left 4 Dead 2     A  76561199503738766         1
# 8009                 Hotline Miami     A  76561199072029304       182
# 5672                Sea of Thieves     A  76561198364347497         1
# 25902                     Portal 2     P  76561198335473960         2
# 1469                         Omori     R  76561198301250186         1
#
#                                                   review  \
# 12637                                         it is good
# 1880                                               Omori
# 23772                                this game's amazing
# 27694                                          good game
# 12801                                               Good
# 16502                                                gud
# 10900                                               good
# 8674          You're not as bad as everyone says you are
# 12389                                               Yes.
# 2206                            this game ruined my life
# 30578                                         Good stuff
# 18311                                               good
# 14743                                               Good
# 26493                                          Very cool
# 16053                                          very good
# 23103                                         great game
# 8009   girls with autism: *excited lil hands*\n\nboys...
# 5672                                              pirate
# 25902                                                yes
# 1469                                                  :(
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 12637  0.523809552192687988      True                0               60017
# 1880   0.507462680339813232      True                0                 185
# 23772  0.523809552192687988      True              286               13741
# 27694  0.510676145553588867      True                0                 246
# 12801  0.523809552192687988      True              219                5688
# 16502  0.523809552192687988      True              128                5049
# 10900  0.523809552192687988      True               82                 684
# 8674   0.716918468475341797      True                0                 594
# 12389  0.527559041976928711      True              197              152301
# 2206   0.869415760040283203      True                0                1030
# 30578  0.523809552192687988      True                0               23334
# 18311  0.523809552192687988      True                0                 261
# 14743  0.523809552192687988      True               37                 207
# 26493  0.523809552192687988      True                0                 511
# 16053  0.523809552192687988      True                0                 789
# 23103  0.523809552192687988      True                0                 324
# 8009     0.8478546142578125      True               33                 378
# 5672   0.507042229175567627      True                0                 718
# 25902  0.545454561710357666      True                0                 379
# 1469   0.523809552192687988      True              105                2229
#
#        num_reviews   timestamp_created
# 12637            1 2023-07-25 16:07:31
# 1880             2 2023-07-20 01:07:00
# 23772           34 2023-01-19 22:05:04
# 27694           11 2022-11-11 08:05:15
# 12801            4 2023-05-08 13:27:39
# 16502           32 2022-10-14 17:24:16
# 10900           22 2022-11-12 19:51:37
# 8674            26 2023-11-03 17:43:42
# 12389           13 2023-01-17 01:35:28
# 2206             4 2023-12-27 12:45:45
# 30578            1 2023-06-10 17:45:00
# 18311            3 2023-05-13 12:30:59
# 14743            9 2022-12-14 19:40:57
# 26493            1 2023-05-05 07:04:57
# 16053            7 2023-03-05 17:07:57
# 23103            3 2023-05-11 02:30:04
# 8009             4 2022-01-05 10:43:33
# 5672            25 2023-01-08 22:54:43
# 25902            5 2023-09-19 00:33:52
# 1469             4 2022-10-18 02:54:56

# %%
(df.duplicated(subset='review') == False).sum()
# Out:
# 29492

# %%
df = df[df.duplicated(subset='review') == False]

# %%
df.duplicated(subset='review').sum()
# Out:
# 0

# %% [markdown]
# #### Długość recenzji

# %%
df["temp_review_len"] = df["review"].apply(lambda x: x.split(" ").__len__())
df["temp_review_len"].describe()
# Out:
# count    29492.000000
# mean        54.191984
# std        135.354534
# min          1.000000
# 25%          5.000000
# 50%         13.000000
# 75%         39.000000
# max       3997.000000
# Name: temp_review_len, dtype: float64

# %% [raw]
# df[df["temp_review_len"] == df["temp_review_len"].max()]['review'].values

# %%
df[df["temp_review_len"] < 4].groupby(by=["genre"]).count()
# Out:
#        title  steamid  votes_up  review  weighted_vote_score  voted_up  \
# genre
# A       1659     1659      1659    1659                 1659      1659
# P        852      852       852     852                  852       852
# R        798      798       798     798                  798       798
# S       1140     1140      1140    1140                 1140      1140
#
#        num_games_owned  playtime_at_review  num_reviews  timestamp_created  \
# genre
# A                 1659                1659         1659               1659
# P                  852                 852          852                852
# R                  798                 798          798                798
# S                 1140                1140         1140               1140
#
#        temp_review_len
# genre
# A                 1659
# P                  852
# R                  798
# S                 1140

# %%
df = df[df["temp_review_len"] >= 3]

# %%
suma = 0
for i in df["temp_review_len"]:
    suma += i

# %%
print("Ilość słów:", suma,
     "Ilość recenzji:", len(df["temp_review_len"]))
# Out:
# Ilość słów: 1593992 Ilość recenzji: 26663

# %%
df = df.drop(["temp_review_len"], axis=1)

# %% [markdown]
# ### Wordcloud

# %%
txt = ' '.join(i for i in df["review"])
wordcloud = WordCloud(max_font_size = 180,
                max_words = 120,
                width = 1200,
                height = 800,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "A"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "R"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "P"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "S"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# #### Usunięcie znaków, text lowering

# %%
df["review"] = df["review"].str.replace(r"\[.*?\]|\n|[^\x00-\x7F]+", "", regex=True).str.lower()

# %%
df["review"].sample(10)
# Out:
# 6219     find a friend and enjoy, communicate, and rage...
# 4379     recomiendo este juego, especialmente lo pasari...
# 1298     nothing i say about omori could do it justice....
# 28710    code 31 officer in need of assistance on the d...
# 13230    fun and addicting. only problem is that the de...
# 18790    some of the hardest achievements i did in a ga...
# 1553                                    i have nightmares.
# 27504    i am both the dumb player and the smart player...
# 12751             may the 5000+ hours speak for themselves
# 8990     do you like puzzles? are you interested in exi...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie znaków interpunkcyjnych i liczb

# %%
df["review"] = df["review"].str.replace(r"[0-9]", "", regex=True)

# %%
df["review"] = df["review"].str.replace('['  + string.punctuation + ']', "", regex =True)

# %%
df["review"].sample(5)
# Out:
# 27227                                       story is great
# 16385                                      anti go outside
# 19465    run while you still can dont look backrecommen...
# 11002    civ is amazing i install it every few years to...
# 284      if you like undertale youll love omorithis gam...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie tytułów gier z recenzji

# %%
for value in title_dict.values():
    df["review"] = df["review"].str.replace(value.lower(), "")

# %% [markdown]
# #### Tokenizacja

# %%
df["tokenized"] = df["review"].apply(nltk.word_tokenize)

# %%
df["tokenized"].sample(15)
# Out:
# 1676     [i, love, it, final, duet, makes, me, cry, eve...
# 9710     [a, great, game, to, help, you, get, rid, of, ...
# 8120                                       [ow, my, brain]
# 7840         [puedo, sentir, el, venirse, adentro, de, mi]
# 9100           [i, would, sleep, with, anyone, who, plays]
# 19178    [only, played, hours, hours, and, i, would, sa...
# 23213    [i, swear, if, someone, makes, another, addon,...
# 18488                           [its, you, go, through, s]
# 12986    [after, hours, i, have, finally, beaten, the, ...
# 18718    [i, wonder, can, i, scratch, my, back, with, t...
# 23829    [amazing, game, from, our, childhoods, support...
# 25655                                 [coach, my, beloved]
# 7207     [excellent, puzzle, game, simple, concept, but...
# 16495    [guns, go, brr, orange, pie, chart, good, plan...
# 28048    [capital, has, the, ability, to, subsume, all,...
# Name: tokenized, dtype: object

# %% [markdown]
# ### Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
english_stopwords = stopwords.words('english')
english_stopwords_cleaned = [word.replace("'", "") for word in english_stopwords]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marty\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
new_column = []
for row in df["tokenized"]:
    new_row = [word for word in row if word[0] not in english_stopwords_cleaned]
    new_column.append(new_row)
df["final_review"] = new_column

# %% [markdown]
# ## Describe

# %%
df.dtypes
# Out:
# title                          object
# genre                          object
# steamid                        object
# votes_up                        int64
# review                         object
# weighted_vote_score            object
# voted_up                         bool
# num_games_owned                 int64
# playtime_at_review              int64
# num_reviews                     int64
# timestamp_created      datetime64[ns]
# tokenized                      object
# final_review                   object
# dtype: object

# %%
df["weighted_vote_score"] = pd.to_numeric(df["weighted_vote_score"])

# %%
df["voted_up"] = pd.to_numeric(df["voted_up"])

# %%
df.describe()
# Out:
#            votes_up  weighted_vote_score  num_games_owned  playtime_at_review  \
# count  26663.000000         26663.000000     26663.000000        2.666300e+04
# mean      31.715148             0.570098       140.866707        1.309372e+04
# std      173.097223             0.109932       538.652824        4.720263e+04
# min        0.000000             0.500000         0.000000        5.000000e+00
# 25%        1.000000             0.521739         0.000000        5.350000e+02
# 50%        1.000000             0.523810         0.000000        1.800000e+03
# 75%        3.000000             0.545180       113.000000        7.111500e+03
# max     9568.000000             0.987843     22780.000000        1.890626e+06
#
#         num_reviews
# count  26663.000000
# mean      21.467689
# std       59.809381
# min        1.000000
# 25%        3.000000
# 50%        8.000000
# 75%       20.000000
# max     3419.000000

# %%
corr = df.corr(method = "pearson")
plt.figure(figsize=(7,5))
sns.heatmap(corr, cmap=sns.cubehelix_palette(as_cmap=True),annot=True)
plt.show()
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_4388\2852639080.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method = "pearson")

# %% [markdown]
# ## Wykresy

# %%
value_counts_title = df["title"].value_counts()
genre_colors = {"A": sns.cubehelix_palette(4)[1], "R": sns.cubehelix_palette(4)[2], "P": sns.cubehelix_palette(4)[3], 
                "S": sns.cubehelix_palette(4)[0]}
df['color'] = df['genre'].map(genre_colors)
colors = [df.loc[df['title'] == title]['color'].iloc[0] for title in value_counts_title.index]

plt.figure(figsize=(12, 6))
x = value_counts_title.plot(kind = "bar", color = colors)
plt.ylabel("Ilość recenzji")
plt.xticks(rotation = 90)
for i, count in enumerate(value_counts_title):
    x.text(i, count, count, va = "bottom", ha = "center")

handles = [plt.Rectangle((0,0), 1,1, color=genre_colors[label]) for label in genre_colors]
plt.legend(handles, genre_colors.keys(), title="Gatunek", loc="upper right")


plt.show()
df = df.drop(["color"], axis=1)

# %%
value_counts_recommendation_genre = df.groupby("genre").voted_up.value_counts().unstack(0)
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 

total_count = percentage_pos + percentage_neg

def addlabels_neg(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] + 2, f"{x[i]:.2f}%",  ha = "center")

def addlabels_pos(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] - 6, f"{y[i]:.2f}%",  ha = "center")

fig, axs = plt.subplots(1, 2, figsize=(12, 4))

total_count.plot(kind="bar", color="#d0a2cf",  label="Recommended")
percentage_neg.plot(kind="bar", color="#543d71", label="Not Recommended")

axs[1].set_xlabel("Gatunki")
addlabels_neg(percentage_neg, total_count) 
addlabels_pos(total_count, percentage_pos) 
axs[1].legend(["Polecane",  "Niepolecane"], loc="upper center", bbox_to_anchor=(0.5, 1.15), ncol=2, fontsize=11)


value_counts_genre = df["genre"].value_counts()
colors = sns.cubehelix_palette(6, rot=.2)

axs[0].pie(value_counts_genre, labels = value_counts_genre.index,colors=colors, autopct='%1.1f%%', startangle=140)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Dependency parser test

# %%
test = [df["final_review"][6543], df["final_review"][4534], df["final_review"][12345], df["final_review"][12354],
        df["final_review"][1925], df["final_review"][1067],df["final_review"][22951],df["final_review"][2231],
       ["not","fun", "gameplay"], df["tokenized"][832], df["final_review"][21], df["tokenized"][27061],
       df["final_review"][11088], df["final_review"][3171], df["final_review"][7834], df["final_review"][20180],
       df["final_review"][6697], df["final_review"][893]]

# %%
import stanza
nlp = stanza.Pipeline('en', tokenize_pretokenized=True) 
doc = nlp(test)
# Out:
# 2024-09-08 12:43:42 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-09-08 12:43:43 INFO: Downloaded file to C:\Users\marty\stanza_resources\resources.json
# 2024-09-08 12:43:43 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-09-08 12:43:43 INFO: Using device: cuda
# 2024-09-08 12:43:43 INFO: Loading: tokenize
# 2024-09-08 12:43:43 INFO: Loading: mwt
# 2024-09-08 12:43:43 INFO: Loading: pos
# 2024-09-08 12:43:44 INFO: Loading: lemma
# 2024-09-08 12:43:44 INFO: Loading: constituency
# 2024-09-08 12:43:45 INFO: Loading: depparse
# 2024-09-08 12:43:45 INFO: Loading: sentiment
# 2024-09-08 12:43:45 INFO: Loading: ner
# 2024-09-08 12:43:46 INFO: Done loading processors!

# %%
dependency_list = []
for dependency in doc.sentences[13].dependencies:
    dependency_list.append([dependency[2].text, dependency[0].id, dependency[1]])
    
for i in range(0, len(dependency_list)):
    if (int(dependency_list[i][1]) != 0):
        dependency_list[i][1] = test[13][(int(dependency_list[i][1]) - 1)]

print(*dependency_list[:10], sep='\n')
# Out:
# ['crewing', 0, 'root']
# ['game', 'value', 'compound']
# ['value', 'crewing', 'obj']
# ['likely', 'crewing', 'advmod']
# ['worthless', 'crewing', 'xcomp']
# ['real', 'crewing', 'xcomp']
# ['but', 'play', 'cc']
# ['can', 'play', 'aux']
# ['play', 'crewing', 'conj']
# ['player', 'play', 'obj']

# %%
feature_list = []
feature_opinion_list = [] 

for dependency in doc.sentences[13].dependencies:
    if dependency[2].xpos == "RB":
        opinion_word = dependency[2]
        rb_adj = dependency[0]
        
    if (dependency[2].xpos in ["NN", "NNS","JJ", "JJS", "JJR"]) and (dependency[1] in ["amod"]):
        if dependency[0] == rb_adj or dependency[2] == rb_adj:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}     
        else:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}  

        feature_list.append(dependency[0].lemma)
        feature_opinion_list.append(result_dict)

print(f'Feature list: {feature_list}')
print(f'Feature-opinion list: {feature_opinion_list}')
# Out:
# Feature list: ['graphic', 'beauty', 'player', 'player', 'player', 'guide', 'reward', 'reward', 'reward']
# Feature-opinion list: [{'feature': 'graphic', 'opinion': 'fun'}, {'feature': 'beauty', 'opinion': 'real'}, {'feature': 'player', 'opinion': 'unbalanced'}, {'feature': 'player', 'opinion': 'janky'}, {'feature': 'player', 'opinion': 'human'}, {'feature': 'guide', 'opinion': 'necessary'}, {'feature': 'reward', 'opinion': 'risky'}, {'feature': 'reward', 'opinion': 'lowest'}, {'feature': 'reward', 'opinion': 'highest'}]

# %% [markdown]
# ## Dependency parser final

# %% [raw]
# feature_list_column = []
# feature_opinion_list_column = []
#
# for review in tqdm(df["final_review"]):
#     if isinstance(review, list):
#         review = " ".join(review)
#         doc = nlp(review)
#         feature_list = []
#         feature_opinion_list = []
#
#         if len(doc.sentences) == 0:
#             continue
#
#         for dependency in doc.sentences[0].dependencies:
#             if dependency[2].xpos == "RB":
#                 opinion_word = dependency[2]
#                 rb_adj = dependency[0]
#             if (dependency[2].xpos in ["JJ", "JJS"]) and (dependency[0].xpos in ["NN", "NNS"]) and (dependency[1] in ["amod"]):
#
#                 if dependency[0] == rb_adj or dependency[2] == rb_adj:
#                     if dependency[2].xpos in ["JJS", "JJR"]:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
#                     else:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}
#                 else:
#                     if dependency[2].xpos in ["JJS", "JJR"]:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
#                     else:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}
#
#                 feature_list.append(dependency[0].lemma)
#                 feature_opinion_list.append(result_dict)
#
#     feature_list_column.append(feature_list)
#     feature_opinion_list_column.append([review, feature_opinion_list])
#
# df["feature"] = [feature_list_column]
# df["feature_opinion_list"] = [feature_opinion_list_column]

# %% [raw]
# new_df = pd.DataFrame([feature_list_column, feature_opinion_list_column])
# new_df.T
#
# non_empty_indexes = df[df["final_review"].apply(lambda x: len(x)!=0)].index
#
# import json
# opinions_dict = {k:v for k, v in zip(non_empty_indexes, feature_opinion_list_column)}
# out_file = open("opinions.json", "w")
#
# json.dump(opinions_dict, out_file, indent = 6)
#
# out_file.close()

# %%
with open('opinions.json', 'r') as file:
    dct = json.load(file)

# %%
feature_list = []

for i in range(len(df)):
    index = str(i)  
    feature = dct.get(index)
    if feature is None:
        feature_list.append([])
    else:
        feature_list.append(feature)

df["feature"] = feature_list

# %%
words = []
for i in df["feature"]:
    for j in i:
        words.append(j["feature"])

# %%
unique_words = list(set(words))

# %%
word_counts = pd.DataFrame([[i, len([q for q in words if q==i])] for i in unique_words], 
              columns=['word', 'count']).sort_values('count', ascending=False)

# %% [markdown]
# ## Dendrogram

# %%
popular_words = word_counts[word_counts['count']>= 15]["word"].to_list()
nlp = spacy.load('en_core_web_md')
tokens = [nlp(word) for word in popular_words]
word_vectors = pd.DataFrame([i.vector for i in tokens])

# %%
Z = linkage(word_vectors.values, method='ward')

plt.figure(figsize=(10,6))
dendrogram(Z, p = 4, truncate_mode = "level", orientation='top', above_threshold_color="blue", 
           labels = popular_words, leaf_font_size = 10)
plt.title('Hierarchical Clustering Dendrogram')

plt.grid(True, linestyle='--', alpha=0.5)

plt.axhline(y=75, color='red', linestyle='--', label='Threshold = 75')

plt.legend()

plt.xlabel('Words')
plt.ylabel('Distance')
plt.tight_layout()
plt.show()

# %%
cluster_labels = fcluster(Z, t = 75,  criterion="distance")

clusters = {}
for word, label in zip(popular_words, cluster_labels):
    if label not in clusters:
        clusters[label] = [word]
    else:
        clusters[label].append(word)

for label, words in clusters.items():
    print(f"Cluster {label}: {', '.join(words)}")
# Out:
# Cluster 68: game, play, player, playing
# Cluster 57: puzzle, pirate, horror, zomby, zombie, pawn, wolf, franchise, coop, nightmare, limbo, pve, gamei, fable, clue, glado, eargasm, chill, cannibal, hacker
# Cluster 21: experience, community, work, environment, resource, workshop, focus, knowledge, research, project, practice, learning
# Cluster 75: gameplay, gamer, gaming, rng, bonus, replay, cue
# Cluster 99: way, pace
# Cluster 97: hour, week, night
# Cluster 12: price, cost
# Cluster 47: person, friend, boss, child, woman, family, partner
# Cluster 48: love, choice, voice, wish, reward, hope, enjoyment, pleasure, praise
# Cluster 62: character, hero, genre, plot, figure, episode, cutscene, lore, chapter, legend, protagonist, narrator, backstory
# Cluster 1: world, city, country, nation
# Cluster 54: fun
# Cluster 19: level, point, number, class, rating
# Cluster 72: review, note, view, guide
# Cluster 76: graphic, visual, video, pixel
# Cluster 18: content, quality, value, product
# Cluster 52: lot
# Cluster 50: life
# Cluster 4: part, event, place
# Cluster 58: grind, luck, guess, hell, fuck, joke, ruin, cry, biter
# Cluster 25: challenge, problem, effect, reason, possibility, question, change, chance, balance, future, potential, factor, purpose
# Cluster 53: bit
# Cluster 8: colony, quest, colonist, empire, journey, voyage, fortress
# Cluster 92: room, wall, floor
# Cluster 77: update, feature, version, release, entry, upgrade, launcher, patch
# Cluster 9: end
# Cluster 63: bug, glitch
# Cluster 49: nothing, everything, feeling, everyone, emotion, kind, being, fear
# Cluster 16: factory, base, unit, platformer, location, production, company, plant, equipment, network, facility, platform
# Cluster 78: NASA
# Cluster 64: civ, pvp, rpg
# Cluster 7: enemy, fight, battle, combat, campaign, effort, victory
# Cluster 85: line, curve, loop, button, edge, length, belt, hook
# Cluster 51: guy, kid, boy, girl
# Cluster 20: element, playthrough, ending, civilization, requirement, replayability, example, progress, form, complaint, exploration, conclusion, progression, period, customization, connection, combination, conversation, expansion, confession, process, beginning, relationship, portion, communication, recommendation, frustration, condition, complexity, comment, warning, presentation, cycle, component, execution, experiment
# Cluster 39: need, help, want
# Cluster 29: run
# Cluster 43: job
# Cluster 22: concept, history, narrative, writing, personality, philosophy, nature, language, reality, perspective, vision, behavior
# Cluster 15: building, builder, build
# Cluster 101: lake, water, boat
# Cluster 11: war
# Cluster 37: cant, havent
# Cluster 86: piece, pack, cake, layer, package
# Cluster 30: look, feel
# Cluster 69: fan
# Cluster 102: crew, crash, ride
# Cluster 5: control, force, power
# Cluster 3: leader, party, group, faction
# Cluster 35: use
# Cluster 26: fact, case, crime, error, flaw
# Cluster 89: hand, chamber, face, front, head, corner, lobby, chest, back
# Cluster 60: word, name
# Cluster 95: weapon, loot, gun, bomb
# Cluster 23: robot, encounter, usage, course, planet, landscape, computer, universe, cheater, cosmetic, background, creature, physics, formula, library
# Cluster 42: eye
# Cluster 90: couple, half, winter, plenty
# Cluster 28: wait, break, pass, finish, call, leave, kill, pick, beat
# Cluster 6: rule, plan, policy
# Cluster 61: book, novel
# Cluster 34: buy
# Cluster 84: valve, engine
# Cluster 40: heart, brain, blood, body, bone
# Cluster 59: god
# Cluster 24: worth, waste, purchase, payment, buying, credit
# Cluster 94: raid, raider
# Cluster 87: color, paint, light
# Cluster 45: care, health
# Cluster 100: goal
# Cluster 56: humor, classic, vibe, gem, hint, quirk, charm
# Cluster 17: variety, range
# Cluster 98: path, route, road
# Cluster 71: list, page
# Cluster 79: fps
# Cluster 46: food
# Cluster 93: box
# Cluster 55: joy
# Cluster 38: can, will
# Cluster 80: leg
# Cluster 96: fire
# Cluster 33: find, fix
# Cluster 10: era
# Cluster 82: egg
# Cluster 36: go
# Cluster 65: pc
# Cluster 83: cup
# Cluster 14: risk
# Cluster 31: grow
# Cluster 70: hit
# Cluster 91: wave
# Cluster 27: lack
# Cluster 103: race
# Cluster 88: gold
# Cluster 66: ld
# Cluster 81: hat
# Cluster 41: pain
# Cluster 32: fit
# Cluster 67: ui
# Cluster 13: rate
# Cluster 44: role
# Cluster 74: key
# Cluster 73: log
# Cluster 2: land

# %% [raw]
# clusters = {}
# for word, label in zip(popular_words, cluster_labels):
#     if label not in clusters:
#         clusters[label] = [word]
#     else:
#         clusters[label].append(word)
#
# with open('clusters.csv', 'w') as file:
#     file.write('Cluster,Words\n')
#     for label, words in clusters.items():
#         file.write(f"{label},{' '.join(words)}\n")
#         print(f"Cluster {label}: {', '.join(words)}")
#
# print("Clusters saved to clusters.csv")

# %%
def words_to_list(words_string):
    return words_string.split()

clusters_df = pd.read_csv('clusters.csv', converters={'Words': words_to_list})
clusters_df
# Out:
#      Cluster                                              Words
# 0         68                      [game, play, player, playing]
# 1         57  [puzzle, pirate, horror, zomby, pawn, zombie, ...
# 2         21  [experience, community, work, environment, res...
# 3         75  [gameplay, gamer, gaming, rng, bonus, replay, ...
# 4         99                                        [way, pace]
# ..       ...                                                ...
# 98        13                                             [rate]
# 99        74                                              [key]
# 100       44                                             [role]
# 101        2                                             [land]
# 102       73                                              [log]
#
# [103 rows x 2 columns]

# %% [raw]
# clusters = {7: 'Combat',
#     95: 'Combat',
#     11: "Combat",
#     75: 'Gameplay',
#     19: 'Game Mechanics',
#     99: 'Game Mechanics',
#     25: 'Challenges',
#     76: 'Visuals',
#     87: 'Visuals',
#     67: 'Visuals',
#     56: 'Humor',
#     62: 'Narrative and Story',
#     22: 'Narrative and Story',
#     63: 'Bugs and Glitches',
#     77: 'Updates and Patches',
#     21: 'Community and Collaboration',
#     12: 'Cost',
#     24: 'Cost',
#     18: 'Content Quality',
#     8: 'Quests and Adventures',
#     16: 'Production and Development',
#     72: 'User Feedback',
#     48: 'Enjoyment and Reward'}

# %%
clusters = {
    7: 'Walka',
    95: 'Walka',
    11: 'Walka',
    75: 'Rozgrywka',
    19: 'Mechanika gry',
    99: 'Mechanika gry',
    25: 'Wyzwania',
    76: 'Grafika',
    87: 'Grafika',
    67: 'Grafika',
    56: 'Humor',
    62: 'Narracja i fabuła',
    22: 'Narracja i fabuła',
    63: 'Błędy i usterki',
    77: 'Aktualizacje i poprawki',
    21: 'Społeczność i współpraca',
    12: 'Koszt',
    24: 'Koszt',
    18: 'Jakość treści',
    8: 'Misje i przygody',
    16: 'Produkcja i rozwój',
    72: 'Opinie użytkowników',
    48: 'Satysfakcja'
}

# %%
categories = clusters_df.groupby(clusters_df['Cluster'].map(clusters)).agg({'Words': 'sum'}).reset_index()
categories
# Out:
#                      Cluster  \
# 0    Aktualizacje i poprawki
# 1            Błędy i usterki
# 2                    Grafika
# 3                      Humor
# 4              Jakość treści
# 5                      Koszt
# 6              Mechanika gry
# 7           Misje i przygody
# 8          Narracja i fabuła
# 9        Opinie użytkowników
# 10        Produkcja i rozwój
# 11                 Rozgrywka
# 12               Satysfakcja
# 13  Społeczność i współpraca
# 14                     Walka
# 15                  Wyzwania
#
#                                                 Words
# 0   [update, feature, version, release, entry, upg...
# 1                                       [bug, glitch]
# 2   [graphic, visual, video, pixel, color, paint, ...
# 3     [humor, classic, vibe, gem, hint, quirk, charm]
# 4                  [content, quality, value, product]
# 5   [price, cost, worth, waste, purchase, payment,...
# 6    [way, pace, level, point, number, class, rating]
# 7   [colony, quest, colonist, empire, journey, voy...
# 8   [character, hero, genre, plot, figure, episode...
# 9                         [review, note, view, guide]
# 10  [factory, base, unit, platformer, location, pr...
# 11  [gameplay, gamer, gaming, rng, bonus, replay, ...
# 12  [love, choice, voice, wish, reward, hope, enjo...
# 13  [experience, community, work, environment, res...
# 14  [enemy, fight, battle, combat, campaign, effor...
# 15  [challenge, problem, effect, reason, possibili...

# %%
categories["Words"][15]
# Out:
# ['challenge',
#  'problem',
#  'effect',
#  'reason',
#  'possibility',
#  'question',
#  'change',
#  'chance',
#  'balance',
#  'future',
#  'potential',
#  'purpose',
#  'factor']

# %% [markdown]
# ## Similarity

# %%
words = word_counts["word"].to_list()
nlp = spacy.load('en_core_web_md')
tokens = [nlp(word) for word in words]

# %%
categories['WordTokens'] = categories['Words'].apply(lambda words: [nlp(word) for word in words])
all_cluster_words = set(word for words in categories['Words'] for word in words)

for token in tokens:
    max_similarity = 0
    best_cluster = None
    
    for idx, row in categories.iterrows():
        for word_token in row['WordTokens']:
            similarity = token.similarity(word_token)
            if similarity > max_similarity:
                max_similarity = similarity
                best_cluster = idx
    
    if max_similarity > 0.75 and str(token) not in all_cluster_words:
        categories.at[best_cluster, 'Words'].append(str(token))
        all_cluster_words.add(token)

categories.drop(columns=['WordTokens'], inplace=True)
print(categories)
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_4388\1993302271.py:10: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = token.similarity(word_token)
#                      Cluster  \
# 0    Aktualizacje i poprawki
# 1            Błędy i usterki
# 2                    Grafika
# 3                      Humor
# 4              Jakość treści
# 5                      Koszt
# 6              Mechanika gry
# 7           Misje i przygody
# 8          Narracja i fabuła
# 9        Opinie użytkowników
# 10        Produkcja i rozwój
# 11                 Rozgrywka
# 12               Satysfakcja
# 13  Społeczność i współpraca
# 14                     Walka
# 15                  Wyzwania
#
#                                                 Words
# 0   [update, feature, version, release, entry, upg...
# 1                                       [bug, glitch]
# 2   [graphic, visual, video, pixel, color, paint, ...
# 3   [humor, classic, vibe, gem, hint, quirk, charm...
# 4           [content, quality, value, product, qualm]
# 5   [price, cost, worth, waste, purchase, payment,...
# 6   [way, pace, level, point, number, class, ratin...
# 7   [colony, quest, colonist, empire, journey, voy...
# 8   [character, hero, genre, plot, figure, episode...
# 9    [review, note, view, guide, reviewer, viewpoint]
# 10  [factory, base, unit, platformer, location, pr...
# 11  [gameplay, gamer, gaming, rng, bonus, replay, ...
# 12  [love, choice, voice, wish, reward, hope, enjo...
# 13  [experience, community, work, environment, res...
# 14  [enemy, fight, battle, combat, campaign, effor...
# 15  [challenge, problem, effect, reason, possibili...

# %%
categories["Words"][15]
# Out:
# ['challenge',
#  'problem',
#  'effect',
#  'reason',
#  'possibility',
#  'question',
#  'change',
#  'chance',
#  'balance',
#  'future',
#  'potential',
#  'purpose',
#  'factor',
#  'consequence',
#  'probability',
#  'changing',
#  'challenging',
#  'expereince',
#  'challange',
#  'necessity',
#  'profitability',
#  'balancing',
#  'propensity',
#  'questing',
#  'effectiveness',
#  'prot']

# %% [markdown]
# # Feature-opinion-category list

# %%
for i in df["feature"]:
    for j in i:
        for index, row in categories.iterrows():
            if j["feature"] in row["Words"]:
                j["category"] = row["Cluster"]

# %% [markdown]
# # Sentiment

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\marty\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
for i in df["feature"]:
    for j in i:
        expr = j["opinion"] #+ " " + j["feature"] 
        scores = analyzer.polarity_scores(expr)
        j["sentiment"] = scores["compound"]

# %% [markdown]
# ### Sentiment for each feature category for different genres

# %%
category_genre_sentiment_count = {}

for genre, features in zip(df["genre"], df["feature"]):

    if genre not in category_genre_sentiment_count:
        category_genre_sentiment_count[genre] = defaultdict(lambda: {"positive": 0, "negative": 0, "neutral": 0})
    
    for feature in features:
        if "category" in feature and "sentiment" in feature:
            category = feature["category"]
            sentiment = feature["sentiment"]
            
            if category not in category_genre_sentiment_count[genre]:
                category_genre_sentiment_count[genre][category] = {"positive": 0, "negative": 0, "neutral": 0}
            
            if sentiment > 0:
                category_genre_sentiment_count[genre][category]["positive"] += 1
            elif sentiment < 0:
                category_genre_sentiment_count[genre][category]["negative"] += 1
            else:
                category_genre_sentiment_count[genre][category]["neutral"] += 1
                
    for category in category_genre_sentiment_count[genre]:
        total = sum(category_genre_sentiment_count[genre][category].values())
        for sentiment in category_genre_sentiment_count[genre][category]:
            category_genre_sentiment_count[genre][category][sentiment] = \
                (category_genre_sentiment_count[genre][category][sentiment] / total) * 100
    
    category_genre_sentiment_count[genre] = dict(category_genre_sentiment_count[genre])

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle("Proporcje nastrojów w poszczególnych kategoriach", fontsize=16)

def plot_genre_sentiments(ax, genre, title):
    categories = list(category_genre_sentiment_count[genre].keys())
    positive = np.array([category_genre_sentiment_count[genre][cat]["positive"] for cat in categories])
    negative = np.array([category_genre_sentiment_count[genre][cat]["negative"] for cat in categories])
    neutral = np.array([category_genre_sentiment_count[genre][cat]["neutral"] for cat in categories])

    ax.bar(categories, positive, color="#96d800", label="Positive", width=0.5)
    ax.bar(categories, neutral, bottom=positive, color="#fce655", label="Neutral", width=0.5)
    ax.bar(categories, negative, bottom=neutral + positive, color="#b20918", label="Negative", width=0.5)

    ax.tick_params(axis="x", rotation=90)
    ax.set_title(title, fontsize=12)
    ax.grid(True, which='major', axis='y', linestyle='--', alpha=0.5)

plot_genre_sentiments(axs[0, 0], "R", "RPG")
plot_genre_sentiments(axs[0, 1], "A", "Akcja")
plot_genre_sentiments(axs[1, 0], "P", "Puzzle")
plot_genre_sentiments(axs[1, 1], "S", "Strategia")

plt.tight_layout(rect=[0, 0, 1, 0.95])

fig.legend(["Pozytywne", "Neutralne", "Negatywne"], loc="upper center", bbox_to_anchor=(0.5, 0.95), ncol=3, fontsize=11)

plt.show()

# %% [markdown]
# ### Feature category significance analysis for different genres

# %%
genre_category = {}
for genre, features in zip(df["genre"], df["feature"]):
    if genre not in genre_category:
        genre_category[genre] = []
    for feature in features:
        if "category" in feature:
            genre_category[genre].append(feature["category"])

# %%
genre_category_counts = {genre: pd.Series(categories).value_counts() for genre, categories in genre_category.items()}

# %%
genre_category_counts = pd.DataFrame(genre_category_counts)

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 11.5))
fig.suptitle("Liczba cech według gatunku z podziałem na kategorie", fontsize=16)

values = genre_category_counts["R"].sort_values(ascending=False)[1:].keys()
cmap = mpl.colormaps["turbo"]
colors = cmap(np.linspace(0, 1, len(values)))
value_color_dict = dict(zip(values, colors))

def plot_genre_category_count(ax, genre, title):
    categories = list(genre_category_counts[genre].sort_values(ascending=False)[1:].keys())
    counts = list(genre_category_counts[genre].sort_values(ascending=False)[1:])
    bars = ax.bar(categories, counts, color=[value_color_dict[category] for category in categories])
    ax.set_title(title, fontsize=12)
    ax.set_ylabel("Liczba", fontsize=10)
    ax.tick_params(axis="x", rotation= 90, labelsize=10)
    ax.grid(True, which='major', axis='y', linestyle='-', alpha=0.5)
    
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval +0.5 , round(yval, 1), ha='center', va='bottom', fontsize=8)

plot_genre_category_count(axs[0, 0], "R", "RPG")
plot_genre_category_count(axs[0, 1], "A", "Akcja")
plot_genre_category_count(axs[1, 0], "P", "Puzzle")
plot_genre_category_count(axs[1, 1], "S", "Strategia")

plt.tight_layout(rect=[0, 0, 1, 0.99])

plt.show()

# %%
def pie_data(counts, categories, top_n=6):
    sorted_indices = sorted(range(len(counts)), key=lambda i: counts[i], reverse=True)
    sorted_counts = [counts[i] for i in sorted_indices]
    sorted_categories = [categories[i] for i in sorted_indices]

    filtered_counts = sorted_counts[:top_n]
    filtered_labels = sorted_categories[:top_n]
    others_count = sum(sorted_counts[top_n:])
    
    if others_count > 0:
        filtered_counts.append(others_count)
        filtered_labels.append("Inne")
    
    return filtered_counts, filtered_labels

fig, axs = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle("Procentowy udział cech według gatunku", fontsize=20)

def plot_genre_category_count_pie(ax, genre, title):
    categories = list(genre_category_counts[genre].sort_values(ascending=False)[1:].keys())
    counts = list(genre_category_counts[genre].sort_values(ascending=False)[1:])
    filtered_counts, filtered_labels = pie_data(counts, categories)
    colors = [value_color_dict.get(label, "#0097b8") for label in filtered_labels]
    ax.pie(filtered_counts, labels=filtered_labels, colors=colors, autopct="%1.1f%%")
    ax.set_title(title, size=16)

plot_genre_category_count_pie(axs[0,0], "R", "RPG")
plot_genre_category_count_pie(axs[0,1], "A", "Akcja")
plot_genre_category_count_pie(axs[1,0], "P", "Puzzle")
plot_genre_category_count_pie(axs[1,1], "S", "Strategia")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sentiment towards each aspect in aspect category

# %% [markdown]
# #### Feature: opinion, sentiment, catergory

# %%
sentiment_aspect = {}
for genre, features in zip(df["genre"], df["feature"]):
    if genre not in sentiment_aspect:
        sentiment_aspect[genre] = {}
    
    for feature in features:
        if "category" in feature and "sentiment" in feature and "feature" in feature:
            category = feature["category"]
            sentiment = feature["sentiment"]
            feature = feature["feature"]
            if category not in sentiment_aspect[genre]:
                sentiment_aspect[genre][category] = {}
            if feature not in sentiment_aspect[genre][category]:
                sentiment_aspect[genre][category][feature] = []
            sentiment_aspect[genre][category][feature].append(sentiment)

# %% [markdown]
# #### Mean, median, standard deviation, variance, minimum, maximum

# %%
data = []

for i,j in sentiment_aspect.items():
    for k, l in j.items():
        for m, n in l.items():
            data.append([i, k, m, len(n), np.mean(n), np.median(n), np.var(n), np.std(n), np.min(n), np.max(n)])

sentiment_aspect_df = pd.DataFrame(data, columns=["Genre", "Category", "Feature", "Count", "Mean", "Median", "Variance", "StdDev", "Min", "Max"])

sentiment_aspect_df
# Out:
#     Genre       Category   Feature  Count      Mean  Median  Variance  \
# 0       R      Rozgrywka      game   1914  0.289913  0.4404  0.102521
# 1       R      Rozgrywka  gameplay    147  0.170112  0.0000  0.139995
# 2       R      Rozgrywka       cue     12  0.029650  0.0000  0.062390
# 3       R      Rozgrywka     gamer      6  0.000000  0.0000  0.000000
# 4       R      Rozgrywka    replay      2  0.449600  0.4496  0.000085
# ..    ...            ...       ...    ...       ...     ...       ...
# 715     S  Jakość treści   content     91  0.123224  0.0000  0.073775
# 716     S  Jakość treści   quality     19 -0.010247  0.0000  0.032233
# 717     S  Jakość treści     value     17  0.225265  0.2263  0.056113
# 718     S  Jakość treści     qualm      3  0.146800  0.0000  0.043100
# 719     S  Jakość treści   product      7  0.184414  0.0000  0.054711
#
#        StdDev     Min     Max
# 0    0.320188 -0.6597  0.8020
# 1    0.374159 -0.5423  0.7269
# 2    0.249780 -0.5423  0.6249
# 3    0.000000  0.0000  0.0000
# 4    0.009200  0.4404  0.4588
# ..        ...     ...     ...
# 715  0.271615 -0.5423  0.6249
# 716  0.179534 -0.2732  0.6249
# 717  0.236883  0.0000  0.6369
# 718  0.207607  0.0000  0.4404
# 719  0.233903  0.0000  0.5719
#
# [720 rows x 10 columns]

# %% [markdown]
# #### Frequency

# %% [raw]
# count_description = sentiment_aspect_df["Count"].describe()
# print(count_description)

# %% [raw]
# sentiment_aspect_df["Count"].quantile(0.7)

# %% [raw]
# sentiment_aspect_df["Log"] = sentiment_aspect_df["Count"].apply(lambda x: np.log(x+1))
#
# plt.figure(figsize=(12, 6))
# plt.hist(sentiment_aspect_df["Log"], bins=50, edgecolor="black", alpha=1)
# plt.title("Log Feature Counts")
# plt.xlabel("Log Count")
# plt.ylabel("Features Count")
# plt.show()

# %% [raw]
# log_thresh = sentiment_aspect_df["Log Count"].quantile([0,0.25, 0.5, 0.75, 0.90, 0.95, 0.99])
# print(log_thresh)

# %% [raw]
# sentiment_aspect_df[sentiment_aspect_df["Log Count"] > 2]

# %% [markdown]
# #### Most popular words in each category in genre

# %%
sentiment_aspect_df_sort= sentiment_aspect_df.sort_values(by="Count", ascending=False)
top_10_common = sentiment_aspect_df_sort.groupby("Genre", group_keys=False).apply(lambda x: x.head(10))
top_10_common
# Out:
#     Genre                  Category     Feature  Count      Mean   Median  \
# 164     A                 Rozgrywka        game   2669  0.265004  0.44040
# 172     A  Społeczność i współpraca  experience    273  0.171037  0.00000
# 166     A                 Rozgrywka    gameplay    209  0.147220  0.00000
# 276     A                     Koszt       price    207  0.189603  0.22630
# 218     A             Mechanika gry         way    192  0.209522  0.00000
# 296     A        Produkcja i rozwój     factory    128  0.085475  0.00000
# 331     A           Błędy i usterki         bug     87 -0.051800  0.00000
# 219     A             Mechanika gry       level     84  0.124308  0.00000
# 262     A       Opinie użytkowników      review     82  0.082230  0.00000
# 322     A                   Grafika     graphic     82  0.296185  0.44040
# 333     P                 Rozgrywka        game   1799  0.266264  0.44040
# 335     P                 Rozgrywka    gameplay    197  0.154856  0.00000
# 344     P  Społeczność i współpraca  experience    186  0.157509  0.00000
# 383     P             Mechanika gry         way    156  0.203601  0.00000
# 427     P                     Koszt       price     96  0.232865  0.22630
# 442     P         Narracja i fabuła   character     66  0.235673  0.00000
# 472     P             Jakość treści     content     52  0.078917  0.00000
# 382     P             Mechanika gry       level     47  0.133855  0.00000
# 362     P       Opinie użytkowników      review     42 -0.036195  0.00000
# 476     P   Aktualizacje i poprawki      update     41  0.091122  0.00000
# 0       R                 Rozgrywka        game   1914  0.289913  0.44040
# 84      R               Satysfakcja        love    341 -0.226078  0.00000
# 111     R  Społeczność i współpraca  experience    172  0.229687  0.07655
# 1       R                 Rozgrywka    gameplay    147  0.170112  0.00000
# 48      R         Narracja i fabuła   character    143  0.248673  0.15310
# 37      R             Mechanika gry         way    131  0.220562  0.31820
# 92      R                     Koszt       price     65  0.235823  0.22630
# 39      R             Mechanika gry       level     46  0.064272  0.00000
# 24      R                  Wyzwania   challenge     38  0.164971  0.00000
# 101     R                   Grafika     graphic     38  0.286621  0.44040
# 512     S                 Rozgrywka        game   3026  0.227712  0.15310
# 568     S             Mechanika gry         way    260  0.138947  0.00000
# 648     S  Społeczność i współpraca  experience    236  0.206847  0.00000
# 513     S                 Rozgrywka    gameplay    231  0.139409  0.00000
# 636     S                     Koszt       price    179  0.162679  0.00000
# 597     S         Narracja i fabuła   character    171  0.168781  0.00000
# 712     S          Misje i przygody      colony    146  0.132835  0.00000
# 566     S             Mechanika gry       level    117  0.032750  0.00000
# 682     S       Opinie użytkowników      review    109 -0.024739  0.00000
# 584     S                   Grafika     graphic     99  0.194473  0.00000
#
#      Variance    StdDev     Min     Max
# 164  0.106782  0.326775 -0.6249  0.8074
# 172  0.105222  0.324379 -0.6249  0.7845
# 166  0.156314  0.395366 -0.5423  0.6369
# 276  0.073508  0.271124 -0.5719  0.6369
# 218  0.095509  0.309046 -0.5849  0.7579
# 296  0.058899  0.242690 -0.6597  0.6705
# 331  0.115684  0.340123 -0.5719  0.7579
# 219  0.062707  0.250414 -0.4847  0.6369
# 262  0.165174  0.406416 -0.5719  0.5574
# 322  0.093014  0.304982 -0.5423  0.6369
# 333  0.107460  0.327811 -0.6249  0.8176
# 335  0.146124  0.382262 -0.6249  0.7579
# 344  0.094499  0.307406 -0.6249  0.8020
# 383  0.097896  0.312883 -0.6249  0.6369
# 427  0.045283  0.212799 -0.3612  0.6249
# 442  0.085104  0.291725 -0.4767  0.7351
# 472  0.073140  0.270444 -0.5574  0.6369
# 382  0.076919  0.277343 -0.4404  0.7269
# 362  0.185768  0.431008 -0.6249  0.6369
# 476  0.057738  0.240288 -0.5719  0.6249
# 0    0.102521  0.320188 -0.6597  0.8020
# 84   0.098181  0.313338 -0.5719  0.6369
# 111  0.097035  0.311505 -0.5423  0.7579
# 1    0.139995  0.374159 -0.5423  0.7269
# 48   0.087592  0.295959 -0.6597  0.7269
# 37   0.121371  0.348384 -0.6597  0.6369
# 92   0.055647  0.235895 -0.5256  0.6249
# 39   0.061578  0.248149 -0.5423  0.7269
# 24   0.071079  0.266606 -0.3400  0.6249
# 101  0.148919  0.385900 -0.6249  0.7351
# 512  0.111386  0.333745 -0.7579  0.8074
# 568  0.107815  0.328353 -0.6597  0.7717
# 648  0.097331  0.311980 -0.5849  0.8074
# 513  0.154856  0.393518 -0.5719  0.6369
# 636  0.059338  0.243595 -0.6249  0.6249
# 597  0.092406  0.303983 -0.6597  0.6369
# 712  0.102646  0.320385 -0.6597  0.6369
# 566  0.050640  0.225033 -0.5719  0.6249
# 682  0.176491  0.420109 -0.5719  0.7096
# 584  0.097492  0.312238 -0.5423  0.7269

# %% [markdown]
# #### higher variance vs sentiment

# %%
plt.scatter(sentiment_aspect_df["Mean"], sentiment_aspect_df["Variance"], alpha = 0.7)
plt.title("Sentiment mean vs. Variance")
plt.xlabel("Sentiment mean")
plt.ylabel("Variance")
plt.show()

# %%
corr_mean_variance = sentiment_aspect_df[["Mean", "Variance"]].corr().iloc[0, 1]
corr_mean_variance
# Out:
# 0.18323278636721493

# %% [markdown]
# ### Sentiment towards category

# %%
sentiment_aspect_category = {}
for genre, features in zip(df["genre"], df["feature"]):
    if genre not in sentiment_aspect_category:
        sentiment_aspect_category[genre] = {}
    
    for feature in features:
        if "category" in feature and "sentiment" in feature:
            category = feature["category"]
            sentiment = feature["sentiment"]
            if category not in sentiment_aspect_category[genre]:
                sentiment_aspect_category[genre][category] = []
            sentiment_aspect_category[genre][category].append(sentiment)

# %%
sentiment_category_data = []

for i,j in sentiment_aspect_category.items():
    for k, l in j.items():
        sentiment_category_data.append([i, k, len(l), np.mean(l), np.median(l), np.var(l), np.std(l), np.min(l), np.max(l)])

sentiment_category_df = pd.DataFrame(sentiment_category_data, columns=["Genre", "Category", "Count", "Mean", "Median", "Variance", "StdDev", "Min", "Max"])

sentiment_category_df
# Out:
#    Genre                 Category  Count      Mean  Median  Variance  \
# 0      R                Rozgrywka   2091  0.278110  0.4404  0.106049
# 1      R                    Walka    139  0.137246  0.0000  0.078923
# 2      R                 Wyzwania    110  0.119441  0.0000  0.065433
# 3      R            Mechanika gry    223  0.185285  0.0000  0.103020
# 4      R      Opinie użytkowników     45  0.088573  0.0000  0.110558
# ..   ...                      ...    ...       ...     ...       ...
# 59     S              Satysfakcja    178  0.137303  0.0000  0.099697
# 60     S  Aktualizacje i poprawki    256  0.107303  0.0000  0.055673
# 61     S          Błędy i usterki     39  0.073410  0.0000  0.062360
# 62     S         Misje i przygody    300  0.102452  0.0000  0.078570
# 63     S            Jakość treści    137  0.121018  0.0000  0.068137
#
#       StdDev     Min     Max
# 0   0.325652 -0.6597  0.8020
# 1   0.280932 -0.6597  0.6369
# 2   0.255798 -0.6249  0.6369
# 3   0.320967 -0.6597  0.7269
# 4   0.332503 -0.5719  0.6249
# ..       ...     ...     ...
# 59  0.315748 -0.5719  0.7579
# 60  0.235950 -0.5719  0.6705
# 61  0.249720 -0.5719  0.7579
# 62  0.280303 -0.6597  0.6369
# 63  0.261031 -0.5423  0.6369
#
# [64 rows x 9 columns]

# %%
sentiment_category_pivot = sentiment_category_df.pivot("Genre", "Category", "Mean")
plt.figure(figsize=(12, 6))
sns.heatmap(round(sentiment_category_pivot, 2), annot=True, cmap="PiYG")
plt.title("Average Sentiment Scores by Category and Genre")
plt.xlabel("Kategoria")
plt.ylabel("Gatunek")
plt.xticks(rotation=90)
plt.yticks()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_4388\1338126980.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sentiment_category_pivot = sentiment_category_df.pivot("Genre", "Category", "Mean")

# %% [raw]
# def plot_sentiment_genre(data):
#     plt.figure(figsize=(12, 6))
#     sns.barplot(x="Category", y="Mean", data=data, palette="coolwarm")
#     plt.title("Highest Sentiments by Category")
#     plt.xlabel("Category")
#     plt.ylabel("Sentiment Score")
#     plt.xticks(rotation=45, ha="right")
#     plt.tight_layout()
#     plt.show()
# plot_sentiment_genre(sentiment_category_df[sentiment_category_df["Genre"] == "R"])

# %%
sentiment_category_pivot = sentiment_category_df.pivot(index="Genre", columns="Category", values="Mean").reset_index()

# %%
df_plot = sentiment_category_pivot.melt(id_vars="Genre", var_name="Category", value_name="Sentiment")

plt.figure(figsize=(14, 8))
sns.barplot(x="Category", y="Sentiment", hue="Genre", data=df_plot, palette="magma")

plt.title("Sentiment Scores by Category and Genre")
plt.xlabel("Category")
plt.ylabel("Sentiment")
plt.xticks(rotation=90)
plt.legend(title="Genre")

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle("xyz", fontsize=20)

def boxplot_category(ax, genre, title):
    labels, data = [*zip(*sentiment_aspect_category[genre].items())]  
    labels, data = sentiment_aspect_category[genre].keys(), sentiment_aspect_category[genre].values()
    ax.boxplot(data)
    ax.set_xticklabels(labels)
    ax.tick_params(axis="x", rotation=90)
    ax.set_title(title)

boxplot_category(axs[0,0], "R", "RPG")
boxplot_category(axs[0,1], "A", "Action")
boxplot_category(axs[1,0], "P", "Puzzle")
boxplot_category(axs[1,1], "S", "Strategy")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Polarized categories

# %%
sentiment_category_df.sort_values(by="StdDev", ascending=False).head(10)
# Out:
#    Genre             Category  Count      Mean  Median  Variance    StdDev  \
# 34     P  Opinie użytkowników     59 -0.014320  0.0000  0.167344  0.409078
# 24     A  Opinie użytkowników    105  0.096888  0.0000  0.146299  0.382490
# 58     S  Opinie użytkowników    149  0.010225  0.0000  0.145754  0.381777
# 6      R          Satysfakcja    406 -0.163143  0.0000  0.117518  0.342809
# 48     S            Rozgrywka   3340  0.216941  0.0000  0.115261  0.339501
# 15     R      Błędy i usterki      7  0.067143  0.0000  0.111936  0.334569
# 31     A      Błędy i usterki     91 -0.046521  0.0000  0.111820  0.334395
# 32     P            Rozgrywka   2040  0.252728  0.4215  0.111552  0.333995
# 8      R              Grafika     95  0.239273  0.3182  0.111461  0.333858
# 17     A            Rozgrywka   2913  0.254343  0.4215  0.110855  0.332948
#
#        Min     Max
# 34 -0.6249  0.6369
# 24 -0.5719  0.6369
# 58 -0.5719  0.7096
# 6  -0.5719  0.7269
# 48 -0.7579  0.8074
# 15 -0.5423  0.5719
# 31 -0.5719  0.7579
# 32 -0.6249  0.8176
# 8  -0.6249  0.7351
# 17 -0.6249  0.8074

# %% [markdown]
# ## Game time and sentiment

# %%
category_time = {}
for playtime, features in zip(df["playtime_at_review"], df["feature"]):        
    for feature in features:
        if "category" in feature and "sentiment" in feature:
            category = feature["category"]
            sentiment = feature["sentiment"]
            if category not in category_time:
                category_time[category] = []

            category_time[category].append((sentiment, playtime))

# %%
playtime_sentiment_correlation = {}
for category, sentiments_playtimes in category_time.items():
    sentiments = [sentiment for sentiment, _ in sentiments_playtimes]
    playtimes = [playtime for _, playtime in sentiments_playtimes]
    if sentiments and playtimes and len(sentiments) > 1:  
        correlation, _ = pearsonr(playtimes, sentiments)
        playtime_sentiment_correlation[category] = correlation

# %%
playtime_sentiment_correlation_df = pd.DataFrame(list(playtime_sentiment_correlation.items()), 
    columns=["Category", "Korelacja"]).set_index("Category").T

# %%
plt.figure(figsize=(10, 4))
sns.heatmap(round(playtime_sentiment_correlation_df, 2), annot=True, cmap="PiYG", vmin=-1, vmax=1)

plt.title("Korelacja między wydźwiękiem a czasem gry")
plt.xlabel("Kategoria")
plt.xticks(rotation=90, ha="right")
plt.yticks()
plt.tight_layout()
plt.show()

# %%
plot_data = []
for voted_up, votes_data in playtime_sentiment_correlation.items():
    for category, sentiments in votes_data.items():
            for sentiment in sentiments:
                plot_data.append({"Voted_up": voted_up, "Category": category, "Sentiment": sentiment})

df_plot = pd.DataFrame(plot_data)

def boxplot_category():
    plt.figure(figsize=(14, 8))
    sns.boxplot(x="Category", y="Sentiment", hue="Voted_up", data=df_plot)
    plt.tick_params(axis="x", rotation=90)
    plt.title("xyz")
    plt.tight_layout()
    plt.show()

boxplot_category()

# %% [markdown]
# ## Adj for the word "game"

# %%
genre_game_adj = {}
for genre, features in zip(df["genre"], df["feature"]):
    if genre not in genre_game_adj:
        genre_game_adj[genre] = []
        
    for feature in features:
        if feature["feature"] == "game" and "sentiment" in feature:
            opinion = feature["opinion"]
            sentiment = feature["sentiment"]
            genre_game_adj[genre].append((opinion, sentiment))

# %%
sentiments_by_genre = [np.array([sentiment for _, sentiment in values]) for values in genre_game_adj.values()]
genres = list(genre_game_adj.keys())

for genre, sentiments in zip(genres, sentiments_by_genre):
    stat, p_value = stats.shapiro(sentiments)
    print(f"Test Shapiro-Wilka dla gatunku {genre}:")
    print("Statystyka W:", stat)
    print("Wartość p:", p_value)
# Out:
# Test Shapiro-Wilka dla gatunku R:
# Statystyka W: 0.8552963066008451
# Wartość p: 9.57362426003584e-39
# Test Shapiro-Wilka dla gatunku A:
# Statystyka W: 0.8642518540086882
# Wartość p: 3.2184162881676854e-43
# Test Shapiro-Wilka dla gatunku P:
# Statystyka W: 0.8624504675425589
# Wartość p: 4.646152499370099e-37
# Test Shapiro-Wilka dla gatunku S:
# Statystyka W: 0.868309148926333
# Wartość p: 7.021232995820495e-45

# %%
sentiments_by_genre = [np.array([sentiment for _, sentiment in values]) for values in genre_game_adj.values()]

stat, p_value = stats.kruskal(*sentiments_by_genre)

print("Statystyka H", stat)
print("Wartość p", p_value)
# Out:
# Statystyka H 46.45258382003662
# Wartość p 4.544216809271996e-10

# %%
sentiments_df = pd.DataFrame({
    "Sentiment": [sentiment for sentiments in genre_game_adj.values() for _, sentiment in sentiments],
    "Genre": [genre for genre, sentiments in genre_game_adj.items() for _ in sentiments]})

# %%
dunn_test = sp.posthoc_dunn(sentiments_df, val_col="Sentiment", group_col="Genre")
print(dunn_test)
# Out:
#           A         P             R             S
# A  1.000000  0.673148  1.600215e-03  1.742742e-04
# P  0.673148  1.000000  1.289401e-02  1.566476e-04
# R  0.001600  0.012894  1.000000e+00  2.938980e-11
# S  0.000174  0.000157  2.938980e-11  1.000000e+00

# %%
plt.figure(figsize=(10, 4))
sns.heatmap(dunn_test, annot=True, cmap="PuRd", fmt=".2f")

plt.title("Dunn Test")
plt.xlabel('Gatunek')
plt.ylabel('Gatunek')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Boxplot jeszcze

# %% [markdown]
# #### Number of positive, negative, and neutral sentiments

# %%
def sentiment_analysis(opinions):
    positive, neutral, negative = 0, 0, 0
    for opinion, sentiment in opinions:
        if sentiment > 0:
            positive += 1
        elif sentiment < 0:
            negative += 1
        else:
            neutral += 1
    return positive, neutral, negative

sentiment_distribution = {genre: sentiment_analysis(opinions) for genre, opinions in genre_game_adj.items()}

# %%
plt.figure(figsize=(6,8))

genres = list(sentiment_distribution.keys())
positive = np.array([sentiment_distribution[genre][0] for genre in genres])
neutral = np.array([sentiment_distribution[genre][1] for genre in genres])
negative = np.array([sentiment_distribution[genre][2] for genre in genres])

plt.bar(genres, positive, color="#96d800", label="Positive")
plt.bar(genres, neutral, bottom=positive, color="#fce655", label="Neutral")
plt.bar(genres, negative, bottom=neutral + positive, color="#b20918", label="Negative")

plt.tick_params(axis="x", rotation=90)
plt.xlabel("Gatunek")
plt.ylabel("Liczba recenzji")
plt.title('Sentiment distribution for the word "game" by genre')
plt.legend()

for i, genre in enumerate(genres):
    pos_value = sentiment_distribution[genre][0]
    neu_value = sentiment_distribution[genre][1]
    neg_value = sentiment_distribution[genre][2]
    
    plt.annotate(pos_value, (i, pos_value/2), ha='center', color='black')
    plt.annotate(neu_value, (i, pos_value + neu_value/2), ha='center', color='black')
    plt.annotate(neg_value, (i, pos_value + neu_value + neg_value/2.7), ha = "center", color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Most frequent opinions

# %%
common_opinions = {genre: Counter([opinion for opinion, _ in opinions]).most_common(5)
                   for genre, opinions in genre_game_adj.items()}

common_opinions
# Out:
# {'R': [('best', 262),
#   ('good', 142),
#   ('great', 102),
#   ('fun', 58),
#   ('favorite', 55)],
#  'A': [('good', 233),
#   ('best', 211),
#   ('great', 195),
#   ('fun', 99),
#   ('first', 52)],
#  'P': [('best', 196),
#   ('good', 165),
#   ('great', 105),
#   ('first', 56),
#   ('fun', 52)],
#  'S': [('best', 230),
#   ('great', 228),
#   ('good', 226),
#   ('first', 67),
#   ('fun', 60)]}

# %% [markdown]
# #### Opinion Polarity Analysis

# %%
threshold = 0.5
polarized_opinions = { 'positive': {}, 'negative': {} }

for genre, opinions in genre_game_adj.items():
    polarized_opinions['positive'][genre] = []
    polarized_opinions['negative'][genre] = []

    used_opinions = set()

    for opinion, sentiment in opinions:
        if sentiment > threshold and opinion not in used_opinions:
            polarized_opinions['positive'][genre].append((opinion, sentiment))
            used_opinions.add(opinion) 
        elif sentiment < -threshold and opinion not in used_opinions:
            polarized_opinions['negative'][genre].append((opinion, sentiment))
            used_opinions.add(opinion) 

    polarized_opinions['positive'][genre] = sorted(polarized_opinions['positive'][genre], key=lambda x: x[1], reverse=True)[:5]
    polarized_opinions['negative'][genre] = sorted(polarized_opinions['negative'][genre], key=lambda x: x[1], reverse=False)[:5]

for genre in polarized_opinions['positive']:
    print(f"Genre: {genre}")
    print("Top 5 Positive Opinions:")
    for opinion, sentiment in polarized_opinions['positive'][genre]:
        print(f"Opinion: '{opinion}', Sentiment: {sentiment}")
        
    print("Top 5 Negative Opinions:")
    for opinion, sentiment in polarized_opinions['negative'][genre]:
        print(f"Opinion: '{opinion}', Sentiment: {sentiment}")
# Out:
# Genre: R
# Top 5 Positive Opinions:
# Opinion: 'honestly best', Sentiment: 0.802
# Opinion: 'honestly great', Sentiment: 0.7964
# Opinion: 'eagerly best', Sentiment: 0.7783
# Opinion: 'certainly best', Sentiment: 0.765
# Opinion: 'easily best', Sentiment: 0.765
# Top 5 Negative Opinions:
# Opinion: 'evil', Sentiment: -0.6597
# Opinion: 'worst', Sentiment: -0.6249
# Opinion: 'far worst', Sentiment: -0.6249
# Opinion: 'extremely negative', Sentiment: -0.6115
# Opinion: 'violent', Sentiment: -0.5994
# Genre: A
# Top 5 Positive Opinions:
# Opinion: 'pretty great', Sentiment: 0.8074
# Opinion: 'honestly best', Sentiment: 0.802
# Opinion: 'honestly perfect', Sentiment: 0.7717
# Opinion: 'easily best', Sentiment: 0.765
# Opinion: 'pretty fun', Sentiment: 0.7579
# Top 5 Negative Opinions:
# Opinion: 'worst', Sentiment: -0.6249
# Opinion: 'racist', Sentiment: -0.6124
# Opinion: 'horrendous', Sentiment: -0.5859
# Opinion: 'very bad', Sentiment: -0.5849
# Opinion: 'really bad', Sentiment: -0.5849
# Genre: P
# Top 5 Positive Opinions:
# Opinion: 'perfectly fun', Sentiment: 0.8176
# Opinion: 'excellently fun', Sentiment: 0.8126
# Opinion: 'honestly best', Sentiment: 0.802
# Opinion: 'perfectly enjoyable', Sentiment: 0.7964
# Opinion: 'pretty beautiful', Sentiment: 0.7964
# Top 5 Negative Opinions:
# Opinion: 'worst', Sentiment: -0.6249
# Opinion: 'violent', Sentiment: -0.5994
# Opinion: 'very bad', Sentiment: -0.5849
# Opinion: 'horrifying', Sentiment: -0.5719
# Opinion: 'nasty', Sentiment: -0.5574
# Genre: S
# Top 5 Positive Opinions:
# Opinion: 'pretty great', Sentiment: 0.8074
# Opinion: 'perfectly good', Sentiment: 0.7964
# Opinion: 'pretty brilliant', Sentiment: 0.7906
# Opinion: 'easily best', Sentiment: 0.765
# Opinion: 'easily greatest', Sentiment: 0.765
# Top 5 Negative Opinions:
# Opinion: 'horribly wrong', Sentiment: -0.7579
# Opinion: 'very evil', Sentiment: -0.6901
# Opinion: 'evil', Sentiment: -0.6597
# Opinion: 'brutally hard', Sentiment: -0.6597
# Opinion: 'very brutal', Sentiment: -0.659

# %% [markdown]
# #### Wordcloud

# %%
def plot_wordcloud(genre, opinions):
    opinions_text = ' '.join(opinion for opinion, _ in opinions)
    wordcloud = WordCloud(max_font_size = 220,
                max_words = 100,
                width = 1200,
                height = 800,
                background_color = "black",
                colormap='RdPu_r').generate(opinions_text)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.title(f"Word Cloud for Genre {genre}", fontsize=16)
    plt.show()

for genre, opinions in genre_game_adj.items():
    plot_wordcloud(genre, opinions)

# %% [markdown]
# ## Overall opinion and sentiment

# %%
sentiment_voted_up = {}
for votes, features in zip(df["voted_up"], df["feature"]):    
    for feature in features:
        if "category" in feature and "sentiment" in feature:
            category = feature["category"]
            sentiment = feature["sentiment"]
            if votes not in sentiment_voted_up:
                sentiment_voted_up[votes] = {}
            if category not in sentiment_voted_up[votes]:
                sentiment_voted_up[votes][category] = []
            sentiment_voted_up[votes][category].append(sentiment)

# %%
plot_data = []
for voted_up, categories in sentiment_voted_up.items():
    for category, sentiments in categories.items():
        for sentiment in sentiments:
                plot_data.append({"Genre": genre, "Voted_up": voted_up, "Kategoria": category, "Sentyment": sentiment})

df_plot = pd.DataFrame(plot_data)

def boxplot_category():
    plt.figure(figsize=(14, 8))
    sns.boxplot(x="Kategoria", y="Sentyment", hue="Voted_up", data=df_plot)
    plt.tick_params(axis="x", rotation=90)
    plt.tight_layout()
    plt.show()

boxplot_category()

# %%
voted_up_data = []

for voted_up, voted_up_dict in sentiment_voted_up.items():
    for category, category_list in voted_up_dict.items():
            voted_up_data.append([voted_up, category, len(category_list), np.mean(category_list),
                                  np.median(category_list), np.var(category_list), np.std(category_list), 
                                  np.min(category_list), np.max(category_list)])

voted_up_df = pd.DataFrame(voted_up_data, columns=["Voted_up", "Category", "Count", "Mean", "Median", "Variance", "StdDev", "Min", "Max"])

# %% [raw]
# overall_pos = voted_up_df[voted_up_df["Voted_up"] == True]

# %% [raw]
# heatmap_data_pos = overall_pos.pivot_table(index="Category", values="Mean", aggfunc='mean')
#
# plt.figure(figsize=(10, 8))
# sns.heatmap(heatmap_data_pos, annot=True, cmap="coolwarm", cbar=True)
# plt.title("Average Sentiment Scores by Category")
# plt.ylabel("Category")
# plt.xticks(rotation=90)
# plt.yticks(rotation=0)
# plt.tight_layout()
# plt.show()

# %% [raw]
# overall_neg = voted_up_df[voted_up_df["Voted_up"] == False]

# %% [raw]
# heatmap_data_neg = overall_neg.pivot_table(index="Category", values="Mean", aggfunc='mean')
#
# plt.figure(figsize=(10, 8))
# sns.heatmap(heatmap_data_neg, annot=True, cmap="coolwarm", cbar=True)
# plt.title("Average Sentiment Scores by Category")
# plt.ylabel("Category")
# plt.xticks(rotation=90)
# plt.yticks(rotation=0)
# plt.tight_layout()
# plt.show()

# %%
correlation_voted = df_plot.groupby(["Category"]).apply(lambda x: x[["Voted_up", "Sentiment"]].corr().iloc[0, 1]).reset_index(name="Korelacja")

# %%
heatmap_voted = correlation_voted.set_index("Category").T

plt.figure(figsize=(12, 4))
sns.heatmap(round(heatmap_voted, 2), annot=True, cmap="PiYG", cbar=True, vmin=-1, vmax=1)
plt.title("Korelacja między ogólną satysfakcją a wydźwiękiem")
plt.xlabel("Kategoria")
plt.tight_layout()
plt.show()
