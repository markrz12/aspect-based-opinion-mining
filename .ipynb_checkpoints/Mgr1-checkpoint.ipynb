# %%
import pandas as pd
import spacy
import steamreviews
import json
import csv
import os
import glob
import json
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import wordcloud
from wordcloud import WordCloud
import re
import plotly
import seaborn as sns
# Out:
# C:\Users\marty\AppData\Local\Programs\Python\Python311\Lib\site-packages\thinc\compat.py:36: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   hasattr(torch, "has_mps")
# C:\Users\marty\AppData\Local\Programs\Python\Python311\Lib\site-packages\thinc\compat.py:37: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   and torch.has_mps  # type: ignore[attr-defined]

# %% [markdown]
# ## Reviews download
# https://pypi.org/project/steamreviews/

# %% [raw]
# list_of_app_ids = [219150, 1172620, 460950, 262060, 250320, 210970, 620, 736260,
#                    219890, 289070, 427520, 257510, 304430, 400, 394360, 550,
#                    632470, 294100, 646570, 1150690, 1341290, 1515210, 860510]
#
# def get_reviews(list_of_app_ids):
#     request_params = dict()
#     request_params['language'] = 'english'
#     request_params['day_range'] = '365'
#     request_params['filter'] = 'all'
#     for app_id in list_of_app_ids:
#         review_dict, query_count = steamreviews.download_reviews_for_app_id(app_id,chosen_request_params=request_params)
#     return review_dict, query_count
# get_reviews(list_of_app_ids);

# %%
dir_name = "data"
reviews_jsons = glob.glob(f"{dir_name}/*")
reviews_jsons
# Out:
# ['data\\review_1150690.json',
#  'data\\review_1172620.json',
#  'data\\review_1341290.json',
#  'data\\review_1515210.json',
#  'data\\review_210970.json',
#  'data\\review_219150.json',
#  'data\\review_219890.json',
#  'data\\review_250320.json',
#  'data\\review_257510.json',
#  'data\\review_262060.json',
#  'data\\review_289070.json',
#  'data\\review_294100.json',
#  'data\\review_304430.json',
#  'data\\review_394360.json',
#  'data\\review_400.json',
#  'data\\review_427520.json',
#  'data\\review_460950.json',
#  'data\\review_550.json',
#  'data\\review_620.json',
#  'data\\review_632470.json',
#  'data\\review_646570.json',
#  'data\\review_736260.json',
#  'data\\review_860510.json']

# %%
title_dict = {"219150": "Hotline Miami",
              "1172620" : "Sea of Thieves",
              "460950" : "Katana ZERO",
              "262060" : "Darkest Dungeon",
              "250320" : "The Wolf Among Us",
              "210970" : "The Witness",
              "620" : "Portal 2",
              "736260" : "Baba Is You",
              "219890" : "Antichamber",
              "289070" : "Sid Meier's Civilization VI",
              "427520" : "Factorio",
              "257510" : "The Talos Principle",
             "304430" : "INSIDE",
             "400" : "Portal",
             "394360" : "Hearts of Iron IV",
             "632470" : "Disco Elysium",
             "294100" : "RimWorld",
              "646570" : "Slay the Spire",
              "1150690" : "Omori",
              "1341290" : "We Were Here Forever",
              "1515210" : "The Past Within",
              "860510" : "Little Nightmares II",
              "550" : "Left 4 Dead 2"}

# %%
genre_dict = {"219150": "A",
              "1172620" : "A",
              "460950" : "A",
              "262060" : "R",
              "250320" : "R",
              "210970" : "P",
              "620" : "P",
              "736260" : "P",
              "219890" : "P",
              "289070" : "S",
              "427520" : "S",
              "257510" : "P",
              "304430" : "P",
             "400" : "P",
             "394360" : "S",
             "632470" : "R",
             "294100" : "S",
             "646570" : "R",
             "1150690" : "R",
             "1341290" : "P",
             "1515210" : "P",
             "860510" : "P",
             "550" : "A"}

# %%
data_list = []
for i in reviews_jsons:
    with open(i, encoding = "utf-8") as json_file:
        json_data = json.load(json_file)
        reviews = json_data['reviews']
        file_name = json_file.name.split('.')[0].split('_')[1]
        for key in reviews.keys():
            data_list.append([title_dict.get(file_name),genre_dict.get(file_name),reviews[key]['author']['steamid'], reviews[key]['votes_up'], 
                          reviews[key]['review'], reviews[key]['weighted_vote_score'], reviews[key]['voted_up'],
                          reviews[key]['author']['num_games_owned'], reviews[key]['author']['playtime_at_review'],
                          reviews[key]['author']['num_reviews'], 
                          reviews[key]["timestamp_created"] ])
df = pd.DataFrame(data_list, columns = ["title", "genre","steamid", "votes_up", "review", "weighted_vote_score", "voted_up",
                                        "num_games_owned", "playtime_at_review", "num_reviews", "timestamp_created"])

# %% [markdown]
# ## Wykresy

# %%
value_counts_title = df["title"].value_counts()
genre_colors = {"A": "mistyrose", "R": "palevioletred", "P": "thistle", "S": "pink"}
df['color'] = df['genre'].map(genre_colors)
colors = [df.loc[df['title'] == title]['color'].iloc[0] for title in value_counts_title.index]

plt.figure(figsize=(12, 6))
x = value_counts_title.plot(kind = "bar", color = colors)
plt.ylabel("Ilość recenzji")
plt.xticks(rotation = 90)
for i, count in enumerate(value_counts_title):
    x.text(i, count, count, va = "bottom", ha = "center")

plt.show()

# %%
value_counts_genre = df["genre"].value_counts()
colors = ["pink", "mistyrose", "palevioletred", "thistle"]
x = plt.pie(value_counts_genre, labels = value_counts_genre.index, colors=colors, autopct='%1.2f%%')
plt.show()

# %%
value_counts_recommendation_genre = df.groupby('genre').voted_up.value_counts().unstack(0)
colors = ["pink", "mistyrose", "palevioletred", "thistle"]
plt.figure(figsize=(12, 6))
x = value_counts_recommendation_genre.plot(kind = "bar", color = colors, mark_right = True)
plt.ylabel("Ilość recenzji")
plt.xlabel("Rekomendacje")
plt.show()

# %%
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 
print(percentage_pos)
print(percentage_neg)
# Out:
# genre
# A    88.619463
# P    96.954239
# R    91.465953
# S    85.354180
# dtype: float64
# genre
# A    11.380537
# P     3.045761
# R     8.534047
# S    14.645820
# dtype: float64

# %%
df.sample(frac=0.3).head()
# Out:
#                              title genre            steamid  votes_up  \
# 21078                     Factorio     S  76561198041386882        96
# 9862   Sid Meier's Civilization VI     S  76561198154689922       319
# 5753                Sea of Thieves     A  76561199020212036         1
# 2387                Sea of Thieves     A  76561197967428613        39
# 21724                  Katana ZERO     A  76561198181842774        12
#
#                                                   review  \
# 21078  The Factory must grow to meet the needs of the...
# 9862   Germany opened borders after I offered them on...
# 5753   i love the game but it wont  let me play anymo...
# 2387   It REALLY, REALLY needs a PVE setting. I tried...
# 21724  This game yelling like ‘’IM AN INDIE GAME’’. e...
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 21078  0.856543481349945068      True              297                7784
# 9862   0.917388856410980225      True              104                 559
# 5753    0.50519031286239624      True                0                 218
# 2387   0.639393448829650879     False                0                 519
# 21724  0.605176568031311035      True              360                 342
#
#        num_reviews  timestamp_created      color
# 21078            7         1703639890       pink
# 9862            13         1688498094       pink
# 5753             2         1687201718  mistyrose
# 2387             1         1681432057  mistyrose
# 21724           88         1700896564  mistyrose

# %%
df['timestamp_created'] = pd.to_datetime(df['timestamp_created'], unit='s')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 1. Braki danych
# 2. Usunięcie duplikatów
# 4. Usunięcie recenzjii krótszych niż 3 słowa
# 9. Usunięcie znaków spcjalnych
# 10. "Text lowering"
# 6. Usunięcie znaków interpunkcyjnych i liczb
# 7. Tokenizacja
# 8. Part-of-speech tagging
# 9. Lematyzacja

# %% [markdown]
# #### Braki danych

# %%
df.isna().sum()
# Out:
# title                  0
# genre                  0
# steamid                0
# votes_up               0
# review                 0
# weighted_vote_score    0
# voted_up               0
# num_games_owned        0
# playtime_at_review     0
# num_reviews            0
# timestamp_created      0
# color                  0
# dtype: int64

# %% [markdown]
# #### Usunięcie duplikatów

# %%
df.duplicated(subset='review').sum()
# Out:
# 2580

# %%
df[df.duplicated(subset='review')].sample(59)
# Out:
#                              title genre            steamid  votes_up  \
# 15115            Hearts of Iron IV     S  76561198972069384       146
# 26752                     Portal 2     P  76561199380635909         1
# 19817                     Factorio     S  76561198862123784         1
# 22609                Left 4 Dead 2     A  76561198863827167         1
# 21204                  Katana ZERO     A  76561198891830132         8
# 12089                     RimWorld     S  76561198116204950         6
# 24337                Left 4 Dead 2     A  76561198825505319         1
# 22257                Left 4 Dead 2     A  76561199447438574         3
# 16089            Hearts of Iron IV     S  76561198268561981         1
# 20370                     Factorio     S  76561199117177610         1
# 29945                Disco Elysium     R  76561198243510512         1
# 25149                Left 4 Dead 2     A  76561198964554887         1
# 14028                     RimWorld     S  76561198348425674         1
# 23976                Left 4 Dead 2     A  76561199445262360         1
# 16553            Hearts of Iron IV     S  76561198872107737         2
# 27502                     Portal 2     P  76561198056738665         1
# 23283                Left 4 Dead 2     A  76561199181407496         1
# 24131                Left 4 Dead 2     A  76561199025115121         1
# 10446  Sid Meier's Civilization VI     S  76561198027253598         1
# 29082                Disco Elysium     R  76561198365268449         1
# 16311            Hearts of Iron IV     S  76561199221887571         1
# 19813                     Factorio     S  76561199078626050         1
# 20692                     Factorio     S  76561199089514102         2
# 17274            Hearts of Iron IV     S  76561199526542537         1
# 27622                     Portal 2     P  76561198331674179         1
# 25798                     Portal 2     P  76561199037499590        88
# 17171            Hearts of Iron IV     S  76561199226706874         1
# 16431            Hearts of Iron IV     S  76561199035551303         1
# 17560            Hearts of Iron IV     S  76561199191240468         1
# 20458                     Factorio     S  76561198313322953         1
# 4148                Sea of Thieves     A  76561199013181222         1
# 13668                     RimWorld     S  76561198123506261         1
# 26451                     Portal 2     P  76561199122550059         1
# 20196                     Factorio     S  76561198234924480         2
# 12712                     RimWorld     S  76561198035500398         1
# 21615                  Katana ZERO     A  76561198069954191       181
# 4700                Sea of Thieves     A  76561199203813832         1
# 3116                Sea of Thieves     A  76561198271599278         3
# 20379                     Factorio     S  76561198059989680         1
# 14751                       INSIDE     P  76561198300843517         1
# 20729                     Factorio     S  76561198416847943         2
# 27716                     Portal 2     P  76561199152057492         1
# 16400            Hearts of Iron IV     S  76561198990709309         1
# 15307            Hearts of Iron IV     S  76561198121807020         3
# 31928         Little Nightmares II     P  76561199216256048         1
# 22856                Left 4 Dead 2     A  76561199203777268         1
# 25141                Left 4 Dead 2     A  76561198068513589         1
# 25580                Left 4 Dead 2     A  76561199250976807         1
# 2624                Sea of Thieves     A  76561198935676921         2
# 28600                Disco Elysium     R  76561198095572698         3
# 15536            Hearts of Iron IV     S  76561198048436143         1
# 16839            Hearts of Iron IV     S  76561198018448893         3
# 3654                Sea of Thieves     A  76561199202014536         1
# 26917                     Portal 2     P  76561199104632107         1
# 23992                Left 4 Dead 2     A  76561199232784136         1
# 23449                Left 4 Dead 2     A  76561198049831417         1
# 15005                       INSIDE     P  76561198135871021         6
# 5760                Sea of Thieves     A  76561199485646711         2
# 26060                     Portal 2     P  76561198969036634         1
#
#                                                   review  \
# 15115                                   i hate this game
# 26752                                             portal
# 19817  T̷̺̩̬͚͈̜͓̖͉͔͉̀̀̍̅͠͝h̸̘̣͂͐̋̋͂͋̍̚̚͝e̶̊̓̆́̀̾͊̓̏̇́...
# 22609                                                yes
# 21204  🟢[b] Plug and Play [/b]\n\nTested on: OnexPlay...
# 12089                                          i love it
# 24337                                                  a
# 22257                                               epic
# 16089                                            is nice
# 20370                                           very gud
# 29945                                                 :D
# 25149                      fun game to play with friends
# 14028                                             w game
# 23976                                            Awesome
# 16553                            you can nuke the french
# 27502                                                 <3
# 23283                                                  .
# 24131                                    best game ever.
# 10446                                                 :D
# 29082                           Kim Kitsuragi my beloved
# 16311                                                fun
# 19813                                              crack
# 20692                                  Factory must grow
# 17274                                             good\n
# 27622                                     very good game
# 25798                                                sex
# 17171                                                Yes
# 16431                                           very gud
# 17560                                    this game sucks
# 20458                             The factory must grow.
# 4148                                                GOOD
# 13668                                         It's okay.
# 26451                                   i like this game
# 20196                              THE FACTORY MUST GROW
# 12712                                            It's ok
# 21615                                        masterpiece
# 4700                                           good game
# 3116                                                 yes
# 20379                                            Factory
# 14751                                          good game
# 20729                                               dont
# 27716                                      its very good
# 16400                                               good
# 15307                                           its okay
# 31928                                           the best
# 22856                                             zombie
# 25141                                         pills here
# 25580                                               epic
# 2624                                         MASTERPIECE
# 28600                                       literally me
# 15536                                         Great game
# 16839                                   i hate this game
# 3654                                             add sex
# 26917                                              funny
# 23992                                               good
# 23449                                         PILLS HERE
# 15005                                                  👍
# 5760                                      best game ever
# 26060                                          good game
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 15115  0.778438448905944824      True               58               60222
# 26752  0.523809552192687988      True               44                 288
# 19817  0.523809552192687988      True              237               26999
# 22609  0.523809552192687988      True               45                 773
# 21204  0.561014294624328613      True              996                 162
# 12089  0.563176929950714111      True               67                1367
# 24337  0.523809552192687988      True                3                 570
# 22257  0.538808882236480713      True               22                 193
# 16089  0.523809552192687988      True               62               24030
# 20370  0.523809552192687988      True                0                8494
# 29945  0.507462680339813232      True               93                 408
# 25149  0.518518567085266113      True                6                3877
# 14028  0.516150951385498047      True                0                5757
# 23976  0.523809552192687988      True                0                1339
# 16553  0.522751331329345703      True                0                3378
# 27502   0.52173912525177002      True              663                2005
# 23283  0.523809552192687988      True                0                 249
# 24131  0.523809552192687988      True                0                1246
# 10446  0.523809552192687988      True                0               30451
# 29082  0.523809552192687988      True                0                 642
# 16311  0.523809552192687988      True               37                7290
# 19813  0.523809552192687988      True               59                7564
# 20692  0.516129016876220703      True               84                3872
# 17274  0.507575750350952148      True                0                9250
# 27622  0.518518567085266113      True               68                 442
# 25798  0.751271665096282959      True               72                 517
# 17171  0.509803950786590576      True               32                3765
# 16431  0.523809552192687988      True               49                2031
# 17560  0.503058075904846191     False                0                1281
# 20458   0.52173912525177002      True                0                  30
# 4148   0.523809552192687988      True                0                 930
# 13668   0.52173912525177002      True              264              538006
# 26451  0.523809552192687988      True                0                1968
# 20196  0.523809552192687988      True              187                8599
# 12712  0.523809552192687988      True                0               60042
# 21615  0.905311226844787598      True              258                 543
# 4700   0.523809552192687988      True                0                3494
# 3116   0.524564206600189209      True                0               11842
# 20379  0.523809552192687988      True                0                1179
# 14751  0.523809552192687988      True               86                 278
# 20729  0.514056205749511719      True                0                1699
# 27716  0.508928596973419189      True               67                1747
# 16400  0.523809552192687988      True                0               42218
# 15307  0.545454561710357666      True                0              239824
# 31928  0.500671148300170898      True                0                 365
# 22856  0.523809552192687988      True                0                 351
# 25141  0.518716573715209961      True                0                1321
# 25580                   0.5      True                0                8391
# 2624   0.545454561710357666      True               23                2594
# 28600  0.533018887042999268      True              377                 204
# 15536  0.525862038135528564      True                0                1207
# 16839  0.519875288009643555      True               64                9427
# 3654   0.523809552192687988      True                0                1729
# 26917  0.523809552192687988      True                0                 371
# 23992  0.523809552192687988      True                0                2516
# 23449  0.523809552192687988      True                0               71932
# 15005   0.61538463830947876      True                0                2194
# 5760   0.504950463771820068      True                0                5592
# 26060  0.525862038135528564      True                0                 381
#
#        num_reviews   timestamp_created          color
# 15115            6 2023-07-29 19:41:38           pink
# 26752            6 2023-02-23 22:56:33        thistle
# 19817            9 2023-07-12 12:59:54           pink
# 22609           24 2023-08-20 00:04:17      mistyrose
# 21204          117 2023-01-16 06:31:16      mistyrose
# 12089           19 2023-03-08 16:33:36           pink
# 24337            2 2022-11-24 10:18:27      mistyrose
# 22257           26 2023-06-09 19:28:43      mistyrose
# 16089            1 2023-02-18 11:26:25           pink
# 20370           10 2022-11-09 16:13:12           pink
# 29945            7 2022-11-24 22:31:25  palevioletred
# 25149            3 2023-03-28 23:51:09      mistyrose
# 14028            2 2023-07-18 03:28:45           pink
# 23976            2 2022-12-31 03:12:27      mistyrose
# 16553           13 2023-07-07 01:17:11           pink
# 27502           14 2022-11-23 22:09:36        thistle
# 23283           10 2023-04-03 20:23:40      mistyrose
# 24131            2 2022-12-13 07:23:18      mistyrose
# 10446           21 2023-05-18 16:35:26           pink
# 29082           12 2023-03-06 07:54:44  palevioletred
# 16311            3 2022-12-11 19:02:33           pink
# 19813            9 2023-07-14 22:55:25           pink
# 20692           20 2023-08-25 15:44:09           pink
# 17274            3 2023-08-20 18:43:28           pink
# 27622            4 2022-11-23 20:28:35        thistle
# 25798            5 2023-09-12 20:38:53        thistle
# 17171            7 2022-12-13 11:22:06           pink
# 16431            7 2022-11-08 15:01:09           pink
# 17560            5 2023-09-30 19:53:02           pink
# 20458            1 2023-08-07 03:27:34           pink
# 4148             3 2023-01-15 05:06:10      mistyrose
# 13668            7 2023-05-03 06:44:03           pink
# 26451            2 2023-05-17 16:43:53        thistle
# 20196            4 2023-01-04 10:25:36           pink
# 12712           14 2023-06-29 19:38:28           pink
# 21615           45 2020-06-18 10:44:01      mistyrose
# 4700             2 2022-10-23 10:40:44      mistyrose
# 3116             1 2023-09-03 04:04:14      mistyrose
# 20379           16 2022-10-31 15:22:42           pink
# 14751           31 2022-11-17 01:54:21        thistle
# 20729            5 2023-07-26 02:22:28           pink
# 27716           23 2023-01-23 14:03:54        thistle
# 16400            2 2022-11-17 06:05:05           pink
# 15307            1 2022-11-18 05:37:06           pink
# 31928           39 2022-11-19 20:30:35        thistle
# 22856            6 2023-07-05 17:03:35      mistyrose
# 25141            4 2023-01-17 02:25:10      mistyrose
# 25580            2 2023-04-14 01:06:14      mistyrose
# 2624             7 2023-05-11 16:30:18      mistyrose
# 28600            5 2023-07-04 06:56:32  palevioletred
# 15536           13 2022-11-03 13:52:31           pink
# 16839           11 2023-05-11 19:50:34           pink
# 3654            12 2023-04-28 11:19:01      mistyrose
# 26917           37 2023-01-07 03:41:32        thistle
# 23992            1 2022-12-30 03:43:52      mistyrose
# 23449            1 2023-03-16 05:16:48      mistyrose
# 15005           88 2023-12-16 13:18:12        thistle
# 5760             1 2023-09-03 02:47:55      mistyrose
# 26060            6 2023-03-03 18:54:01        thistle

# %%
(df.duplicated(subset='review') == False).sum()
# Out:
# 29492

# %%
df = df[df.duplicated(subset='review') == False]

# %%
df.duplicated(subset='review').sum()
# Out:
# 0

# %% [markdown]
# #### Czas gry mniejszy od godziny

# %% [raw]
# df["playtime_at_review"] = df["playtime_at_review"] / 60

# %% [raw]
# value_counts_hour_playtime = df[df["playtime_at_review"] <1]["title"].value_counts()

# %% [raw]
# genre_colors = {"A": "mistyrose", "R": "palevioletred", "P": "thistle", "S": "pink"}
# df['color'] = df['genre'].map(genre_colors)
# colors = [df.loc[df['title'] == title]['color'].iloc[0] for title in value_counts_title.index]
#
# plt.figure(figsize=(12, 6))
# x = value_counts_hour_playtime.plot(kind = "bar", color = colors)
# plt.ylabel("Ilość recenzji")
# plt.xticks(rotation = 90)
# for i, count in enumerate(value_counts_hour_playtime):
#     x.text(i, count, count, va = "bottom", ha = "center")
#
# plt.show()

# %% [raw]
# df = df[df["playtime_at_review"]>1]

# %% [markdown]
# #### Długość recenzji

# %%
df["temp_review_len"] = df["review"].apply(lambda x: x.split(" ").__len__())
df["temp_review_len"].describe()
# Out:
# count    29492.000000
# mean        54.191984
# std        135.354534
# min          1.000000
# 25%          5.000000
# 50%         13.000000
# 75%         39.000000
# max       3997.000000
# Name: temp_review_len, dtype: float64

# %%
df[df["temp_review_len"] == df["temp_review_len"].max()]['review'].values
# Out:
# array(['t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r  ...
#       dtype=object)

# %%
df[df["temp_review_len"] < 4].groupby(by=["genre"]).count()
# Out:
#        title  steamid  votes_up  review  weighted_vote_score  voted_up  \
# genre
# A       1659     1659      1659    1659                 1659      1659
# P        852      852       852     852                  852       852
# R        798      798       798     798                  798       798
# S       1140     1140      1140    1140                 1140      1140
#
#        num_games_owned  playtime_at_review  num_reviews  timestamp_created  \
# genre
# A                 1659                1659         1659               1659
# P                  852                 852          852                852
# R                  798                 798          798                798
# S                 1140                1140         1140               1140
#
#        color  temp_review_len
# genre
# A       1659             1659
# P        852              852
# R        798              798
# S       1140             1140

# %%
df = df[df["temp_review_len"] >= 3]

# %%
suma = 0
for i in df["temp_review_len"]:
    suma += i

# %%
print("Ilość słów:", suma,
     "Ilość recenzji:", len(df["temp_review_len"]))
# Out:
# Ilość słów: 1593992 Ilość recenzji: 26663

# %% [markdown]
# ### Wordcloud

# %%
txt = ' '.join(i for i in df["review"])
wordcloud = WordCloud(max_font_size = 180,
                max_words = 120,
                width = 1200,
                height = 800,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "A"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "R"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "P"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "S"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# #### Usunięcie znaków, text lowering

# %%
df["review"] = df["review"].str.replace(r"\[.*?\]|\n|[^\x00-\x7F]+", "", regex=True).str.lower()

# %%
df["review"].sample(10)
# Out:
# 27640        i wish i had a portal gun to suck my own d...
# 29572                            neat political commentary
# 13183                     need some mods, but it good game
# 13248    amazing game, held off for a while as wasn't s...
# 21062                               i need more cracktorio
# 27685    really good gamewhen i think about tests to so...
# 1035                                highkey sobbing rn tbh
# 7842                                          cool game :3
# 3512     i like to fish, i only fish, iv fished for 77 ...
# 5148     the game is pretty good for what it is but as ...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie znaków interpunkcyjnych i liczb

# %%
df["review"] = df["review"].str.replace(r"[0-9]", "", regex=True)

# %%
import string 
df["review"] = df["review"].str.replace('['  + string.punctuation + ']', "", regex =True)

# %%
df["review"].sample(5)
# Out:
# 15921    with each new dlc its getting worsehas some gr...
# 31365    i dont usually play games with this kind of gr...
# 22174    played for ages way back when in computer shop...
# 10039    they added an annoying launcher which does not...
# 25645                                i wish coach was real
# Name: review, dtype: object

# %% [markdown]
# #### Tokenizacja

# %%
import nltk
df["tokenized"] = df["review"].apply(nltk.word_tokenize)

# %%
df["tokenized"].sample(15)
# Out:
# 30712               [this, is, the, best, game, on, steam]
# 31588    [very, good, puzzles, makes, you, think, its, ...
# 15467                                   [yeahits, a, game]
# 14908    [i, see, people, complaining, how, short, this...
# 28015    [zaum, forced, the, creative, minds, behind, t...
# 12400    [good, game, if, you, buy, everything, on, sal...
# 15035        [i, have, never, interacted, with, a, female]
# 20177     [if, you, have, adhd, youve, discovered, heaven]
# 15665    [my, art, teacher, said, that, im, not, going,...
# 10377    [unlike, a, lot, of, other, civ, players, numb...
# 28924    [this, is, such, an, amazing, and, oneofakind,...
# 17287                      [i, sure, do, hate, the, frnch]
# 12388    [simple, ideas, shining, solutions, even, with...
# 29118    [excellent, and, really, unique, story, gamepl...
# 19648    [warning, this, game, is, addicting, you, may,...
# Name: tokenized, dtype: object

# %% [markdown]
# #### POS tagging

# %%
nltk.download('averaged_perceptron_tagger')
df["tagged"] = df["tokenized"].apply(nltk.pos_tag)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\marty\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
