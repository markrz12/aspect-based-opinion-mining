# %%
import pandas as pd
import spacy
import steamreviews
import json
import csv
import os
import glob
import json
import matplotlib.pyplot as plt
import nltk
import wordcloud
import re
import plotly
import seaborn as sns
import stanza
import string 
import joblib

from scipy.stats import pearsonr
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import fcluster
from wordcloud import WordCloud
from pandas.io.json import json_normalize
from nltk.corpus import stopwords
from tqdm.notebook import trange, tqdm
from sklearn.cluster import KMeans
# Out:
# C:\Users\marty\AppData\Local\Programs\Python\Python311\Lib\site-packages\thinc\compat.py:36: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   hasattr(torch, "has_mps")
# C:\Users\marty\AppData\Local\Programs\Python\Python311\Lib\site-packages\thinc\compat.py:37: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   and torch.has_mps  # type: ignore[attr-defined]

# %% [markdown]
# ## Reviews download
# https://pypi.org/project/steamreviews/

# %% [raw]
# list_of_app_ids = [219150, 1172620, 460950, 262060, 250320, 210970, 620, 736260,
#                    219890, 289070, 427520, 257510, 304430, 400, 394360, 550,
#                    632470, 294100, 646570, 1150690, 1341290, 1515210, 860510]
#
# def get_reviews(list_of_app_ids):
#     request_params = dict()
#     request_params['language'] = 'english'
#     request_params['day_range'] = '365'
#     request_params['filter'] = 'all'
#     for app_id in list_of_app_ids:
#         review_dict, query_count = steamreviews.download_reviews_for_app_id(app_id,chosen_request_params=request_params)
#     return review_dict, query_count
# get_reviews(list_of_app_ids);

# %%
dir_name = "data"
reviews_jsons = glob.glob(f"{dir_name}/*")
reviews_jsons
# Out:
# ['data\\review_1150690.json',
#  'data\\review_1172620.json',
#  'data\\review_1341290.json',
#  'data\\review_1515210.json',
#  'data\\review_210970.json',
#  'data\\review_219150.json',
#  'data\\review_219890.json',
#  'data\\review_250320.json',
#  'data\\review_257510.json',
#  'data\\review_262060.json',
#  'data\\review_289070.json',
#  'data\\review_294100.json',
#  'data\\review_304430.json',
#  'data\\review_394360.json',
#  'data\\review_400.json',
#  'data\\review_427520.json',
#  'data\\review_460950.json',
#  'data\\review_550.json',
#  'data\\review_620.json',
#  'data\\review_632470.json',
#  'data\\review_646570.json',
#  'data\\review_736260.json',
#  'data\\review_860510.json']

# %%
title_dict = {"219150": "Hotline Miami",
              "1172620" : "Sea of Thieves",
              "460950" : "Katana ZERO",
              "262060" : "Darkest Dungeon",
              "250320" : "The Wolf Among Us",
              "210970" : "The Witness",
              "620" : "Portal 2",
              "736260" : "Baba Is You",
              "219890" : "Antichamber",
              "289070" : "Sid Meier's Civilization VI",
              "427520" : "Factorio",
              "257510" : "The Talos Principle",
             "304430" : "INSIDE",
             "400" : "Portal",
             "394360" : "Hearts of Iron IV",
             "632470" : "Disco Elysium",
             "294100" : "RimWorld",
              "646570" : "Slay the Spire",
              "1150690" : "Omori",
              "1341290" : "We Were Here Forever",
              "1515210" : "The Past Within",
              "860510" : "Little Nightmares II",
              "550" : "Left 4 Dead 2"}

# %%
genre_dict = {"219150": "A",
              "1172620" : "A",
              "460950" : "A",
              "262060" : "R",
              "250320" : "R",
              "210970" : "P",
              "620" : "P",
              "736260" : "P",
              "219890" : "P",
              "289070" : "S",
              "427520" : "S",
              "257510" : "P",
              "304430" : "P",
             "400" : "P",
             "394360" : "S",
             "632470" : "R",
             "294100" : "S",
             "646570" : "R",
             "1150690" : "R",
             "1341290" : "P",
             "1515210" : "P",
             "860510" : "P",
             "550" : "A"}

# %%
data_list = []
for i in reviews_jsons:
    with open(i, encoding = "utf-8") as json_file:
        json_data = json.load(json_file)
        reviews = json_data['reviews']
        file_name = json_file.name.split('.')[0].split('_')[1]
        for key in reviews.keys():
            data_list.append([title_dict.get(file_name),genre_dict.get(file_name),reviews[key]['author']['steamid'], reviews[key]['votes_up'], 
                          reviews[key]['review'], reviews[key]['weighted_vote_score'], reviews[key]['voted_up'],
                          reviews[key]['author']['num_games_owned'], reviews[key]['author']['playtime_at_review'],
                          reviews[key]['author']['num_reviews'], 
                          reviews[key]["timestamp_created"] ])
df = pd.DataFrame(data_list, columns = ["title", "genre","steamid", "votes_up", "review", "weighted_vote_score", "voted_up",
                                        "num_games_owned", "playtime_at_review", "num_reviews", "timestamp_created"])

# %%
df.sample(frac=0.3).head()
# Out:
#                              title genre            steamid  votes_up  \
# 8880           The Talos Principle     P  76561197999220006         1
# 10285  Sid Meier's Civilization VI     S  76561198818373554         1
# 23380                Left 4 Dead 2     A  76561199217131343         1
# 6322          We Were Here Forever     P  76561198077928623         1
# 21586                  Katana ZERO     A  76561198079630086         1
#
#                                                   review  \
# 8880   I received the game as a gift from a friend, i...
# 10285  id Meier's Civilization VI is a strategic mast...
# 23380                                          best game
# 6322   I'm a huge fan of the entire 'We Were Here' se...
# 21586                              Yes, that should work
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 8880   0.503342866897583008      True              293                 939
# 10285  0.523809552192687988      True               35                1738
# 23380  0.523809552192687988      True               41                 206
# 6322   0.523809552192687988      True                0                1065
# 21586  0.505882382392883301      True              157                 275
#
#        num_reviews  timestamp_created
# 8880            32         1672623501
# 10285           18         1693989900
# 23380           59         1679497126
# 6322            13         1671752894
# 21586           16         1669284100

# %%
df['timestamp_created'] = pd.to_datetime(df['timestamp_created'], unit='s')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 1. Braki danych
# 2. Usunięcie duplikatów
# 4. Usunięcie recenzjii krótszych niż 3 słowa
# 9. Usunięcie znaków spcjalnych
# 10. "Text lowering"
# 6. Usunięcie znaków interpunkcyjnych i liczb
# 8. Usunięcie tytułów gier z recenzji
# 7. Tokenizacja
# 8. Part-of-speech tagging
# 9. Lematyzacja

# %% [markdown]
# #### Braki danych

# %%
df.isna().sum()
# Out:
# title                  0
# genre                  0
# steamid                0
# votes_up               0
# review                 0
# weighted_vote_score    0
# voted_up               0
# num_games_owned        0
# playtime_at_review     0
# num_reviews            0
# timestamp_created      0
# dtype: int64

# %% [markdown]
# #### Usunięcie duplikatów

# %%
df.duplicated(subset='review').sum()
# Out:
# 2580

# %%
df[df.duplicated(subset='review')].sample(20)
# Out:
#                              title genre            steamid  votes_up  \
# 5285                Sea of Thieves     A  76561198318274779         1
# 20250                     Factorio     S  76561198247377980         1
# 20568                     Factorio     S  76561199205804585         1
# 14216                     RimWorld     S  76561198316707684         1
# 17133            Hearts of Iron IV     S  76561199084022533         1
# 25148                Left 4 Dead 2     A  76561199218148538         1
# 23471                Left 4 Dead 2     A  76561198868037760         1
# 1148                         Omori     R  76561199375439958         1
# 31649         Little Nightmares II     P  76561198083449187        14
# 13016                     RimWorld     S  76561198063353691         1
# 26331                     Portal 2     P  76561199465259017         1
# 27463                     Portal 2     P  76561198057917452         1
# 15596            Hearts of Iron IV     S  76561198330621262         1
# 1895                         Omori     R  76561199208399667         1
# 8144                   Antichamber     P  76561198117585562         1
# 12674                     RimWorld     S  76561199104701437         1
# 5156                Sea of Thieves     A  76561198997247564         2
# 31385                  Baba Is You     P  76561199059934445         1
# 20410                     Factorio     S  76561199405985718         1
# 11237  Sid Meier's Civilization VI     S  76561198132055632         1
#
#                                                   review  \
# 5285                                    fun with friends
# 20250                             The factory must grow.
# 20568                                          cool game
# 14216                                      It's alright.
# 17133                                           map game
# 25148  Before I played this i had a small penis, no g...
# 23471                                  this game is good
# 1148                                                omor
# 31649                                                  👍
# 13016
# 26331                                          gud game.
# 27463                                               good
# 15596                              It's alright I guess.
# 1895                                                epic
# 8144                                    I like this game
# 12674                                                  e
# 5156
# 31385                                               yeah
# 20410                                           very pog
# 11237                                           its good
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 5285   0.517241418361663818      True              137                 350
# 20250  0.523809552192687988      True                0                5125
# 20568   0.52173912525177002      True                0               32335
# 14216  0.507598817348480225      True                0               72517
# 17133  0.510436415672302246      True                0               13250
# 25148  0.518518567085266113      True               51                3321
# 23471  0.523809552192687988      True                0                1992
# 1148   0.523809552192687988      True                0                 279
# 31649  0.598033249378204346      True              414                 366
# 13016  0.523809552192687988      True                0               22333
# 26331  0.523809552192687988      True                9                 365
# 27463   0.52173912525177002      True                0                 623
# 15596  0.523809552192687988      True               42               59732
# 1895   0.506896555423736572      True                0                2752
# 8144   0.523809552192687988      True              127                 294
# 12674  0.523809552192687988      True                0                2890
# 5156   0.519841313362121582      True                0                2093
# 31385  0.523809552192687988      True               75                 191
# 20410  0.523809552192687988      True                5                  47
# 11237  0.518518567085266113      True                0               31641
#
#        num_reviews   timestamp_created
# 5285            44 2022-12-07 13:24:02
# 20250            4 2022-12-23 23:02:31
# 20568            4 2022-10-30 16:02:14
# 14216            8 2023-09-05 20:24:18
# 17133            8 2022-12-29 02:26:44
# 25148           11 2023-04-25 17:20:40
# 23471           62 2023-03-11 23:37:44
# 1148             3 2023-01-13 02:19:06
# 31649          298 2023-01-14 07:56:32
# 13016            1 2023-02-05 01:52:32
# 26331            6 2023-07-05 12:56:18
# 27463            3 2023-01-07 16:22:26
# 15596            7 2023-09-13 16:42:52
# 1895             1 2022-11-06 18:18:52
# 8144            22 2023-07-18 10:50:06
# 12674            4 2023-07-11 05:32:10
# 5156             1 2023-02-10 11:18:52
# 31385           16 2023-01-07 05:12:38
# 20410            1 2022-10-09 08:55:28
# 11237            2 2022-11-10 20:46:12

# %%
(df.duplicated(subset='review') == False).sum()
# Out:
# 29492

# %%
df = df[df.duplicated(subset='review') == False]

# %%
df.duplicated(subset='review').sum()
# Out:
# 0

# %% [markdown]
# #### Długość recenzji

# %%
df["temp_review_len"] = df["review"].apply(lambda x: x.split(" ").__len__())
df["temp_review_len"].describe()
# Out:
# count    29492.000000
# mean        54.191984
# std        135.354534
# min          1.000000
# 25%          5.000000
# 50%         13.000000
# 75%         39.000000
# max       3997.000000
# Name: temp_review_len, dtype: float64

# %% [raw]
# df[df["temp_review_len"] == df["temp_review_len"].max()]['review'].values

# %%
df[df["temp_review_len"] < 4].groupby(by=["genre"]).count()
# Out:
#        title  steamid  votes_up  review  weighted_vote_score  voted_up  \
# genre
# A       1659     1659      1659    1659                 1659      1659
# P        852      852       852     852                  852       852
# R        798      798       798     798                  798       798
# S       1140     1140      1140    1140                 1140      1140
#
#        num_games_owned  playtime_at_review  num_reviews  timestamp_created  \
# genre
# A                 1659                1659         1659               1659
# P                  852                 852          852                852
# R                  798                 798          798                798
# S                 1140                1140         1140               1140
#
#        temp_review_len
# genre
# A                 1659
# P                  852
# R                  798
# S                 1140

# %%
df = df[df["temp_review_len"] >= 3]

# %%
suma = 0
for i in df["temp_review_len"]:
    suma += i

# %%
print("Ilość słów:", suma,
     "Ilość recenzji:", len(df["temp_review_len"]))
# Out:
# Ilość słów: 1593992 Ilość recenzji: 26663

# %%
df = df.drop(["temp_review_len"], axis=1)

# %% [markdown]
# ### Wordcloud

# %%
txt = ' '.join(i for i in df["review"])
wordcloud = WordCloud(max_font_size = 180,
                max_words = 120,
                width = 1200,
                height = 800,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "A"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "R"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "P"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "S"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# #### Usunięcie znaków, text lowering

# %%
df["review"] = df["review"].str.replace(r"\[.*?\]|\n|[^\x00-\x7F]+", "", regex=True).str.lower()

# %%
df["review"].sample(10)
# Out:
# 29031    the most beautiful and well written game i've ...
# 744                               i will never be the same
# 1108     i love this game almost as much as kel loves b...
# 11030    after a while of playing this game you have a ...
# 24327    guys this game is the best zombie game ppl hav...
# 8866     this is not a game. it is a very ugly, empty w...
# 17996                               the cake wasn't a lie.
# 1430     i really loved this game, the music, the story...
# 5860     don't waste your time and money. servers are a...
# 13919    cool game, might be able to sink a few hours i...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie znaków interpunkcyjnych i liczb

# %%
df["review"] = df["review"].str.replace(r"[0-9]", "", regex=True)

# %%
df["review"] = df["review"].str.replace('['  + string.punctuation + ']', "", regex =True)

# %%
df["review"].sample(5)
# Out:
# 16672                                i love drawing arrows
# 30907    i got fired from my job for playing this durin...
# 1489     the best game that no one has heard of  i cant...
# 4001     les pln pirti moe lumprnk deo mi ukrad upln ro...
# 23413                      its justthe best zombie shooter
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie tytułów gier z recenzji

# %%
for value in title_dict.values():
    df["review"] = df["review"].str.replace(value.lower(), "")

# %% [markdown]
# #### Tokenizacja

# %%
df["tokenized"] = df["review"].apply(nltk.word_tokenize)

# %%
df["tokenized"].sample(15)
# Out:
# 24642       [do, you, know, what, suck, the, heads, means]
# 17806    [this, is, somehow, the, only, game, where, yo...
# 6826        [really, fun, game, to, play, with, a, friend]
# 5352     [very, good, suggest, buyng, but, only, buy, i...
# 27958    [the, greatest, rpg, of, all, time, stolen, by...
# 28645    [detective, in, need, of, assistance, on, the,...
# 6445     [game, was, amazing, up, until, the, point, wh...
# 22679    [i, just, love, this, game, all, the, zombies,...
# 10294    [funniest, thing, is, to, play, earth, real, s...
# 21630    [bought, the, game, to, slice, things, with, a...
# 485      [this, was, an, amazing, game, that, really, m...
# 15501    [this, game, is, my, favorite, one, i, have, p...
# 24265    [fun, game, to, play, with, friends, you, can,...
# 10156    [wow, probably, the, biggest, disappointment, ...
# 13869    [warcrimes, organ, harvesting, child, labour, ...
# Name: tokenized, dtype: object

# %% [markdown]
# ### Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
english_stopwords = stopwords.words('english')
english_stopwords_cleaned = [word.replace("'", "") for word in english_stopwords]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marty\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
new_column = []
for row in df["tokenized"]:
    new_row = [word for word in row if word[0] not in english_stopwords_cleaned]
    new_column.append(new_row)
df["final_review"] = new_column

# %% [markdown]
# ## Describe

# %%
df.dtypes
# Out:
# title                          object
# genre                          object
# steamid                        object
# votes_up                        int64
# review                         object
# weighted_vote_score            object
# voted_up                         bool
# num_games_owned                 int64
# playtime_at_review              int64
# num_reviews                     int64
# timestamp_created      datetime64[ns]
# tokenized                      object
# final_review                   object
# dtype: object

# %%
df["weighted_vote_score"] = pd.to_numeric(df["weighted_vote_score"])

# %%
df["voted_up"] = pd.to_numeric(df["voted_up"])

# %%
df.describe()
# Out:
#            votes_up  weighted_vote_score  num_games_owned  playtime_at_review  \
# count  26663.000000         26663.000000     26663.000000        2.666300e+04
# mean      31.715148             0.570098       140.866707        1.309372e+04
# std      173.097223             0.109932       538.652824        4.720263e+04
# min        0.000000             0.500000         0.000000        5.000000e+00
# 25%        1.000000             0.521739         0.000000        5.350000e+02
# 50%        1.000000             0.523810         0.000000        1.800000e+03
# 75%        3.000000             0.545180       113.000000        7.111500e+03
# max     9568.000000             0.987843     22780.000000        1.890626e+06
#
#         num_reviews
# count  26663.000000
# mean      21.467689
# std       59.809381
# min        1.000000
# 25%        3.000000
# 50%        8.000000
# 75%       20.000000
# max     3419.000000

# %%
corr = df.corr(method = "pearson")
plt.figure(figsize=(7,5))
sns.heatmap(corr, cmap=sns.cubehelix_palette(as_cmap=True),annot=True)
plt.show()
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_17004\2852639080.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method = "pearson")

# %% [markdown]
# ## Wykresy

# %%
value_counts_title = df["title"].value_counts()
genre_colors = {"A": sns.cubehelix_palette(4)[1], "R": sns.cubehelix_palette(4)[2], "P": sns.cubehelix_palette(4)[3], 
                "S": sns.cubehelix_palette(4)[0]}
df['color'] = df['genre'].map(genre_colors)
colors = [df.loc[df['title'] == title]['color'].iloc[0] for title in value_counts_title.index]

plt.figure(figsize=(12, 6))
x = value_counts_title.plot(kind = "bar", color = colors)
plt.ylabel("Ilość recenzji")
plt.xticks(rotation = 90)
for i, count in enumerate(value_counts_title):
    x.text(i, count, count, va = "bottom", ha = "center")

handles = [plt.Rectangle((0,0), 1,1, color=genre_colors[label]) for label in genre_colors]
plt.legend(handles, genre_colors.keys(), title="Gatunek", loc="upper right")


plt.show()
df = df.drop(["color"], axis=1)

# %%
value_counts_genre = df["genre"].value_counts()
colors = sns.cubehelix_palette(4)
x = plt.pie(value_counts_genre, labels = value_counts_genre.index, colors=colors, autopct='%1.2f%%')
plt.show()

# %%
value_counts_recommendation_genre = df.groupby('genre').voted_up.value_counts().unstack(0)
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 

total_count = percentage_pos + percentage_neg

def addlabels_neg(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] + 2, f"{x[i]:.2f}%",  ha = "center")

def addlabels_pos(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] - 6, f"{y[i]:.2f}%",  ha = "center")

fig, ax1 = plt.subplots(figsize=(7, 4))
ax2 = ax1.twinx()

total_count.plot(kind="bar", color="#95DBE5FF",  label="Recommended")
percentage_neg.plot(kind="bar", color="#078282FF", label="Not Recommended")

ax1.set_xlabel("Gatunki")
ax1.tick_params(axis="y", left=False, labelleft=False)
ax2.tick_params(axis="y", right=False, labelright=False)

addlabels_neg(percentage_neg, total_count) 
addlabels_pos(total_count, percentage_pos) 

plt.legend(bbox_to_anchor=(0.85, 1.15), ncol=2)
plt.show()

# %%
import numpy as np

value_counts_recommendation_genre = df.groupby('genre').voted_up.value_counts().unstack(0)
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 

total_count = percentage_pos + percentage_neg

def addlabels_neg(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] + 2, f"{x[i]:.2f}%",  ha = "center")

def addlabels_pos(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] - 6, f"{y[i]:.2f}%",  ha = "center")

fig, axs = plt.subplots(1, 2, figsize=(12, 4))

total_count.plot(kind="bar", color="#ffdaf6",  label="Recommended")
percentage_neg.plot(kind="bar", color="#b34a98", label="Not Recommended")

axs[1].set_xlabel("Gatunki")
addlabels_neg(percentage_neg, total_count) 
addlabels_pos(total_count, percentage_pos) 
axs[1].legend(loc=(1.04, 0))

value_counts_genre = df["genre"].value_counts()
colors = sns.cubehelix_palette(6)

axs[0].pie(value_counts_genre, labels = value_counts_genre.index,colors=colors, autopct='%1.1f%%', startangle=140)
plt.show()

# %% [markdown]
# ## Dependency parser test

# %%
test = [df["final_review"][6543], df["final_review"][4534], df["final_review"][12345], df["final_review"][12354],
        df["final_review"][1925], df["final_review"][1067],df["final_review"][22951],df["final_review"][2231],
       ["not","fun", "gameplay"], df["tokenized"][832], df["final_review"][21], df["tokenized"][27061],
       df["final_review"][11088], df["final_review"][3171], df["final_review"][7834], df["final_review"][20180],
       df["final_review"][6697], df["final_review"][893]]

# %%
import stanza
nlp = stanza.Pipeline('en', tokenize_pretokenized=True) 
doc = nlp(test)
# Out:
# 2024-06-27 10:23:07 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-06-27 10:23:07 INFO: Downloaded file to C:\Users\marty\stanza_resources\resources.json
# 2024-06-27 10:23:08 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-06-27 10:23:08 INFO: Using device: cuda
# 2024-06-27 10:23:08 INFO: Loading: tokenize
# 2024-06-27 10:23:08 INFO: Loading: mwt
# 2024-06-27 10:23:10 INFO: Loading: pos
# 2024-06-27 10:23:10 INFO: Loading: lemma
# 2024-06-27 10:23:10 INFO: Loading: constituency
# 2024-06-27 10:23:11 INFO: Loading: depparse
# 2024-06-27 10:23:11 INFO: Loading: sentiment
# 2024-06-27 10:23:12 INFO: Loading: ner
# 2024-06-27 10:23:12 INFO: Done loading processors!

# %%
dependency_list = []
for dependency in doc.sentences[13].dependencies:
    dependency_list.append([dependency[2].text, dependency[0].id, dependency[1]])
    
for i in range(0, len(dependency_list)):
    if (int(dependency_list[i][1]) != 0):
        dependency_list[i][1] = test[13][(int(dependency_list[i][1]) - 1)]

print(*dependency_list[:10], sep='\n')
# Out:
# ['crewing', 0, 'root']
# ['game', 'value', 'compound']
# ['value', 'crewing', 'obj']
# ['likely', 'crewing', 'advmod']
# ['worthless', 'crewing', 'xcomp']
# ['real', 'crewing', 'xcomp']
# ['but', 'play', 'cc']
# ['can', 'play', 'aux']
# ['play', 'crewing', 'conj']
# ['player', 'play', 'obj']

# %%
feature_list = []
feature_opinion_list = [] 

for dependency in doc.sentences[13].dependencies:
    if dependency[2].xpos == "RB":
        opinion_word = dependency[2]
        rb_adj = dependency[0]
        
    if (dependency[2].xpos in ["NN", "NNS","JJ", "JJS", "JJR"]) and (dependency[1] in ["amod"]):
        if dependency[0] == rb_adj or dependency[2] == rb_adj:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}     
        else:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}  

        feature_list.append(dependency[0].lemma)
        feature_opinion_list.append(result_dict)

print(f'Feature list: {feature_list}')
print(f'Feature-opinion list: {feature_opinion_list}')
# Out:
# Feature list: ['graphic', 'beauty', 'player', 'player', 'player', 'guide', 'reward', 'reward', 'reward']
# Feature-opinion list: [{'feature': 'graphic', 'opinion': 'fun'}, {'feature': 'beauty', 'opinion': 'real'}, {'feature': 'player', 'opinion': 'unbalanced'}, {'feature': 'player', 'opinion': 'janky'}, {'feature': 'player', 'opinion': 'human'}, {'feature': 'guide', 'opinion': 'necessary'}, {'feature': 'reward', 'opinion': 'risky'}, {'feature': 'reward', 'opinion': 'lowest'}, {'feature': 'reward', 'opinion': 'highest'}]

# %% [markdown]
# ## Dependency parser final

# %% [raw]
# feature_list_column = []
# feature_opinion_list_column = []
#
# for review in tqdm(df["final_review"]):
#     if isinstance(review, list):
#         review = " ".join(review)
#         doc = nlp(review)
#         feature_list = []
#         feature_opinion_list = []
#
#         if len(doc.sentences) == 0:
#             continue
#
#         for dependency in doc.sentences[0].dependencies:
#             if dependency[2].xpos == "RB":
#                 opinion_word = dependency[2]
#                 rb_adj = dependency[0]
#             if (dependency[2].xpos in ["JJ", "JJS"]) and (dependency[0].xpos in ["NN", "NNS"]) and (dependency[1] in ["amod"]):
#
#                 if dependency[0] == rb_adj or dependency[2] == rb_adj:
#                     if dependency[2].xpos in ["JJS", "JJR"]:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
#                     else:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}
#                 else:
#                     if dependency[2].xpos in ["JJS", "JJR"]:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
#                     else:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}
#
#                 feature_list.append(dependency[0].lemma)
#                 feature_opinion_list.append(result_dict)
#
#     feature_list_column.append(feature_list)
#     feature_opinion_list_column.append([review, feature_opinion_list])
#
# df["feature"] = [feature_list_column]
# df["feature_opinion_list"] = [feature_opinion_list_column]

# %% [raw]
# new_df = pd.DataFrame([feature_list_column, feature_opinion_list_column])
# new_df.T
#
# non_empty_indexes = df[df["final_review"].apply(lambda x: len(x)!=0)].index
#
# import json
# opinions_dict = {k:v for k, v in zip(non_empty_indexes, feature_opinion_list_column)}
# out_file = open("opinions.json", "w")
#
# json.dump(opinions_dict, out_file, indent = 6)
#
# out_file.close()

# %%
with open('opinions.json', 'r') as file:
    dct = json.load(file)

# %%
feature_list = []

for i in range(len(df)):
    index = str(i)  
    feature = dct.get(index)
    if feature is None:
        feature_list.append([])
    else:
        feature_list.append(feature)

df["feature"] = feature_list

# %%
df = df[df["feature"].apply(lambda x: len(x) > 0)]

# %%
words = []
for i in df["feature"]:
    for j in i:
        words.append(j["feature"])

# %%
unique_words = list(set(words))

# %%
word_counts = pd.DataFrame([[i, len([q for q in words if q==i])] for i in unique_words], 
              columns=['word', 'count']).sort_values('count', ascending=False)

# %% [markdown]
# ## Dendrogram

# %%
popular_words = word_counts[word_counts['count']>= 15]["word"].to_list()
nlp = spacy.load('en_core_web_md')
tokens = [nlp(word) for word in popular_words]
word_vectors = pd.DataFrame([i.vector for i in tokens])

# %%
Z = linkage(word_vectors.values, method='ward')

plt.figure(figsize=(10,6))
dendrogram(Z, p = 5, truncate_mode = "level", orientation='top', labels = popular_words, leaf_font_size = 8)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Words')
plt.ylabel('Distance')
plt.show()

# %%
cluster_labels = fcluster(Z, t = 75,  criterion="distance")

clusters = {}
for word, label in zip(popular_words, cluster_labels):
    if label not in clusters:
        clusters[label] = [word]
    else:
        clusters[label].append(word)

for label, words in clusters.items():
    print(f"Cluster {label}: {', '.join(words)}")
# Out:
# Cluster 68: game, play, player, playing
# Cluster 57: puzzle, pirate, horror, zomby, zombie, pawn, wolf, franchise, coop, nightmare, limbo, gamei, pve, fable, eargasm, clue, glado, hacker, chill, cannibal
# Cluster 21: experience, community, work, environment, resource, workshop, focus, knowledge, research, project, practice, learning
# Cluster 75: gameplay, gamer, gaming, rng, bonus, replay, cue
# Cluster 99: way, pace
# Cluster 97: hour, week, night
# Cluster 12: price, cost
# Cluster 47: person, friend, boss, child, woman, family, partner
# Cluster 48: love, choice, voice, wish, reward, hope, enjoyment, pleasure, praise
# Cluster 62: character, hero, genre, plot, figure, episode, cutscene, lore, chapter, legend, protagonist, narrator, backstory
# Cluster 1: world, city, country, nation
# Cluster 54: fun
# Cluster 19: level, point, number, class, rating
# Cluster 72: review, note, view, guide
# Cluster 76: graphic, visual, video, pixel
# Cluster 18: content, quality, value, product
# Cluster 52: lot
# Cluster 50: life
# Cluster 4: part, event, place
# Cluster 58: grind, luck, guess, hell, fuck, joke, ruin, cry, biter
# Cluster 25: challenge, problem, effect, reason, possibility, question, change, chance, balance, future, potential, purpose, factor
# Cluster 53: bit
# Cluster 8: colony, quest, colonist, empire, journey, voyage, fortress
# Cluster 92: room, wall, floor
# Cluster 77: update, feature, version, release, entry, upgrade, launcher, patch
# Cluster 9: end
# Cluster 63: bug, glitch
# Cluster 49: nothing, everything, feeling, everyone, emotion, kind, being, fear
# Cluster 16: factory, base, unit, platformer, location, production, company, plant, equipment, network, platform, facility
# Cluster 78: NASA
# Cluster 64: civ, pvp, rpg
# Cluster 7: enemy, fight, battle, combat, campaign, effort, victory
# Cluster 85: line, curve, loop, button, edge, length, belt, hook
# Cluster 51: guy, kid, boy, girl
# Cluster 20: element, playthrough, ending, civilization, requirement, replayability, example, progress, form, complaint, exploration, conclusion, progression, period, customization, combination, connection, conversation, expansion, process, confession, portion, relationship, beginning, communication, recommendation, condition, frustration, complexity, comment, warning, presentation, cycle, component, execution, experiment
# Cluster 39: need, help, want
# Cluster 29: run
# Cluster 43: job
# Cluster 22: concept, history, narrative, writing, personality, nature, philosophy, language, reality, perspective, vision, behavior
# Cluster 15: building, builder, build
# Cluster 101: lake, water, boat
# Cluster 11: war
# Cluster 37: cant, havent
# Cluster 86: piece, pack, cake, layer, package
# Cluster 30: look, feel
# Cluster 69: fan
# Cluster 102: crew, crash, ride
# Cluster 5: control, force, power
# Cluster 3: leader, party, group, faction
# Cluster 35: use
# Cluster 89: hand, chamber, face, front, head, chest, corner, lobby, back
# Cluster 26: fact, case, crime, error, flaw
# Cluster 60: word, name
# Cluster 95: weapon, loot, gun, bomb
# Cluster 23: robot, usage, encounter, course, planet, landscape, computer, universe, cheater, cosmetic, background, creature, physics, library, formula
# Cluster 42: eye
# Cluster 90: couple, half, winter, plenty
# Cluster 28: wait, break, pass, finish, call, leave, kill, pick, beat
# Cluster 6: rule, plan, policy
# Cluster 61: book, novel
# Cluster 34: buy
# Cluster 84: valve, engine
# Cluster 40: heart, brain, blood, body, bone
# Cluster 59: god
# Cluster 24: worth, waste, purchase, payment, buying, credit
# Cluster 94: raid, raider
# Cluster 87: color, paint, light
# Cluster 100: goal
# Cluster 45: care, health
# Cluster 56: humor, classic, vibe, gem, quirk, hint, charm
# Cluster 17: variety, range
# Cluster 98: path, route, road
# Cluster 71: list, page
# Cluster 79: fps
# Cluster 93: box
# Cluster 38: can, will
# Cluster 55: joy
# Cluster 46: food
# Cluster 80: leg
# Cluster 96: fire
# Cluster 33: find, fix
# Cluster 10: era
# Cluster 82: egg
# Cluster 36: go
# Cluster 65: pc
# Cluster 83: cup
# Cluster 91: wave
# Cluster 31: grow
# Cluster 14: risk
# Cluster 70: hit
# Cluster 27: lack
# Cluster 103: race
# Cluster 66: ld
# Cluster 88: gold
# Cluster 81: hat
# Cluster 41: pain
# Cluster 32: fit
# Cluster 13: rate
# Cluster 67: ui
# Cluster 74: key
# Cluster 73: log
# Cluster 2: land
# Cluster 44: role

# %% [raw]
# clusters = {}
# for word, label in zip(popular_words, cluster_labels):
#     if label not in clusters:
#         clusters[label] = [word]
#     else:
#         clusters[label].append(word)
#
# with open('clusters.csv', 'w') as file:
#     file.write('Cluster,Words\n')
#     for label, words in clusters.items():
#         file.write(f"{label},{' '.join(words)}\n")
#         print(f"Cluster {label}: {', '.join(words)}")
#
# print("Clusters saved to clusters.csv")

# %%
def words_to_list(words_string):
    return words_string.split()

clusters_df = pd.read_csv('clusters.csv', converters={'Words': words_to_list})
clusters_df
# Out:
#      Cluster                                              Words
# 0         68                      [game, play, player, playing]
# 1         57  [puzzle, pirate, horror, zomby, pawn, zombie, ...
# 2         21  [experience, community, work, environment, res...
# 3         75  [gameplay, gamer, gaming, rng, bonus, replay, ...
# 4         99                                        [way, pace]
# ..       ...                                                ...
# 98        13                                             [rate]
# 99        74                                              [key]
# 100       44                                             [role]
# 101        2                                             [land]
# 102       73                                              [log]
#
# [103 rows x 2 columns]

# %%
clusters = {7: 'Combat',
    95: 'Combat',
    75: 'Gameplay',
    19: 'Game Mechanics',
    99: 'Game Mechanics',
    25: 'Challenges',
    76: 'Visuals',
    87: 'Visuals',
    67: 'Visuals',
    56: 'Humor',
    62: 'Narrative and Story',
    22: 'Narrative and Story',
    63: 'Bugs and Glitches',
    77: 'Updates and Patches',
    21: 'Community and Collaboration',
    12: 'Cost',
    24: 'Cost',
    18: 'Content Quality',
    8: 'Quests and Adventures',
    16: 'Production and Development',
    72: 'User Feedback',
    48: 'Enjoyment and Reward'}

# %%
categories = clusters_df.groupby(clusters_df['Cluster'].map(clusters)).agg({'Words': 'sum'}).reset_index()
categories
# Out:
#                         Cluster  \
# 0             Bugs and Glitches
# 1                    Challenges
# 2                        Combat
# 3   Community and Collaboration
# 4               Content Quality
# 5                          Cost
# 6          Enjoyment and Reward
# 7                Game Mechanics
# 8                      Gameplay
# 9                         Humor
# 10          Narrative and Story
# 11   Production and Development
# 12        Quests and Adventures
# 13          Updates and Patches
# 14                User Feedback
# 15                      Visuals
#
#                                                 Words
# 0                                       [bug, glitch]
# 1   [challenge, problem, effect, reason, possibili...
# 2   [enemy, fight, battle, combat, campaign, effor...
# 3   [experience, community, work, environment, res...
# 4                  [content, quality, value, product]
# 5   [price, cost, worth, waste, purchase, payment,...
# 6   [love, choice, voice, wish, reward, hope, enjo...
# 7    [way, pace, level, point, number, class, rating]
# 8   [gameplay, gamer, gaming, rng, bonus, replay, ...
# 9     [humor, classic, vibe, gem, hint, quirk, charm]
# 10  [character, hero, genre, plot, figure, episode...
# 11  [factory, base, unit, platformer, location, pr...
# 12  [colony, quest, colonist, empire, journey, voy...
# 13  [update, feature, version, release, entry, upg...
# 14                        [review, note, view, guide]
# 15  [graphic, visual, video, pixel, color, paint, ...

# %%
categories["Words"][15]
# Out:
# ['graphic', 'visual', 'video', 'pixel', 'color', 'paint', 'light', 'ui']

# %% [markdown]
# ## Similarity

# %%
words = word_counts["word"].to_list()
nlp = spacy.load('en_core_web_md')
tokens = [nlp(word) for word in words]

# %%
categories['WordTokens'] = categories['Words'].apply(lambda words: [nlp(word) for word in words])
all_cluster_words = set(word for words in categories['Words'] for word in words)
print(all_cluster_words)

for token in tokens:
    max_similarity = 0
    best_cluster = None
    
    for idx, row in categories.iterrows():
        for word_token in row['WordTokens']:
            similarity = token.similarity(word_token)
            if similarity > max_similarity:
                max_similarity = similarity
                best_cluster = idx
    
    if max_similarity > 0.8 and str(token) not in all_cluster_words:
        categories.at[best_cluster, 'Words'].append(str(token))
        all_cluster_words.add(token)
        print(token, max_similarity, best_cluster)


categories.drop(columns=['WordTokens'], inplace=True)
print(categories)
# Out:
# {'factory', 'way', 'quirk', 'victory', 'resource', 'payment', 'focus', 'visual', 'waste', 'network', 'character', 'classic', 'color', 'history', 'charm', 'project', 'figure', 'love', 'platformer', 'backstory', 'product', 'research', 'company', 'lore', 'environment', 'rng', 'vibe', 'gameplay', 'question', 'replay', 'glitch', 'credit', 'combat', 'upgrade', 'content', 'quest', 'behavior', 'episode', 'chapter', 'production', 'version', 'base', 'quality', 'reason', 'genre', 'worth', 'praise', 'weapon', 'factor', 'buying', 'colonist', 'nature', 'plot', 'update', 'challenge', 'potential', 'number', 'review', 'level', 'gem', 'gamer', 'wish', 'humor', 'unit', 'purpose', 'vision', 'view', 'release', 'bonus', 'pixel', 'concept', 'enemy', 'campaign', 'battle', 'language', 'possibility', 'graphic', 'gaming', 'reality', 'personality', 'guide', 'reward', 'legend', 'hope', 'pleasure', 'colony', 'narrative', 'writing', 'entry', 'loot', 'paint', 'pace', 'fight', 'light', 'problem', 'hint', 'narrator', 'equipment', 'facility', 'journey', 'point', 'change', 'gun', 'launcher', 'future', 'plant', 'effort', 'perspective', 'location', 'value', 'choice', 'note', 'platform', 'workshop', 'hero', 'voice', 'chance', 'cutscene', 'community', 'empire', 'enjoyment', 'patch', 'philosophy', 'bomb', 'class', 'fortress', 'voyage', 'protagonist', 'bug', 'price', 'rating', 'experience', 'knowledge', 'practice', 'purchase', 'video', 'work', 'cue', 'ui', 'feature', 'learning', 'effect', 'cost', 'balance'}
# C:\Users\marty\AppData\Local\Temp\ipykernel_17004\914374276.py:11: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = token.similarity(word_token)
# colour 0.9479376452124644 15
# narration 0.9999999521958635 10
# foe 1.000000091474777 2
# understanding 0.8729436719411919 3
# fort 0.865434181556071 12
# consequence 0.8084028401712441 1
# launch 0.8510425976339058 13
# flair 1.0000000027919722 9
# videogame 1.0000000224913246 15
# banter 0.9470238821603723 9
# blight 0.9999999565292808 15
# context 0.821453755634528 10
# probability 0.8254659537705171 1
# humour 0.9470238821603723 9
# nostalgia 1.0000000007603036 9
# experiance 0.9999999623013374 3
# platforming 1.0000000567238878 11
# qualm 0.9999999548358158 4
# behaviour 0.9639961313515717 10
# freeplay 0.9999999933353486 8
# launching 0.8584244180310734 13
# enviroment 1.0000001066355872 3
# nuke 1.000000037681983 2
# challenging 0.8121212875770226 1
# notion 0.8127424331082946 10
# changing 0.8204466117923629 1
# challange 0.9999999569891094 1
# fighting 0.8368446792073094 2
# castle 0.8108224141068566 12
# expertise 0.8249769875954454 3
# contemplative 0.8790820566907864 10
# lightbulb 0.8197214051020465 15
# comunity 0.999999984221101 3
# questing 0.8448148714682042 1
# gunfight 1.0000000301219072 2
# waster 0.9999999231029861 5
# propensity 0.8254659537705171 1
# colorblindness 0.9999999848174648 15
# working 0.8205027318277619 3
# fightin 1.000000054510565 2
# purchaser 0.9999999476633928 5
# victoria 0.999999998636142 2
# charisma 1.0000000027919722 9
# foresight 0.8729436719411919 3
# colorblind 0.9999999848174648 15
# paintjob 0.9999999208200712 15
# combatant 1.0000000419172594 2
# gamify 0.9999999745704723 8
# busywork 0.9999999644861312 3
# nugget 0.9999999664229307 9
# conception 0.8790820566907864 10
# weaponry 0.884971682254226 2
# plotline 1.0000000349357185 10
# patching 0.8448050772677675 13
# wast 0.9999999231029861 5
# gui 0.9999999368984193 15
# chokepoint 1.0000000318811404 7
# questline 0.9999999832714055 12
# lighting 0.806565923508805 15
# practise 0.9999999622578359 3
# pricepoint 1.0000001009232535 5
# balancing 0.8331901483889774 1
# wacky 1.0000000003296143 9
# whimsy 1.0000000003296143 9
# gamepad 0.9999999933353486 8
# colourblind 0.9479376452124644 15
# viewpoint 0.8049371866917537 14
#                         Cluster  \
# 0             Bugs and Glitches
# 1                    Challenges
# 2                        Combat
# 3   Community and Collaboration
# 4               Content Quality
# 5                          Cost
# 6          Enjoyment and Reward
# 7                Game Mechanics
# 8                      Gameplay
# 9                         Humor
# 10          Narrative and Story
# 11   Production and Development
# 12        Quests and Adventures
# 13          Updates and Patches
# 14                User Feedback
# 15                      Visuals
#
#                                                 Words
# 0                                       [bug, glitch]
# 1   [challenge, problem, effect, reason, possibili...
# 2   [enemy, fight, battle, combat, campaign, effor...
# 3   [experience, community, work, environment, res...
# 4           [content, quality, value, product, qualm]
# 5   [price, cost, worth, waste, purchase, payment,...
# 6   [love, choice, voice, wish, reward, hope, enjo...
# 7   [way, pace, level, point, number, class, ratin...
# 8   [gameplay, gamer, gaming, rng, bonus, replay, ...
# 9   [humor, classic, vibe, gem, hint, quirk, charm...
# 10  [character, hero, genre, plot, figure, episode...
# 11  [factory, base, unit, platformer, location, pr...
# 12  [colony, quest, colonist, empire, journey, voy...
# 13  [update, feature, version, release, entry, upg...
# 14             [review, note, view, guide, viewpoint]
# 15  [graphic, visual, video, pixel, color, paint, ...

# %% [markdown]
# # Feature-opinion-category list
