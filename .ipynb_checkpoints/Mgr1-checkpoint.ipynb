# %%
import pandas as pd
import spacy
import steamreviews
import json
import csv
import os
import glob
import json
import matplotlib.pyplot as plt
import nltk
import wordcloud
from wordcloud import WordCloud
import re
import plotly
import seaborn as sns
import stanza
import string 

from pandas.io.json import json_normalize
from nltk.corpus import stopwords
from tqdm.notebook import trange, tqdm
from sklearn.cluster import KMeans

# %% [markdown]
# ## Reviews download
# https://pypi.org/project/steamreviews/

# %% [raw]
# list_of_app_ids = [219150, 1172620, 460950, 262060, 250320, 210970, 620, 736260,
#                    219890, 289070, 427520, 257510, 304430, 400, 394360, 550,
#                    632470, 294100, 646570, 1150690, 1341290, 1515210, 860510]
#
# def get_reviews(list_of_app_ids):
#     request_params = dict()
#     request_params['language'] = 'english'
#     request_params['day_range'] = '365'
#     request_params['filter'] = 'all'
#     for app_id in list_of_app_ids:
#         review_dict, query_count = steamreviews.download_reviews_for_app_id(app_id,chosen_request_params=request_params)
#     return review_dict, query_count
# get_reviews(list_of_app_ids);

# %%
dir_name = "data"
reviews_jsons = glob.glob(f"{dir_name}/*")
reviews_jsons
# Out:
# ['data\\review_1150690.json',
#  'data\\review_1172620.json',
#  'data\\review_1341290.json',
#  'data\\review_1515210.json',
#  'data\\review_210970.json',
#  'data\\review_219150.json',
#  'data\\review_219890.json',
#  'data\\review_250320.json',
#  'data\\review_257510.json',
#  'data\\review_262060.json',
#  'data\\review_289070.json',
#  'data\\review_294100.json',
#  'data\\review_304430.json',
#  'data\\review_394360.json',
#  'data\\review_400.json',
#  'data\\review_427520.json',
#  'data\\review_460950.json',
#  'data\\review_550.json',
#  'data\\review_620.json',
#  'data\\review_632470.json',
#  'data\\review_646570.json',
#  'data\\review_736260.json',
#  'data\\review_860510.json']

# %%
title_dict = {"219150": "Hotline Miami",
              "1172620" : "Sea of Thieves",
              "460950" : "Katana ZERO",
              "262060" : "Darkest Dungeon",
              "250320" : "The Wolf Among Us",
              "210970" : "The Witness",
              "620" : "Portal 2",
              "736260" : "Baba Is You",
              "219890" : "Antichamber",
              "289070" : "Sid Meier's Civilization VI",
              "427520" : "Factorio",
              "257510" : "The Talos Principle",
             "304430" : "INSIDE",
             "400" : "Portal",
             "394360" : "Hearts of Iron IV",
             "632470" : "Disco Elysium",
             "294100" : "RimWorld",
              "646570" : "Slay the Spire",
              "1150690" : "Omori",
              "1341290" : "We Were Here Forever",
              "1515210" : "The Past Within",
              "860510" : "Little Nightmares II",
              "550" : "Left 4 Dead 2"}

# %%
genre_dict = {"219150": "A",
              "1172620" : "A",
              "460950" : "A",
              "262060" : "R",
              "250320" : "R",
              "210970" : "P",
              "620" : "P",
              "736260" : "P",
              "219890" : "P",
              "289070" : "S",
              "427520" : "S",
              "257510" : "P",
              "304430" : "P",
             "400" : "P",
             "394360" : "S",
             "632470" : "R",
             "294100" : "S",
             "646570" : "R",
             "1150690" : "R",
             "1341290" : "P",
             "1515210" : "P",
             "860510" : "P",
             "550" : "A"}

# %%
data_list = []
for i in reviews_jsons:
    with open(i, encoding = "utf-8") as json_file:
        json_data = json.load(json_file)
        reviews = json_data['reviews']
        file_name = json_file.name.split('.')[0].split('_')[1]
        for key in reviews.keys():
            data_list.append([title_dict.get(file_name),genre_dict.get(file_name),reviews[key]['author']['steamid'], reviews[key]['votes_up'], 
                          reviews[key]['review'], reviews[key]['weighted_vote_score'], reviews[key]['voted_up'],
                          reviews[key]['author']['num_games_owned'], reviews[key]['author']['playtime_at_review'],
                          reviews[key]['author']['num_reviews'], 
                          reviews[key]["timestamp_created"] ])
df = pd.DataFrame(data_list, columns = ["title", "genre","steamid", "votes_up", "review", "weighted_vote_score", "voted_up",
                                        "num_games_owned", "playtime_at_review", "num_reviews", "timestamp_created"])

# %%
df.sample(frac=0.3).head()
# Out:
#                    title genre            steamid  votes_up  \
# 28835      Disco Elysium     R  76561198063795978         1
# 741                Omori     R  76561199259645777         1
# 8416   The Wolf Among Us     R  76561198196483657         1
# 31318        Baba Is You     P  76561198091433569         1
# 3915      Sea of Thieves     A  76561199166992851         1
#
#                                                   review  \
# 28835  One of the best and most memorable games I hav...
# 741                             mental illness: the game
# 8416   Very nice game for cold and rainy nights.\nThi...
# 31318  Baba Is You is the most innovative puzzler in ...
# 3915   very good game i wish the game can add more ga...
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 28835  0.523809552192687988      True              171                1857
# 741    0.523809552192687988      True               46                 395
# 8416   0.523809552192687988      True               47                 582
# 31318  0.525862038135528564      True              722                3352
# 3915   0.523809552192687988      True                0                4406
#
#        num_reviews  timestamp_created
# 28835            8         1695028247
# 741             15         1688129960
# 8416            11         1696269355
# 31318          497         1677892523
# 3915             1         1678095162

# %%
df['timestamp_created'] = pd.to_datetime(df['timestamp_created'], unit='s')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 1. Braki danych
# 2. Usunięcie duplikatów
# 4. Usunięcie recenzjii krótszych niż 3 słowa
# 9. Usunięcie znaków spcjalnych
# 10. "Text lowering"
# 6. Usunięcie znaków interpunkcyjnych i liczb
# 8. Usunięcie tytułów gier z recenzji
# 7. Tokenizacja
# 8. Part-of-speech tagging
# 9. Lematyzacja

# %% [markdown]
# #### Braki danych

# %%
df.isna().sum()
# Out:
# title                  0
# genre                  0
# steamid                0
# votes_up               0
# review                 0
# weighted_vote_score    0
# voted_up               0
# num_games_owned        0
# playtime_at_review     0
# num_reviews            0
# timestamp_created      0
# dtype: int64

# %% [markdown]
# #### Usunięcie duplikatów

# %%
df.duplicated(subset='review').sum()
# Out:
# 2580

# %%
df[df.duplicated(subset='review')].sample(20)
# Out:
#                    title genre            steamid  votes_up  \
# 30175      Disco Elysium     R  76561199118554152         2
# 29048      Disco Elysium     R  76561198100687027         1
# 12004           RimWorld     S  76561198436646273       427
# 4295      Sea of Thieves     A  76561198135314264         1
# 16915  Hearts of Iron IV     S  76561198325297121         1
# 17548  Hearts of Iron IV     S  76561198175898969         1
# 5505      Sea of Thieves     A  76561199026779325         1
# 15916  Hearts of Iron IV     S  76561199104879622         1
# 22531      Left 4 Dead 2     A  76561199142776774         1
# 13405           RimWorld     S  76561198064578220         1
# 7614       Hotline Miami     A  76561198809587632         1
# 15991  Hearts of Iron IV     S  76561199098632124         1
# 21359        Katana ZERO     A  76561199148943111         1
# 30848     Slay the Spire     R  76561198137777618         1
# 29124      Disco Elysium     R  76561198122262991         1
# 20106           Factorio     S  76561198859428807         1
# 16089  Hearts of Iron IV     S  76561198268561981         1
# 27767           Portal 2     P  76561198169932859         1
# 7975       Hotline Miami     A  76561199258594807         1
# 29237      Disco Elysium     R  76561199389455076         1
#
#                                                   review  \
# 30175                               Sunrise, parabellum.
# 29048                                        Good stuff.
# 12004  Got a cat here. Friends passing by can touch h...
# 4295                                           good game
# 16915                                          good game
# 17548                                           game gud
# 5505                                      best game ever
# 15916                                                fun
# 22531                                          good game
# 13405                                            rimjobs
# 7614                        I like hurting other people.
# 15991                                           very fun
# 21359                                           Very fun
# 30848                                               Good
# 29124                                                Yes
# 20106                                            its fun
# 16089                                            is nice
# 27767                                 best game on steam
# 7975                                                 mid
# 29237                                           its good
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 30175                   0.5      True                0                1745
# 29048  0.523809552192687988      True                0                4414
# 12004  0.699320077896118164      True              240                5782
# 4295   0.523809552192687988      True               41                 403
# 16915  0.518072307109832764      True                0                2189
# 17548  0.503105580806732178      True                0                2142
# 5505   0.510638296604156494      True                0               23218
# 15916  0.523809552192687988      True                0                1550
# 22531  0.523809552192687988      True                0                1520
# 13405  0.523809552192687988      True                0                4762
# 7614   0.523809552192687988      True                0                1073
# 15991  0.523809552192687988      True                0                3419
# 21359  0.523809552192687988      True                0                 228
# 30848   0.52173912525177002      True              646                5873
# 29124  0.523809552192687988      True              107                3395
# 20106  0.523809552192687988      True                0                 654
# 16089  0.523809552192687988      True               62               24030
# 27767  0.503311276435852051      True                0                 552
# 7975                    0.5      True                0                 316
# 29237  0.523809552192687988      True               19                 594
#
#        num_reviews   timestamp_created
# 30175           12 2023-09-26 04:14:00
# 29048            2 2023-03-23 04:48:08
# 12004           17 2023-03-09 17:55:12
# 4295             5 2022-12-28 14:02:12
# 16915           11 2023-01-14 02:41:09
# 17548            6 2023-09-20 02:39:11
# 5505             1 2023-07-29 01:05:38
# 15916            2 2023-05-04 21:24:15
# 22531            1 2023-09-10 08:21:35
# 13405            5 2022-11-07 04:13:48
# 7614             3 2023-07-16 18:33:11
# 15991            1 2023-03-29 22:13:29
# 21359           54 2023-02-03 05:59:28
# 30848           18 2023-08-20 18:03:55
# 29124            1 2023-02-01 05:40:22
# 20106            3 2023-02-23 22:37:34
# 16089            1 2023-02-18 11:26:25
# 27767            1 2023-08-26 20:21:30
# 7975             7 2022-11-28 15:03:42
# 29237            3 2022-12-08 19:41:35

# %%
(df.duplicated(subset='review') == False).sum()
# Out:
# 29492

# %%
df = df[df.duplicated(subset='review') == False]

# %%
df.duplicated(subset='review').sum()
# Out:
# 0

# %% [markdown]
# #### Długość recenzji

# %%
df["temp_review_len"] = df["review"].apply(lambda x: x.split(" ").__len__())
df["temp_review_len"].describe()
# Out:
# count    29492.000000
# mean        54.191984
# std        135.354534
# min          1.000000
# 25%          5.000000
# 50%         13.000000
# 75%         39.000000
# max       3997.000000
# Name: temp_review_len, dtype: float64

# %% [raw]
# df[df["temp_review_len"] == df["temp_review_len"].max()]['review'].values

# %%
df[df["temp_review_len"] < 4].groupby(by=["genre"]).count()
# Out:
#        title  steamid  votes_up  review  weighted_vote_score  voted_up  \
# genre
# A       1659     1659      1659    1659                 1659      1659
# P        852      852       852     852                  852       852
# R        798      798       798     798                  798       798
# S       1140     1140      1140    1140                 1140      1140
#
#        num_games_owned  playtime_at_review  num_reviews  timestamp_created  \
# genre
# A                 1659                1659         1659               1659
# P                  852                 852          852                852
# R                  798                 798          798                798
# S                 1140                1140         1140               1140
#
#        temp_review_len
# genre
# A                 1659
# P                  852
# R                  798
# S                 1140

# %%
df = df[df["temp_review_len"] >= 3]

# %%
suma = 0
for i in df["temp_review_len"]:
    suma += i

# %%
print("Ilość słów:", suma,
     "Ilość recenzji:", len(df["temp_review_len"]))
# Out:
# Ilość słów: 1593992 Ilość recenzji: 26663

# %%
df = df.drop(["temp_review_len"], axis=1)

# %% [markdown]
# ### Wordcloud

# %%
txt = ' '.join(i for i in df["review"])
wordcloud = WordCloud(max_font_size = 180,
                max_words = 120,
                width = 1200,
                height = 800,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "A"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "R"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "P"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "S"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# #### Usunięcie znaków, text lowering

# %%
df["review"] = df["review"].str.replace(r"\[.*?\]|\n|[^\x00-\x7F]+", "", regex=True).str.lower()

# %%
df["review"].sample(10)
# Out:
# 23126    i find left for dead 1 and 2 very fun and if y...
# 29679    best crpg ever. do not buy it until za/um retu...
# 18289    epic. but sadly no bread, i want to teleport b...
# 10600    the best strategy game ever created. they have...
# 3940     sea of thieves is awesome! the game runs great...
# 30425                   very fun and easy achievement hunt
# 15853    way too expensive unless you pay the subscript...
# 4683     reminds me of my trip to the maldivesfeels lik...
# 27389                          still goated after 12 years
# 25967                           finally found my ai waifu!
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie znaków interpunkcyjnych i liczb

# %%
df["review"] = df["review"].str.replace(r"[0-9]", "", regex=True)

# %%
df["review"] = df["review"].str.replace('['  + string.punctuation + ']', "", regex =True)

# %%
df["review"].sample(5)
# Out:
# 3789     sea of thieves professional review by proxyswe...
# 21444    you can be a drug abuser and be a cool samurai...
# 24331                                  shrek tank mod best
# 18338              damn what a good game and its cheap too
# 12246    captured a raider and imprisoned her with the ...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie tytułów gier z recenzji

# %%
for value in title_dict.values():
    df["review"] = df["review"].str.replace(value.lower(), "")

# %% [markdown]
# #### Tokenizacja

# %%
df["tokenized"] = df["review"].apply(nltk.word_tokenize)

# %%
df["tokenized"].sample(15)
# Out:
# 29284    [i, cant, believe, he, discoed, that, elysium,...
# 1697     [masterpiece, im, sobbingg, at, the, end, of, ...
# 28529    [is, a, fantastic, game, dont, buy, itreally, ...
# 17106    [this, is, a, really, great, strategy, game, t...
# 18300    [this, game, made, me, feel, dumb, as, hell, s...
# 13800    [fun, game, ive, sunk, hours, into, it, recomm...
# 8498     [never, thought, i, would, ever, enjoy, a, fai...
# 594      [i, will, be, honest, when, saying, this, game...
# 18412    [addictive, puzzle, experience, with, hidden, ...
# 21238    [the, story, was, a, bit, hard, to, follow, so...
# 1594     [an, emotional, rollercoaster, from, start, to...
# 19355    [this, review, is, negative, to, account, for,...
# 6095     [i, finally, feel, like, after, hours, in, gam...
# 28543    [i, advise, playing, this, game, however, i, d...
# 12209                        [look, at, my, played, hours]
# Name: tokenized, dtype: object

# %% [markdown]
# ### Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
english_stopwords = stopwords.words('english')
english_stopwords_cleaned = [word.replace("'", "") for word in english_stopwords]
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
new_column = []
for row in df["tokenized"]:
    new_row = [word for word in row if word[0] not in english_stopwords_cleaned]
    new_column.append(new_row)
df["final_review"] = new_column

# %% [markdown]
# ## Describe

# %%
df.dtypes
# Out:
# title                          object
# genre                          object
# steamid                        object
# votes_up                        int64
# review                         object
# weighted_vote_score            object
# voted_up                         bool
# num_games_owned                 int64
# playtime_at_review              int64
# num_reviews                     int64
# timestamp_created      datetime64[ns]
# tokenized                      object
# final_review                   object
# dtype: object

# %%
df["weighted_vote_score"] = pd.to_numeric(df["weighted_vote_score"])

# %%
df["voted_up"] = pd.to_numeric(df["voted_up"])

# %%
df.describe()
# Out:
#            votes_up  weighted_vote_score  num_games_owned  playtime_at_review  \
# count  26663.000000         26663.000000     26663.000000        2.666300e+04
# mean      31.715148             0.570098       140.866707        1.309372e+04
# std      173.097223             0.109932       538.652824        4.720263e+04
# min        0.000000             0.500000         0.000000        5.000000e+00
# 25%        1.000000             0.521739         0.000000        5.350000e+02
# 50%        1.000000             0.523810         0.000000        1.800000e+03
# 75%        3.000000             0.545180       113.000000        7.111500e+03
# max     9568.000000             0.987843     22780.000000        1.890626e+06
#
#         num_reviews
# count  26663.000000
# mean      21.467689
# std       59.809381
# min        1.000000
# 25%        3.000000
# 50%        8.000000
# 75%       20.000000
# max     3419.000000

# %%
corr = df.corr()
plt.figure(figsize=(7,5))
sns.heatmap(corr, cmap=sns.cubehelix_palette(as_cmap=True),annot=True)
plt.show()
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_6556\2159658958.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# ## Wykresy

# %%
value_counts_title = df["title"].value_counts()
genre_colors = {"A": sns.cubehelix_palette(4)[1], "R": sns.cubehelix_palette(4)[2], "P": sns.cubehelix_palette(4)[3], 
                "S": sns.cubehelix_palette(4)[0]}
df['color'] = df['genre'].map(genre_colors)
colors = [df.loc[df['title'] == title]['color'].iloc[0] for title in value_counts_title.index]

plt.figure(figsize=(12, 6))
x = value_counts_title.plot(kind = "bar", color = colors)
plt.ylabel("Ilość recenzji")
plt.xticks(rotation = 90)
for i, count in enumerate(value_counts_title):
    x.text(i, count, count, va = "bottom", ha = "center")

handles = [plt.Rectangle((0,0), 1,1, color=genre_colors[label]) for label in genre_colors]
plt.legend(handles, genre_colors.keys(), title="Gatunek", loc="upper right")


plt.show()
df = df.drop(["color"], axis=1)

# %%
value_counts_genre = df["genre"].value_counts()
colors = sns.cubehelix_palette(4)
x = plt.pie(value_counts_genre, labels = value_counts_genre.index, colors=colors, autopct='%1.2f%%')
plt.show()

# %%
value_counts_recommendation_genre = df.groupby('genre').voted_up.value_counts().unstack(0)
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 

total_count = percentage_pos + percentage_neg

def addlabels_neg(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] + 2, f"{x[i]:.2f}%",  ha = "center")

def addlabels_pos(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] - 6, f"{y[i]:.2f}%",  ha = "center")

fig, ax1 = plt.subplots(figsize=(7, 4))
ax2 = ax1.twinx()

total_count.plot(kind="bar", color="#95DBE5FF",  label="Recommended")
percentage_neg.plot(kind="bar", color="#078282FF", label="Not Recommended")

ax1.set_xlabel("Gatunki")
ax1.tick_params(axis="y", left=False, labelleft=False)
ax2.tick_params(axis="y", right=False, labelright=False)

addlabels_neg(percentage_neg, total_count) 
addlabels_pos(total_count, percentage_pos) 

plt.legend(bbox_to_anchor=(0.85, 1.15), ncol=2)
plt.show()

# %% [markdown]
# ## Dependency parser test

# %%
test = [df["final_review"][6543], df["final_review"][4534], df["final_review"][12345], df["final_review"][12354],
        df["final_review"][1925], df["final_review"][1067],df["final_review"][22951],df["final_review"][2231],
       ["not","fun", "gameplay"], df["tokenized"][832], df["final_review"][21], df["tokenized"][27061],
       df["final_review"][11088], df["final_review"][3171], df["final_review"][7834], df["final_review"][20180],
       df["final_review"][6697], df["final_review"][893]]

# %%
import stanza
nlp = stanza.Pipeline('en', tokenize_pretokenized=True) 
doc = nlp(test)
# Out:
# 2024-04-22 16:13:35 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-04-22 16:13:36 INFO: Downloaded file to C:\Users\marty\stanza_resources\resources.json
# 2024-04-22 16:13:37 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-04-22 16:13:37 INFO: Using device: cuda
# 2024-04-22 16:13:37 INFO: Loading: tokenize
# 2024-04-22 16:13:37 INFO: Loading: mwt
# 2024-04-22 16:13:39 INFO: Loading: pos
# 2024-04-22 16:13:39 INFO: Loading: lemma
# 2024-04-22 16:13:39 INFO: Loading: constituency
# 2024-04-22 16:13:40 INFO: Loading: depparse
# 2024-04-22 16:13:40 INFO: Loading: sentiment
# 2024-04-22 16:13:40 INFO: Loading: ner
# 2024-04-22 16:13:41 INFO: Done loading processors!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [195], line 3
#       1 import stanza
#       2 nlp = stanza.Pipeline('en', tokenize_pretokenized=True)
# ----> 3 doc = nlp(test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stanza\pipeline\core.py:477, in Pipeline.__call__(self, doc, processors)
#     476 def __call__(self, doc, processors=None):
# --> 477     return self.process(doc, processors)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stanza\pipeline\core.py:428, in Pipeline.process(self, doc, processors)
#     426     if self.processors.get(processor_name):
#     427         process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 428         doc = process(doc)
#     429 return doc
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stanza\pipeline\ner_processor.py:114, in NERProcessor.process(self, document)
#     112         preds = []
#     113         for i, b in enumerate(batch):
# --> 114             preds += trainer.predict(b)
#     115         all_preds.append(preds)
#     116 # for each sentence, gather a list of predictions
#     117 # merge those predictions into a single list
#     118 # earlier models will have precedence
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stanza\models\ner\trainer.py:144, in Trainer.predict(self, batch, unsort)
#     142 self.model.eval()
#     143 #batch_size = word.size(0)
# --> 144 _, logits, trans = self.model(word, wordchars, wordchars_mask, tags, word_orig_idx, sentlens, wordlens, chars, charoffsets, charlens, char_orig_idx)
#     146 # decode
#     147 # TODO: might need to decode multiple columns of output for
#     148 # models with multiple layers
#     149 trans = [x.data.cpu().numpy() for x in trans]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stanza\models\ner\model.py:224, in NERTagger.forward(self, sentences, wordchars, wordchars_mask, tags, word_orig_idx, sentlens, wordlens, chars, charoffsets, charlens, char_orig_idx)
#     222 if self.args['char'] and self.args['char_emb_dim'] > 0:
#     223     if self.args.get('charlm', None):
# --> 224         char_reps_forward = self.charmodel_forward.get_representation(chars[0], charoffsets[0], charlens, char_orig_idx)
#     225         char_reps_forward = PackedSequence(char_reps_forward.data, char_reps_forward.batch_sizes)
#     226         char_reps_backward = self.charmodel_backward.get_representation(chars[1], charoffsets[1], charlens, char_orig_idx)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stanza\models\common\char_model.py:161, in CharacterLanguageModel.get_representation(self, chars, charoffsets, charlens, char_orig_idx)
#     159 with torch.no_grad():
#     160     output, _, _ = self.forward(chars, charlens)
# --> 161     res = [output[i, offsets] for i, offsets in enumerate(charoffsets)]
#     162     res = unsort(res, char_orig_idx)
#     163     res = pack_sequence(res)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stanza\models\common\char_model.py:161, in <listcomp>(.0)
#     159 with torch.no_grad():
#     160     output, _, _ = self.forward(chars, charlens)
# --> 161     res = [output[i, offsets] for i, offsets in enumerate(charoffsets)]
#     162     res = unsort(res, char_orig_idx)
#     163     res = pack_sequence(res)
#
# KeyboardInterrupt:

# %%
dependency_list = []
for dependency in doc.sentences[13].dependencies:
    dependency_list.append([dependency[2].text, dependency[0].id, dependency[1]])
    
for i in range(0, len(dependency_list)):
    if (int(dependency_list[i][1]) != 0):
        dependency_list[i][1] = test[13][(int(dependency_list[i][1]) - 1)]

print(*dependency_list[:20], sep='\n')
# Out:
# ['crewing', 0, 'root']
# ['game', 'value', 'compound']
# ['value', 'crewing', 'obj']
# ['likely', 'crewing', 'advmod']
# ['worthless', 'crewing', 'xcomp']
# ['real', 'crewing', 'xcomp']
# ['but', 'play', 'cc']
# ['can', 'play', 'aux']
# ['play', 'crewing', 'conj']
# ['player', 'play', 'obj']
# ['but', 'want', 'cc']
# ['cant', 'want', 'aux']
# ['really', 'want', 'advmod']
# ['want', 'crewing', 'conj']
# ['like', 'graphics', 'discourse']
# ['game', 'fun', 'compound']
# ['fun', 'graphics', 'amod']
# ['graphics', 'want', 'obj']
# ['basic', 'want', 'xcomp']
# ['but', 'have', 'cc']

# %%
feature_list = []
feature_opinion_list = [] 

for dependency in doc.sentences[13].dependencies:
    if dependency[2].xpos == "RB":
        opinion_word = dependency[2]
        rb_adj = dependency[0]
        
    if (dependency[2].xpos in ["NN", "NNS", "JJ", "JJS", "JJR"]) and (dependency[1] in ["amod"]):
        if dependency[0] == rb_adj or dependency[2] == rb_adj:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}     
        else:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}  

        feature_list.append(dependency[0].lemma)
        feature_opinion_list.append(result_dict)

print(f'Feature list: {feature_list}')
print(f'Feature-opinion list: {feature_opinion_list}')
# Out:
# Feature list: ['graphic', 'beauty', 'player', 'player', 'player', 'guide', 'reward', 'reward', 'reward']
# Feature-opinion list: [{'feature': 'graphic', 'opinion': 'fun'}, {'feature': 'beauty', 'opinion': 'real'}, {'feature': 'player', 'opinion': 'unbalanced'}, {'feature': 'player', 'opinion': 'janky'}, {'feature': 'player', 'opinion': 'human'}, {'feature': 'guide', 'opinion': 'necessary'}, {'feature': 'reward', 'opinion': 'risky'}, {'feature': 'reward', 'opinion': 'lowest'}, {'feature': 'reward', 'opinion': 'highest'}]

# %% [markdown]
# ## Dependency parser final

# %% [raw]
# feature_list_column = []
# feature_opinion_list_column = []
#
# for review in tqdm(df["final_review"]):
#     if isinstance(review, list):
#         review = " ".join(review)
#         doc = nlp(review)
#         feature_list = []
#         feature_opinion_list = []
#
#         if len(doc.sentences) == 0:
#             continue
#
#         for dependency in doc.sentences[0].dependencies:
#             if dependency[2].xpos == "RB":
#                 opinion_word = dependency[2]
#                 rb_adj = dependency[0]
#             if (dependency[2].xpos in ["JJ", "JJS"]) and (dependency[0].xpos in ["NN", "NNS"]) and (dependency[1] in ["amod"]):
#
#                 if dependency[0] == rb_adj or dependency[2] == rb_adj:
#                     if dependency[2].xpos in ["JJS", "JJR"]:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
#                     else:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}
#                 else:
#                     if dependency[2].xpos in ["JJS", "JJR"]:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
#                     else:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}
#
#                 feature_list.append(dependency[0].lemma)
#                 feature_opinion_list.append(result_dict)
#
#     feature_list_column.append(feature_list)
#     feature_opinion_list_column.append([review, feature_opinion_list])
#
# df["feature"] = [feature_list_column]
# df["feature_opinion_list"] = [feature_opinion_list_column]

# %% [raw]
# new_df = pd.DataFrame([feature_list_column, feature_opinion_list_column])
# new_df.T
#
# non_empty_indexes = df[df["final_review"].apply(lambda x: len(x)!=0)].index
#
# import json
# opinions_dict = {k:v for k, v in zip(non_empty_indexes, feature_opinion_list_column)}
# out_file = open("opinions.json", "w")
#
# json.dump(opinions_dict, out_file, indent = 6)
#
# out_file.close()

# %%
with open('opinions.json', 'r') as file:
    dct = json.load(file)

# %%
feature_list = []

for i in range(len(df)):
    index = str(i)  
    feature = dct.get(index)
    if feature is None:
        feature_list.append([])
    else:
        feature_list.append(feature)

df["feature"] = feature_list

# %%
df = df[df["feature"].apply(lambda x: len(x) > 0)]

# %% [markdown]
# ## Word embedding

# %% [raw]
# import spacy
# from sklearn.metrics.pairwise import cosine_similarity
#
# nlp = spacy.load('en_core_web_md')

# %% [raw]
# word_embeddings = [nlp(word).vector for word in words]
#
# similarity_matrix = cosine_similarity(word_embeddings)
#
# threshold = 0.3
#
# groups = {}
# for i, word in tqdm(enumerate(words)):
#     for j in range(i + 1, len(words)):
#         if similarity_matrix[i][j] > threshold:
#             if word not in groups:
#                 groups[word] = [words[j]]
#             else:
#                 groups[word].append(words[j])
#
# for word, similar_words in groups.items():
#     print(f"Group for '{word}'")

# %% [markdown]
# ## Correct misspeld words

# %% [raw]
# from textblob import TextBlob
#
# for inner_list in tqdm(df["feature"]):
#     for dictionary in inner_list:
#         for key, value in dictionary.items():
#             if isinstance(value, str):
#                 blob = TextBlob(value)
#                 corrected_text = str(blob.correct())
#                 dictionary[key] = corrected_text

# %% [raw]
# unique_values = set()
# for inner_list in tqdm(df["feature"]):
#     for dictionary in inner_list:
#         for key, value in dictionary.items():
#             if isinstance(value, str):
#                 unique_values.add(value)
#
# corrected_values = {}
# for value in tqdm(unique_values):
#     blob = TextBlob(value)
#     corrected_text = str(blob.correct())
#     corrected_values[value] = corrected_text
#
# for inner_list in tqdm(df["feature"]):
#     for dictionary in inner_list:
#         for key, value in dictionary.items():
#             if isinstance(value, str):
#                 dictionary[key] = corrected_values[value]

# %%
words = []
for i in df["feature"]:
    for j in i:
        words.append(j["feature"])

# %% [markdown]
# ## Similarity

# %% [raw]
# unique_words = list(set(words))
# word_counts = pd.DataFrame([[i, len([q for q in words if q==i])] for i in unique_words],
#               columns=['word', 'count']).sort_values('count', ascending=False)
# popular_words = word_counts[word_counts['count']>=10]["word"].to_list()
#
# nlp = spacy.load('en_core_web_md')
# tokens = [nlp(word) for word in popular_words]
#
# for i in tokens:
#     for j in tokens:
#          if i.similarity(j) > 0.75 and i.similarity(j) <1:
#             print(round(i.similarity(j), 2), i,j)

# %% [markdown]
# ### Word counts

# %%
unique_words = list(set(words))

# %%
word_counts = pd.DataFrame([[i, len([q for q in words if q==i])] for i in unique_words], 
              columns=['word', 'count']).sort_values('count', ascending=False)

# %% [markdown]
# ## K-means

# %%
popular_words = word_counts[word_counts['count']>=15]["word"].to_list()
nlp = spacy.load('en_core_web_md')
tokens = [nlp(word) for word in popular_words]
word_vectors = pd.DataFrame([i.vector for i in tokens])

# %%
inertias = []
for i in range(1,40, 2):
    kmeans = KMeans(n_clusters=i, init='k-means++', n_init = 100, random_state=3)
    kmeans.fit(word_vectors)
    inertias.append(kmeans.inertia_)
    
plt.plot(range(1,40, 2), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
kmeans = KMeans(n_clusters=46, init='k-means++', n_init = 10000, random_state=3)

kmeans.fit(word_vectors)
pred = kmeans.predict(word_vectors)

clustered_words = pd.DataFrame([[str(i) for i in tokens], pred], index=['word', 'cluster']).T

for ind, cl in clustered_words.groupby('cluster'):
    print(f'=====================================\nCluster no:{ind}')
    print(*cl['word'], sep='\n')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [311], line 3
#       1 kmeans = KMeans(n_clusters=46, init='k-means++', n_init = 10000, random_state=3)
# ----> 3 kmeans.fit(word_vectors)
#       4 pred = kmeans.predict(word_vectors)
#       6 clustered_words = pd.DataFrame([[str(i) for i in tokens], pred], index=['word', 'cluster']).T
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1461, in KMeans.fit(self, X, y, sample_weight)
#    1457 best_inertia, best_labels = None, None
#    1459 for i in range(self._n_init):
#    1460     # Initialize centers
# -> 1461     centers_init = self._init_centroids(
#    1462         X, x_squared_norms=x_squared_norms, init=init, random_state=random_state
#    1463     )
#    1464     if self.verbose:
#    1465         print("Initialization complete")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:989, in _BaseKMeans._init_centroids(self, X, x_squared_norms, init, random_state, init_size, n_centroids)
#     986     n_samples = X.shape[0]
#     988 if isinstance(init, str) and init == "k-means++":
# --> 989     centers, _ = _kmeans_plusplus(
#     990         X,
#     991         n_clusters,
#     992         random_state=random_state,
#     993         x_squared_norms=x_squared_norms,
#     994     )
#     995 elif isinstance(init, str) and init == "random":
#     996     seeds = random_state.permutation(n_samples)[:n_clusters]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:234, in _kmeans_plusplus(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     231 np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)
#     233 # Compute distances to center candidates
# --> 234 distance_to_candidates = _euclidean_distances(
#     235     X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True
#     236 )
#     238 # update closest distances squared and potential for each candidate
#     239 np.minimum(closest_dist_sq, distance_to_candidates, out=distance_to_candidates)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\pairwise.py:366, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     361         YY = row_norms(Y, squared=True)[np.newaxis, :]
#     363 if X.dtype == np.float32:
#     364     # To minimize precision issues with float32, we compute the distance
#     365     # matrix on chunks of X and Y upcast to float64
# --> 366     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     367 else:
#     368     # if dtype is already float64, no need to chunk and upcast
#     369     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\pairwise.py:568, in _euclidean_distances_upcast(X, XX, Y, YY, batch_size)
#     565 else:
#     566     YY_chunk = YY[:, y_slice]
# --> 568 d = -2 * safe_sparse_dot(X_chunk, Y_chunk.T, dense_output=True)
#     569 d += XX_chunk
#     570 d += YY_chunk
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\extmath.py:192, in safe_sparse_dot(a, b, dense_output)
#     188 else:
#     189     ret = a @ b
#     191 if (
# --> 192     sparse.issparse(a)
#     193     and sparse.issparse(b)
#     194     and dense_output
#     195     and hasattr(ret, "toarray")
#     196 ):
#     197     return ret.toarray()
#     198 return ret
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\_base.py:1483, in issparse(x)
#    1478     pass
#    1480 sparray.__doc__ = _spbase.__doc__
# -> 1483 def issparse(x):
#    1484     """Is `x` of a sparse array or sparse matrix type?
#    1485
#    1486     Parameters
#    (...)
#    1507     False
#    1508     """
#    1509     return isinstance(x, _spbase)
#
# KeyboardInterrupt:

# %%
def process_clusters(clustered_words, cluster_mapping):
    allfeature = []
    lists = {key: [] for key in cluster_mapping.keys()}

    for ind, cl in clustered_words.groupby("cluster"):
        for key, value in cluster_mapping.items():
            if ind in value:
                lists[key].extend(cl["word"])
                allfeature.extend(cl["word"])

    return lists, allfeature

cluster_mapping = {
    "price": [5],
    "backstory": [6],
    "play":[15],
    "graphic":[35],
    "combat": [10, 18, 24, 45],
    "building": [7, 25],
    "people": [14],
    "emotion": [31],
    "journey":[37],
    "world":[40],
    "bugs":[44]}

# %%
for i in process_clusters(clustered_words, cluster_mapping)
# Out:
# price
# backstory
# play
# graphic
# combat
# building
# people
# emotion
# journey
# world
# bugs
# civ
# pvp
# pc
# ld
# bit
# room
# line
# piece
# hand
# chamber
# pack
# wall
# valve
# front
# curve
# loop
# pixel
# paint
# box
# leg
# cup
# layer
# button
# hat
# edge
# length
# belt
# head
# fit
# corner
# chest
# floor
# bone
# hook
# patch
# colony
# colonist
# rule
# period
# era
# land
# fortress
# run
# wait
# buy
# break
# pass
# finish
# find
# hit
# leave
# kill
# fix
# pick
# beat
# back
# point
# problem
# quest
# reason
# fact
# question
# word
# note
# case
# crime
# complaint
# conclusion
# call
# lack
# error
# confession
# flaw
# comment
# warning
# care
# health
# gold

# %%
uncategorized_words = []
for i in popular_words:
    if i not in process_clusters(clustered_words, cluster_mapping):
        uncategorized_words.append(i)

# %%
nlp = spacy.load('en_core_web_md')
tokens = [nlp(word) for word in uncategorized_words]
word_vectors = pd.DataFrame([i.vector for i in tokens])

# %% [markdown]
# ## Categories

# %%
building = []
combat = []
graphic = []
feel = []
price = []
people = []
allfeature = []

for ind, cl in clustered_words.groupby('cluster'):
    if ind == 0:
        price.extend(cl['word'])
        allfeature.extend(cl['word'])
    if ind == 15:
        feel.append(cl["word"])
        allfeature.extend(cl['word'])
    if ind == 20:
        graphic.append(cl["word"])
        allfeature.extend(cl['word'])
    if ind == 24:
        combat.append(cl["word"])
        allfeature.extend(cl['word'])
    if ind == 26:
        building.append(cl["word"])
        allfeature.extend(cl['word'])
    if ind == 27:
        people.append(cl["word"])
        allfeature.extend(cl['word'])
    if ind == 5 or ind == 8 or ind == 16 or ind == 25 or ind == 34:
        allfeature.extend(cl['word'])

print(allfeature)
# Out:
# ['colony', 'place', 'colonist', 'lake', 'city', 'empire', 'country', 'landscape', 'period', 'family', 'winter', 'land', 'fortress', 'rollercoaster', 'region', 'house', 'remains', 'farm', 'home', 'fort', 'run', 'go', 'way', 'love', 'fun', 'nothing', 'everything', 'job', 'choice', 'reason', 'feel', 'feeling', 'everyone', 'reward', 'hope', 'chance', 'heart', 'kind', 'joy', 'fear', 'pain', 'pleasure', 'charm', 'praise', 'excitement', 'evil', 'wonder', 'good', 'enemy', 'fight', 'battle', 'combat', 'weapon', 'raid', 'crime', 'crash', 'gun', 'fire', 'raider', 'kill', 'bomb', 'rocket', 'killer', 'warfare', 'killing', 'foe', 'cannon', 'explosion', 'escape', 'room', 'wall', 'floor', 'bar', 'cake', 'food', 'cup', 'egg', 'potato', 'pie', 'crust', 'rum', 'ld', 'ps', 'h', 'need', 'wish', 'want', 'can', 'will', 'let', 'journey', 'path', 'ride', 'route', 'road', 'vi', 'experience', 'person', 'world', 'life', 'challenge', 'problem', 'concept', 'possibility', 'fact', 'change', 'encounter', 'emotion', 'history', 'course', 'focus', 'writing', 'brain', 'planet', 'knowledge', 'personality', 'being', 'universe', 'future', 'cheater', 'nature', 'philosophy', 'conversation', 'language', 'view', 'reality', 'lack', 'background', 'perspective', 'relationship', 'enjoyment', 'vision', 'creature', 'complexity', 'practice', 'learning', 'physics', 'behavior', 'humanity', 'paradox', 'glance', 'earth', 'existence', 'understanding', 'past', 'expression', 'human', 'creativity', 'regard', 'logic', 'essence', 'consequence']
