# %%
import pandas as pd
import spacy
import steamreviews
import json
import csv
import os
import glob
import json
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import wordcloud
from wordcloud import WordCloud
import re
import plotly
import seaborn as sns
import stanza

# %% [markdown]
# ## Reviews download
# https://pypi.org/project/steamreviews/

# %% [raw]
# list_of_app_ids = [219150, 1172620, 460950, 262060, 250320, 210970, 620, 736260,
#                    219890, 289070, 427520, 257510, 304430, 400, 394360, 550,
#                    632470, 294100, 646570, 1150690, 1341290, 1515210, 860510]
#
# def get_reviews(list_of_app_ids):
#     request_params = dict()
#     request_params['language'] = 'english'
#     request_params['day_range'] = '365'
#     request_params['filter'] = 'all'
#     for app_id in list_of_app_ids:
#         review_dict, query_count = steamreviews.download_reviews_for_app_id(app_id,chosen_request_params=request_params)
#     return review_dict, query_count
# get_reviews(list_of_app_ids);

# %%
dir_name = "data"
reviews_jsons = glob.glob(f"{dir_name}/*")
reviews_jsons
# Out:
# ['data\\review_1150690.json',
#  'data\\review_1172620.json',
#  'data\\review_1341290.json',
#  'data\\review_1515210.json',
#  'data\\review_210970.json',
#  'data\\review_219150.json',
#  'data\\review_219890.json',
#  'data\\review_250320.json',
#  'data\\review_257510.json',
#  'data\\review_262060.json',
#  'data\\review_289070.json',
#  'data\\review_294100.json',
#  'data\\review_304430.json',
#  'data\\review_394360.json',
#  'data\\review_400.json',
#  'data\\review_427520.json',
#  'data\\review_460950.json',
#  'data\\review_550.json',
#  'data\\review_620.json',
#  'data\\review_632470.json',
#  'data\\review_646570.json',
#  'data\\review_736260.json',
#  'data\\review_860510.json']

# %%
title_dict = {"219150": "Hotline Miami",
              "1172620" : "Sea of Thieves",
              "460950" : "Katana ZERO",
              "262060" : "Darkest Dungeon",
              "250320" : "The Wolf Among Us",
              "210970" : "The Witness",
              "620" : "Portal 2",
              "736260" : "Baba Is You",
              "219890" : "Antichamber",
              "289070" : "Sid Meier's Civilization VI",
              "427520" : "Factorio",
              "257510" : "The Talos Principle",
             "304430" : "INSIDE",
             "400" : "Portal",
             "394360" : "Hearts of Iron IV",
             "632470" : "Disco Elysium",
             "294100" : "RimWorld",
              "646570" : "Slay the Spire",
              "1150690" : "Omori",
              "1341290" : "We Were Here Forever",
              "1515210" : "The Past Within",
              "860510" : "Little Nightmares II",
              "550" : "Left 4 Dead 2"}

# %%
genre_dict = {"219150": "A",
              "1172620" : "A",
              "460950" : "A",
              "262060" : "R",
              "250320" : "R",
              "210970" : "P",
              "620" : "P",
              "736260" : "P",
              "219890" : "P",
              "289070" : "S",
              "427520" : "S",
              "257510" : "P",
              "304430" : "P",
             "400" : "P",
             "394360" : "S",
             "632470" : "R",
             "294100" : "S",
             "646570" : "R",
             "1150690" : "R",
             "1341290" : "P",
             "1515210" : "P",
             "860510" : "P",
             "550" : "A"}

# %%
data_list = []
for i in reviews_jsons:
    with open(i, encoding = "utf-8") as json_file:
        json_data = json.load(json_file)
        reviews = json_data['reviews']
        file_name = json_file.name.split('.')[0].split('_')[1]
        for key in reviews.keys():
            data_list.append([title_dict.get(file_name),genre_dict.get(file_name),reviews[key]['author']['steamid'], reviews[key]['votes_up'], 
                          reviews[key]['review'], reviews[key]['weighted_vote_score'], reviews[key]['voted_up'],
                          reviews[key]['author']['num_games_owned'], reviews[key]['author']['playtime_at_review'],
                          reviews[key]['author']['num_reviews'], 
                          reviews[key]["timestamp_created"] ])
df = pd.DataFrame(data_list, columns = ["title", "genre","steamid", "votes_up", "review", "weighted_vote_score", "voted_up",
                                        "num_games_owned", "playtime_at_review", "num_reviews", "timestamp_created"])

# %% [markdown]
# ## Wykresy

# %%
value_counts_title = df["title"].value_counts()
genre_colors = {"A": "mistyrose", "R": "palevioletred", "P": "thistle", "S": "pink"}
df['color'] = df['genre'].map(genre_colors)
colors = [df.loc[df['title'] == title]['color'].iloc[0] for title in value_counts_title.index]

plt.figure(figsize=(12, 6))
x = value_counts_title.plot(kind = "bar", color = colors)
plt.ylabel("Ilość recenzji")
plt.xticks(rotation = 90)
for i, count in enumerate(value_counts_title):
    x.text(i, count, count, va = "bottom", ha = "center")

plt.show()

# %%
value_counts_genre = df["genre"].value_counts()
colors = ["pink", "mistyrose", "palevioletred", "thistle"]
x = plt.pie(value_counts_genre, labels = value_counts_genre.index, colors=colors, autopct='%1.2f%%')
plt.show()

# %%
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 

total_count = percentage_pos + percentage_neg

def addlabels_neg(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] + 2, f"{x[i]:.2f}%",  ha = "center")

def addlabels_pos(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] - 6, f"{y[i]:.2f}%",  ha = "center")

fig, ax1 = plt.subplots(figsize=(7, 4))
ax2 = ax1.twinx()

total_count.plot(kind="bar", color="pink",  label="Recommended")
percentage_neg.plot(kind="bar", color="lightcoral", label="Not Recommended")

ax1.set_xlabel("Gatunki")
ax1.tick_params(axis="y", left=False, labelleft=False)
ax2.tick_params(axis="y", right=False, labelright=False)

addlabels_neg(percentage_neg, total_count) 
addlabels_pos(total_count, percentage_pos) 

plt.legend(bbox_to_anchor=(0.75, 1.15), ncol=2)
plt.show()

# %%
df.sample(frac=0.3).head()
# Out:
#                title genre            steamid  votes_up  \
# 27522       Portal 2     P  76561198274280761         2
# 26465       Portal 2     P  76561198358243791         1
# 28400  Disco Elysium     R  76561198059971364         3
# 19123         Portal     P  76561198367467273        69
# 23693  Left 4 Dead 2     A  76561199211792573         1
#
#                                                   review  \
# 27522                            HAHA CHAMBEr 10 IS NOOB
# 26465   pretty good game\nplayed it 5 times going for 10
# 28400  Finally I can be racist besides on Discord :DD...
# 19123                  Buy it. For science. You monster.
# 23693  good way to shoot something without going to j...
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 27522   0.52173912525177002      True                0               44388
# 26465  0.523809552192687988      True              101                3508
# 28400  0.547692298889160156      True              260                1808
# 19123  0.794758915901184082      True              280                1570
# 23693  0.523809552192687988      True               15                6348
#
#        num_reviews  timestamp_created          color
# 27522            1         1665388688        thistle
# 26465            3         1683856043        thistle
# 28400            5         1683347575  palevioletred
# 19123           25         1625394246        thistle
# 23693            1         1675128339      mistyrose

# %%
df['timestamp_created'] = pd.to_datetime(df['timestamp_created'], unit='s')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 1. Braki danych
# 2. Usunięcie duplikatów
# 4. Usunięcie recenzjii krótszych niż 3 słowa
# 9. Usunięcie znaków spcjalnych
# 10. "Text lowering"
# 6. Usunięcie znaków interpunkcyjnych i liczb
# 7. Tokenizacja
# 8. Part-of-speech tagging
# 9. Lematyzacja

# %% [markdown]
# #### Braki danych

# %%
df.isna().sum()
# Out:
# title                  0
# genre                  0
# steamid                0
# votes_up               0
# review                 0
# weighted_vote_score    0
# voted_up               0
# num_games_owned        0
# playtime_at_review     0
# num_reviews            0
# timestamp_created      0
# color                  0
# dtype: int64

# %% [markdown]
# #### Usunięcie duplikatów

# %%
df.duplicated(subset='review').sum()
# Out:
# 2580

# %%
df[df.duplicated(subset='review')].sample(59)
# Out:
#                              title genre            steamid  votes_up  \
# 14077                     RimWorld     S  76561198254875470         1
# 10565  Sid Meier's Civilization VI     S  76561199092724665         1
# 10559  Sid Meier's Civilization VI     S  76561198963845303         1
# 3387                Sea of Thieves     A  76561199005504152         1
# 22981                Left 4 Dead 2     A  76561197967396758         1
# 27689                     Portal 2     P  76561198329995632         1
# 25249                Left 4 Dead 2     A  76561199222031035         1
# 10217  Sid Meier's Civilization VI     S  76561198108341834         1
# 19964                     Factorio     S  76561198967779780         1
# 1920                         Omori     R  76561199022927094         1
# 27354                     Portal 2     P  76561199382346137         1
# 13944                     RimWorld     S  76561197993331290         1
# 18683                       Portal     P  76561198881091564         1
# 27409                     Portal 2     P  76561198361442040         1
# 17441            Hearts of Iron IV     S  76561198313063244         1
# 23584                Left 4 Dead 2     A  76561199100169272         1
# 12802                     RimWorld     S  76561199028650175         1
# 7616                 Hotline Miami     A  76561198452555618         1
# 1383                         Omori     R  76561199085554047         1
# 13405                     RimWorld     S  76561198064578220         1
# 12712                     RimWorld     S  76561198035500398         1
# 27364                     Portal 2     P  76561198881977759         2
# 18187                       Portal     P  76561199454609182         1
# 26757                     Portal 2     P  76561199367697606         1
# 27619                     Portal 2     P  76561198058825425         1
# 23080                Left 4 Dead 2     A  76561199445850642         1
# 27312                     Portal 2     P  76561198879310981         1
# 18897                       Portal     P  76561199261788063         1
# 17550            Hearts of Iron IV     S  76561198406766827         1
# 22051                Left 4 Dead 2     A  76561198092033378         2
# 24887                Left 4 Dead 2     A  76561199445637179         1
# 23387                Left 4 Dead 2     A  76561198073095484         1
# 12456                     RimWorld     S  76561198806739566         1
# 19532                     Factorio     S  76561198008388529         2
# 27182                     Portal 2     P  76561199020114397         1
# 22828                Left 4 Dead 2     A  76561199198407894         1
# 1054                         Omori     R  76561199229544460         2
# 21659                  Katana ZERO     A  76561198306123137       103
# 4348                Sea of Thieves     A  76561198035910223         1
# 25600                Left 4 Dead 2     A  76561198339996158         1
# 13910                     RimWorld     S  76561198806214173         1
# 3284                Sea of Thieves     A  76561199106647381         1
# 29246                Disco Elysium     R  76561198012184566         1
# 18057                       Portal     P  76561197974151010         2
# 3856                Sea of Thieves     A  76561199131562050         1
# 22440                Left 4 Dead 2     A  76561199043970227         1
# 27717                     Portal 2     P  76561198288550994         1
# 26855                     Portal 2     P  76561199436172775         1
# 23467                Left 4 Dead 2     A  76561198851331628         1
# 17471            Hearts of Iron IV     S  76561199086850899         1
# 30482               Slay the Spire     R  76561198141302430         1
# 25663                Left 4 Dead 2     A  76561198239886930       373
# 15739            Hearts of Iron IV     S  76561199298659520         1
# 22254                Left 4 Dead 2     A  76561198809729007         4
# 19660                     Factorio     S  76561198068992027         1
# 3912                Sea of Thieves     A  76561199029630442         1
# 13590                     RimWorld     S  76561198028242686         1
# 12680                     RimWorld     S  76561198045737669         1
# 31271                  Baba Is You     P  76561198137349289        14
#
#                                   review   weighted_vote_score  voted_up  \
# 14077                       it's alright  0.514285683631896973      True
# 10565                               good  0.523809552192687988      True
# 10559                          good game  0.523809552192687988      True
# 3387                                boat  0.523809552192687988      True
# 22981                          i like it  0.523809552192687988      True
# 27689                     please add sex  0.512820541858673096      True
# 25249                                FUN  0.514592766761779785      True
# 10217                                  .  0.525862038135528564      True
# 19964                         great game  0.523809552192687988      True
# 1920                           miserable  0.505494534969329834      True
# 27354                     Very good game   0.52173912525177002      True
# 13944               War crimes simulator  0.519230782985687256      True
# 18683                             no sex  0.523809552192687988     False
# 27409                               cake   0.52173912525177002      True
# 17441                          good game  0.504504501819610596      True
# 23584                            is good  0.523809552192687988      True
# 12802                         great game  0.523809552192687988      True
# 7616                            gud game  0.523809552192687988      True
# 1383                          depression  0.523809552192687988      True
# 13405                            rimjobs  0.523809552192687988      True
# 12712                            It's ok  0.523809552192687988      True
# 27364  One of the best games of all time   0.52173912525177002      True
# 18187                   Aperture Science  0.523809552192687988      True
# 26757                              funny  0.523809552192687988      True
# 27619               absolute masterpiece  0.518518567085266113      True
# 23080                            play it  0.523809552192687988      True
# 27312                           portal 2  0.523809552192687988      True
# 18897                               Good  0.519999980926513672      True
# 17550                             no sex  0.503105580806732178     False
# 22051                                 :)  0.545454561710357666      True
# 24887                                 gg   0.52173912525177002      True
# 23387                             banger  0.523809552192687988      True
# 12456                                yes  0.525862038135528564      True
# 19532               I want my life back.  0.540636062622070313      True
# 27182                     very good game  0.523809552192687988      True
# 22828                         pills here  0.523809552192687988      True
# 1054                                omor  0.523809552192687988      True
# 21659             Yeah, that should work  0.837453544139862061      True
# 4348                               booty  0.523809552192687988      True
# 25600                                 no                   0.5      True
# 13910                         great game  0.519999980926513672      True
# 3284                            It's fun  0.523809552192687988      True
# 29246                     big brain game  0.523809552192687988      True
# 18057                          Good game  0.530201315879821777      True
# 3856                                   e  0.523809552192687988      True
# 22440                             W game  0.523809552192687988      True
# 27717                               Good  0.508928596973419189      True
# 26855                                  .  0.523809552192687988      True
# 23467                           The GOAT  0.523809552192687988      True
# 17471                          Good game  0.504132270812988281      True
# 30482                            is good  0.525316417217254639      True
# 25663                    My wife left me  0.910686373710632324      True
# 15739                     Very good game  0.523809552192687988      True
# 22254                             autism  0.538831770420074463     False
# 19660                      virtual crack  0.525862038135528564      True
# 3912                              pirate  0.523809552192687988      True
# 13590                    Best game ever.  0.522058844566345215      True
# 12680                                gud  0.523809552192687988      True
# 31271                                  👍    0.6119803786277771      True
#
#        num_games_owned  playtime_at_review  num_reviews   timestamp_created  \
# 14077                0               33410            4 2022-11-25 01:29:14
# 10565                0                 187            7 2023-02-24 11:43:51
# 10559               98                 311           31 2023-02-26 00:14:13
# 3387                 0                4520            3 2023-07-07 23:12:18
# 22981                0                 275           25 2023-06-10 23:18:25
# 27689              329                 537           65 2022-10-19 06:05:17
# 25249               26                 874            1 2023-06-15 23:18:11
# 10217                0                9299            1 2023-02-20 17:48:57
# 19964                0                9052            5 2023-04-29 06:38:07
# 1920                36                1353            8 2023-03-27 20:14:52
# 27354                0                 388            6 2023-08-05 17:26:44
# 13944                0               17526            2 2023-03-17 03:38:47
# 18683               62                 227           10 2022-12-02 19:15:31
# 27409              118                 520           33 2023-04-13 13:26:42
# 17441               59               23493            3 2023-03-22 15:56:09
# 23584               24                7415            4 2023-02-16 21:01:07
# 12802              153                2762           19 2023-05-08 03:40:49
# 7616                81                 363           25 2023-07-14 23:48:44
# 1383                 0                2911            3 2022-11-20 21:02:13
# 13405                0                4762            5 2022-11-07 04:13:48
# 12712                0               60042           14 2023-06-29 19:38:28
# 27364              183                1023           14 2023-07-11 03:44:47
# 18187                0                1081           16 2023-07-29 07:11:44
# 26757              410                 493          504 2023-02-21 14:22:24
# 27619              321                 967           21 2023-01-01 04:34:38
# 23080                0                 214            4 2023-05-15 17:42:05
# 27312                0                 661           16 2022-10-07 16:17:30
# 18897                0                 424           12 2022-11-17 01:28:14
# 17550               86                1246           22 2023-06-21 21:13:01
# 22051                0                 621            4 2023-03-12 13:31:13
# 24887                0                 191            2 2022-12-24 00:17:02
# 23387                0                9769            2 2023-03-21 23:16:00
# 12456                0               42357            7 2022-12-10 08:05:32
# 19532                0               39858           23 2023-09-15 16:36:40
# 27182               37                 467           21 2022-11-24 09:04:06
# 22828                5                2365            4 2023-07-07 18:20:01
# 1054                 0                5957            1 2023-02-12 13:45:21
# 21659                0                 745            5 2021-10-02 07:51:13
# 4348                 0               16945            2 2022-12-22 14:44:04
# 25600                0                 325           30 2022-12-28 05:40:10
# 13910               19                6019            4 2023-01-05 05:05:32
# 3284                 5                2977            2 2023-08-03 07:54:19
# 29246                0                 782           40 2022-12-05 03:12:06
# 18057              711                 225           79 2022-10-05 04:45:58
# 3856                 0                1681            2 2023-03-18 04:05:53
# 22440               17               27606            1 2023-09-28 07:58:51
# 27717                0                 157            8 2023-01-23 13:36:42
# 26855                0                 649            2 2023-01-22 22:06:12
# 23467              123                2418           11 2023-03-13 00:04:57
# 17471                0               24462            4 2023-04-06 03:24:23
# 30482               55                8735            3 2023-10-06 07:43:29
# 25663              201                4418           40 2021-07-06 15:14:30
# 15739                0               19232            4 2023-07-10 03:01:29
# 22254                0                 977            6 2023-08-17 10:11:51
# 19660              213                1424           44 2023-02-28 06:34:31
# 3912                 0                 351            4 2023-03-06 18:31:59
# 13590               24              340222            4 2022-11-12 22:57:22
# 12680                0                1582           31 2023-07-09 20:29:02
# 31271             2217                  67          859 2022-12-18 00:14:37
#
#                color
# 14077           pink
# 10565           pink
# 10559           pink
# 3387       mistyrose
# 22981      mistyrose
# 27689        thistle
# 25249      mistyrose
# 10217           pink
# 19964           pink
# 1920   palevioletred
# 27354        thistle
# 13944           pink
# 18683        thistle
# 27409        thistle
# 17441           pink
# 23584      mistyrose
# 12802           pink
# 7616       mistyrose
# 1383   palevioletred
# 13405           pink
# 12712           pink
# 27364        thistle
# 18187        thistle
# 26757        thistle
# 27619        thistle
# 23080      mistyrose
# 27312        thistle
# 18897        thistle
# 17550           pink
# 22051      mistyrose
# 24887      mistyrose
# 23387      mistyrose
# 12456           pink
# 19532           pink
# 27182        thistle
# 22828      mistyrose
# 1054   palevioletred
# 21659      mistyrose
# 4348       mistyrose
# 25600      mistyrose
# 13910           pink
# 3284       mistyrose
# 29246  palevioletred
# 18057        thistle
# 3856       mistyrose
# 22440      mistyrose
# 27717        thistle
# 26855        thistle
# 23467      mistyrose
# 17471           pink
# 30482  palevioletred
# 25663      mistyrose
# 15739           pink
# 22254      mistyrose
# 19660           pink
# 3912       mistyrose
# 13590           pink
# 12680           pink
# 31271        thistle

# %%
(df.duplicated(subset='review') == False).sum()
# Out:
# 29492

# %%
df = df[df.duplicated(subset='review') == False]

# %%
df.duplicated(subset='review').sum()
# Out:
# 0

# %% [markdown]
# #### Długość recenzji

# %%
df["temp_review_len"] = df["review"].apply(lambda x: x.split(" ").__len__())
df["temp_review_len"].describe()
# Out:
# count    29492.000000
# mean        54.191984
# std        135.354534
# min          1.000000
# 25%          5.000000
# 50%         13.000000
# 75%         39.000000
# max       3997.000000
# Name: temp_review_len, dtype: float64

# %%
df[df["temp_review_len"] == df["temp_review_len"].max()]['review'].values
# Out:
# array(['t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r o w t h e f a c t o r y m u s t g r  ...
#       dtype=object)

# %%
df[df["temp_review_len"] < 4].groupby(by=["genre"]).count()
# Out:
#        title  steamid  votes_up  review  weighted_vote_score  voted_up  \
# genre
# A       1659     1659      1659    1659                 1659      1659
# P        852      852       852     852                  852       852
# R        798      798       798     798                  798       798
# S       1140     1140      1140    1140                 1140      1140
#
#        num_games_owned  playtime_at_review  num_reviews  timestamp_created  \
# genre
# A                 1659                1659         1659               1659
# P                  852                 852          852                852
# R                  798                 798          798                798
# S                 1140                1140         1140               1140
#
#        color  temp_review_len
# genre
# A       1659             1659
# P        852              852
# R        798              798
# S       1140             1140

# %%
df = df[df["temp_review_len"] >= 3]

# %%
suma = 0
for i in df["temp_review_len"]:
    suma += i

# %%
print("Ilość słów:", suma,
     "Ilość recenzji:", len(df["temp_review_len"]))
# Out:
# Ilość słów: 1593992 Ilość recenzji: 26663

# %%
df = df.drop(["temp_review_len"], axis=1)

# %% [markdown]
# ### Wordcloud

# %%
txt = ' '.join(i for i in df["review"])
wordcloud = WordCloud(max_font_size = 180,
                max_words = 120,
                width = 1200,
                height = 800,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "A"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "R"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "P"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "S"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# #### Usunięcie znaków, text lowering

# %%
df["review"] = df["review"].str.replace(r"\[.*?\]|\n|[^\x00-\x7F]+", "", regex=True).str.lower()

# %%
df["review"].sample(10)
# Out:
# 31281                                   baba is me and you
# 18088          fun game, hard at times, but real good game
# 19552    inflation review update: i originally bought t...
# 30597         mobs so icy im just balling bruh im drowning
# 16367    its like a box of chocolates, you never know w...
# 10835    i have over fifty years of playing war games, ...
# 5674                                         piece of shit
# 9991     thumbs down to this game for several reasons. ...
# 13151    good game for spectating what your friends are...
# 30199    so only played 90 minutes but i'm already floo...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie znaków interpunkcyjnych i liczb

# %%
df["review"] = df["review"].str.replace(r"[0-9]", "", regex=True)

# %%
import string 
df["review"] = df["review"].str.replace('['  + string.punctuation + ']', "", regex =True)

# %%
df["review"].sample(5)
# Out:
# 1328     game about depression so quirky uwushut the fu...
# 12874                                 can eat people whole
# 27958    the greatest rpg of all time stolen by con art...
# 12354    thanks for the ridiculous price increase for t...
# 11195    its was good game  wonderful game and maybe it...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie tytułów gier z recenzji

# %%
for value in title_dict.values():
    df["review"] = df["review"].str.replace(value.lower(), "")

# %% [markdown]
# #### Tokenizacja

# %%
import nltk
df["tokenized"] = df["review"].apply(nltk.word_tokenize)

# %%
df["tokenized"].sample(15)
# Out:
# 4183     [verry, good, game, its, not, all, about, the,...
# 24254    [this, game, is, gudbut, i, still, wan, na, di...
# 107      [when, i, first, played, the, game, i, got, to...
# 7593                                   [i, love, violence]
# 20818                         [amazing, instantly, hooked]
# 16309    [ever, wanted, to, be, a, discord, mod, well, ...
# 10586                       [i, can, kill, my, friends, d]
# 9633     [this, is, a, great, game, as, long, as, you, ...
# 29430    [people, are, beautiful, statuesque, parodies,...
# 10088    [amazing, game, to, sink, many, hours, of, you...
# 24496    [this, game, kept, me, alive, through, the, en...
# 31988    [this, is, a, gem, of, world, building, and, a...
# 14393    [ive, been, fiddling, around, with, challengin...
# 1177     [yes, dont, second, guess, buying, this, game,...
# 7232     [its, quite, possibly, the, greatest, and, mos...
# Name: tokenized, dtype: object

# %% [markdown]
# #### Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
english_stopwords = stopwords.words('english')
english_stopwords_cleaned = [word.replace("'", "") for word in english_stopwords]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marty\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
new_column = []
for row in df["tokenized"]:
    new_row = [word for word in row if word[0] not in english_stopwords_cleaned]
    new_column.append(new_row)
df["final_review"] = new_column

# %% [markdown]
# #### Describe

# %%
df.dtypes
# Out:
# title                          object
# genre                          object
# steamid                        object
# votes_up                        int64
# review                         object
# weighted_vote_score            object
# voted_up                         bool
# num_games_owned                 int64
# playtime_at_review              int64
# num_reviews                     int64
# timestamp_created      datetime64[ns]
# color                          object
# tokenized                      object
# final_review                   object
# dtype: object

# %%
df["weighted_vote_score"] = pd.to_numeric(df["weighted_vote_score"])

# %%
df["voted_up"] = pd.to_numeric(df["voted_up"])

# %%
df.describe()
# Out:
#            votes_up  weighted_vote_score  num_games_owned  playtime_at_review  \
# count  26663.000000         26663.000000     26663.000000        2.666300e+04
# mean      31.715148             0.570098       140.866707        1.309372e+04
# std      173.097223             0.109932       538.652824        4.720263e+04
# min        0.000000             0.500000         0.000000        5.000000e+00
# 25%        1.000000             0.521739         0.000000        5.350000e+02
# 50%        1.000000             0.523810         0.000000        1.800000e+03
# 75%        3.000000             0.545180       113.000000        7.111500e+03
# max     9568.000000             0.987843     22780.000000        1.890626e+06
#
#         num_reviews
# count  26663.000000
# mean      21.467689
# std       59.809381
# min        1.000000
# 25%        3.000000
# 50%        8.000000
# 75%       20.000000
# max     3419.000000

# %%
corr = df.corr()
plt.figure(figsize=(7,5))
sns.heatmap(corr, cmap=sns.cubehelix_palette(as_cmap=True),annot=True)
plt.show()
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_16176\2159658958.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# ## Dependency parser test

# %%
test = [df["final_review"][6543], df["final_review"][4534], df["final_review"][12345], df["final_review"][12354],
        df["final_review"][1925], df["final_review"][1067],df["final_review"][22951],df["final_review"][2231],
       ["not","fun", "gameplay"], df["tokenized"][832], df["final_review"][21]]

# %%
import stanza
nlp = stanza.Pipeline('en', tokenize_pretokenized=True) 
doc = nlp(test)
# Out:
# 2024-04-12 23:59:03 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-04-12 23:59:04 INFO: Downloaded file to C:\Users\marty\stanza_resources\resources.json
# 2024-04-12 23:59:05 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-04-12 23:59:05 INFO: Using device: cuda
# 2024-04-12 23:59:05 INFO: Loading: tokenize
# 2024-04-12 23:59:05 INFO: Loading: mwt
# 2024-04-12 23:59:06 INFO: Loading: pos
# 2024-04-12 23:59:06 INFO: Loading: lemma
# 2024-04-12 23:59:06 INFO: Loading: constituency
# 2024-04-12 23:59:07 INFO: Loading: depparse
# 2024-04-12 23:59:07 INFO: Loading: sentiment
# 2024-04-12 23:59:07 INFO: Loading: ner
# 2024-04-12 23:59:08 INFO: Done loading processors!

# %%
dependency_list = []
for dependency in doc.sentences[8].dependencies:
    dependency_list.append([dependency[2].text, dependency[0].id, dependency[1]])
    
for i in range(0, len(dependency_list)):
    if (int(dependency_list[i][1]) != 0):
        dependency_list[i][1] = test[8][(int(dependency_list[i][1]) - 1)]

print(dependency_list)
# Out:
# [['not', 'gameplay', 'advmod'], ['fun', 'gameplay', 'amod'], ['gameplay', 0, 'root']]

# %%
feature_list = []
feature_opinion_list = [] 

for dependency in doc.sentences[8].dependencies:
    if dependency[2].xpos == "RB":
        opinion_word = dependency[2]
        rb_adj = dependency[0]
        
    if (dependency[2].xpos in ["NN", "NNS", "JJ", "JJS", "JJR"]) and (dependency[1] in ["amod"]):
        if dependency[0] == rb_adj or dependency[2] == rb_adj:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}     
        else:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}  

        feature_list.append(dependency[0].lemma)
        feature_opinion_list.append(result_dict)

print(f'Feature list: {feature_list}')
print(f'Feature-opinion list: {feature_opinion_list}')
# Out:
# Feature list: ['gameplay']
# Feature-opinion list: [{'feature': 'gameplay', 'opinion': 'not fun'}]

# %% [markdown]
# ## Dependency parser final

# %%
feature_list_column = []
feature_opinion_list_column = []

for review in df["final_review"][1722:1735]:
    if isinstance(review, list):
        review = " ".join(review)
        doc = nlp(review)
        feature_list = []
        feature_opinion_list = [] 
        
        if len(doc.sentences) == 0:
            continue
            
        for dependency in doc.sentences[0].dependencies:
            if dependency[2].xpos == "RB":
                opinion_word = dependency[2]
                rb_adj = dependency[0]
            if (dependency[2].xpos in ["JJ", "JJS"]) and (dependency[0].xpos in ["NN", "NNS"]) and (dependency[1] in ["amod"]):

                if dependency[0] == rb_adj or dependency[2] == rb_adj:
                    if dependency[2].xpos in ["JJS", "JJR"]:
                        result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
                    else:
                        result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}     
                else:
                    if dependency[2].xpos in ["JJS", "JJR"]:
                        result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
                    else:
                        result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}  

                feature_list.append(dependency[0].lemma)
                feature_opinion_list.append(result_dict)
        print(feature_opinion_list)
                
    feature_list_column.append(feature_list)
    feature_opinion_list_column.append(feature_opinion_list)
# Out:
# []
# [{'feature': 'undertale', 'opinion': 'earthbound'}, {'feature': 'game', 'opinion': 'great'}, {'feature': 'job', 'opinion': 'favorite'}, {'feature': 'job', 'opinion': 'great'}, {'feature': 'ending', 'opinion': 'crazy'}, {'feature': 'ending', 'opinion': 'complete'}, {'feature': 'nikki', 'opinion': 'earthbound'}, {'feature': 'part', 'opinion': 'favorite'}, {'feature': 'game', 'opinion': 'worth'}]
# []
# [{'feature': 'experience', 'opinion': 'vain'}, {'feature': 'narrative', 'opinion': 'fun'}, {'feature': 'narrative', 'opinion': 'colourful'}, {'feature': 'game', 'opinion': 'psychological'}, {'feature': 'game', 'opinion': 'bright'}, {'feature': 'game', 'opinion': 'cheery'}, {'feature': 'game', 'opinion': 'flat'}, {'feature': 'everyone', 'opinion': 'comfortable'}, {'feature': 'rpg', 'opinion': 'fairly fresh'}, {'feature': 'beating', 'opinion': 'happy'}, {'feature': 'box', 'opinion': 'very unique'}, {'feature': 'hit', 'opinion': 'good'}, {'feature': 'effect', 'opinion': 'unique'}, {'feature': 'combat', 'opinion': 'core'}, {'feature': 'bit', 'opinion': 'fresh'}, {'feature': 'person', 'opinion': 'wrong'}, {'feature': 'eye', 'opinion': 'keen'}, {'feature': 'world', 'opinion': 'even zany'}, {'feature': 'game', 'opinion': 'gamesoverall'}, {'feature': 'game', 'opinion': 'exceptional'}, {'feature': 'version', 'opinion': 'future'}]
# []
# [{'feature': 'game', 'opinion': 'good'}]
# []
# []
# []
# [{'feature': 'journey', 'opinion': 'profound'}, {'feature': 'example', 'opinion': 'really romanticizeglamorize'}, {'feature': 'effect', 'opinion': 'harmful'}, {'feature': 'friend', 'opinion': 'poignant'}, {'feature': 'friend', 'opinion': 'fragile'}, {'feature': 'rpg', 'opinion': 'competent'}, {'feature': 'piece', 'opinion': 'heavy'}, {'feature': 'engine', 'opinion': 'quaint'}, {'feature': 'believe', 'opinion': 'just enough'}, {'feature': 'job', 'opinion': 'great'}, {'feature': 'piece', 'opinion': 'good'}, {'feature': 'bond', 'opinion': 'realistic'}, {'feature': 'bond', 'opinion': 'realistic'}, {'feature': 'feeling', 'opinion': 'real'}, {'feature': 'person', 'opinion': 'hard'}, {'feature': 'way', 'opinion': 'clever'}, {'feature': 'life', 'opinion': 'real'}]
# [{'feature': 'game', 'opinion': 'very unique'}, {'feature': 'experience', 'opinion': 'best'}, {'feature': 'combat', 'opinion': 'unique'}, {'feature': 'combat', 'opinion': 'unique'}, {'feature': 'effect', 'opinion': 'emotional'}, {'feature': 'use', 'opinion': 'certain'}, {'feature': 'color', 'opinion': 'combatthe'}, {'feature': 'color', 'opinion': 'full'}, {'feature': 'play', 'opinion': 'white'}, {'feature': 'lightbulb', 'opinion': 'white'}, {'feature': 'lightbulb', 'opinion': 'black'}, {'feature': 'box', 'opinion': 'warm'}, {'feature': 'hero', 'opinion': 'few'}, {'feature': 'focus', 'opinion': 'central'}, {'feature': 'basil', 'opinion': 'best'}, {'feature': 'worldthe', 'opinion': 'very unique'}, {'feature': 'job', 'opinion': 'great'}, {'feature': 'enemy', 'opinion': 'normal'}, {'feature': 'juice', 'opinion': 'certain'}, {'feature': 'end', 'opinion': 'little'}, {'feature': 'experiment', 'opinion': 'best'}, {'feature': 'party', 'opinion': 'new'}, {'feature': 'energy', 'opinion': 'least'}, {'feature': 'party', 'opinion': 'whole'}, {'feature': 'chunk', 'opinion': 'big'}, {'feature': 'emotionsemotion', 'opinion': 'certain'}, {'feature': 'emotion', 'opinion': 'further'}, {'feature': 'emotion', 'opinion': 'happy'}, {'feature': 'beat', 'opinion': 'happy'}, {'feature': 'level', 'opinion': 'enough'}, {'feature': 'reason', 'opinion': 'regular'}, {'feature': 'emotion', 'opinion': 'present'}, {'feature': 'eye', 'opinion': 'very nice'}, {'feature': 'listen', 'opinion': 'really nice'}, {'feature': 'rpg', 'opinion': 'really unique'}, {'feature': 'rpg', 'opinion': 'unique'}, {'feature': 'experience', 'opinion': 'just worth'}, {'feature': 'review', 'opinion': 'good'}]
# []
# [{'feature': 'gameplay', 'opinion': 'beautiful'}, {'feature': 'gameplay', 'opinion': 'good'}, {'feature': 'gameplay', 'opinion': 'bad'}, {'feature': 'gameplay', 'opinion': 'long'}, {'feature': 'NASA', 'opinion': 'rich'}, {'feature': 'usage', 'opinion': 'hard'}, {'feature': 'need', 'opinion': 'necessary'}, {'feature': 'game', 'opinion': 'good'}, {'feature': 'game', 'opinion': 'lovely'}, {'feature': 'price', 'opinion': 'long worth'}, {'feature': 'game', 'opinion': 'big'}]

# %%
##"VBG", "DT"
