# %%
import pandas as pd
import spacy
import steamreviews
import json
import csv
import os
import glob
import json
import matplotlib.pyplot as plt
import nltk
import wordcloud
import re
import plotly
import seaborn as sns
import stanza
import string 
import joblib

from scipy.stats import pearsonr
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import fcluster
from wordcloud import WordCloud
from pandas.io.json import json_normalize
from nltk.corpus import stopwords
from tqdm.notebook import trange, tqdm
from sklearn.cluster import KMeans
from collections import defaultdict

# %% [markdown]
# ## Reviews download
# https://pypi.org/project/steamreviews/

# %% [raw]
# list_of_app_ids = [219150, 1172620, 460950, 262060, 250320, 210970, 620, 736260,
#                    219890, 289070, 427520, 257510, 304430, 400, 394360, 550,
#                    632470, 294100, 646570, 1150690, 1341290, 1515210, 860510]
#
# def get_reviews(list_of_app_ids):
#     request_params = dict()
#     request_params['language'] = 'english'
#     request_params['day_range'] = '365'
#     request_params['filter'] = 'all'
#     for app_id in list_of_app_ids:
#         review_dict, query_count = steamreviews.download_reviews_for_app_id(app_id,chosen_request_params=request_params)
#     return review_dict, query_count
# get_reviews(list_of_app_ids);

# %%
dir_name = "data"
reviews_jsons = glob.glob(f"{dir_name}/*")
reviews_jsons
# Out:
# ['data\\review_1150690.json',
#  'data\\review_1172620.json',
#  'data\\review_1341290.json',
#  'data\\review_1515210.json',
#  'data\\review_210970.json',
#  'data\\review_219150.json',
#  'data\\review_219890.json',
#  'data\\review_250320.json',
#  'data\\review_257510.json',
#  'data\\review_262060.json',
#  'data\\review_289070.json',
#  'data\\review_294100.json',
#  'data\\review_304430.json',
#  'data\\review_394360.json',
#  'data\\review_400.json',
#  'data\\review_427520.json',
#  'data\\review_460950.json',
#  'data\\review_550.json',
#  'data\\review_620.json',
#  'data\\review_632470.json',
#  'data\\review_646570.json',
#  'data\\review_736260.json',
#  'data\\review_860510.json']

# %%
title_dict = {"219150": "Hotline Miami",
              "1172620" : "Sea of Thieves",
              "460950" : "Katana ZERO",
              "262060" : "Darkest Dungeon",
              "250320" : "The Wolf Among Us",
              "210970" : "The Witness",
              "620" : "Portal 2",
              "736260" : "Baba Is You",
              "219890" : "Antichamber",
              "289070" : "Sid Meier's Civilization VI",
              "427520" : "Factorio",
              "257510" : "The Talos Principle",
             "304430" : "INSIDE",
             "400" : "Portal",
             "394360" : "Hearts of Iron IV",
             "632470" : "Disco Elysium",
             "294100" : "RimWorld",
              "646570" : "Slay the Spire",
              "1150690" : "Omori",
              "1341290" : "We Were Here Forever",
              "1515210" : "The Past Within",
              "860510" : "Little Nightmares II",
              "550" : "Left 4 Dead 2"}

# %%
genre_dict = {"219150": "A",
              "1172620" : "A",
              "460950" : "A",
              "262060" : "R",
              "250320" : "R",
              "210970" : "P",
              "620" : "P",
              "736260" : "P",
              "219890" : "P",
              "289070" : "S",
              "427520" : "S",
              "257510" : "P",
              "304430" : "P",
             "400" : "P",
             "394360" : "S",
             "632470" : "R",
             "294100" : "S",
             "646570" : "R",
             "1150690" : "R",
             "1341290" : "P",
             "1515210" : "P",
             "860510" : "P",
             "550" : "A"}

# %%
data_list = []
for i in reviews_jsons:
    with open(i, encoding = "utf-8") as json_file:
        json_data = json.load(json_file)
        reviews = json_data['reviews']
        file_name = json_file.name.split('.')[0].split('_')[1]
        for key in reviews.keys():
            data_list.append([title_dict.get(file_name),genre_dict.get(file_name),reviews[key]['author']['steamid'], reviews[key]['votes_up'], 
                          reviews[key]['review'], reviews[key]['weighted_vote_score'], reviews[key]['voted_up'],
                          reviews[key]['author']['num_games_owned'], reviews[key]['author']['playtime_at_review'],
                          reviews[key]['author']['num_reviews'], 
                          reviews[key]["timestamp_created"] ])
df = pd.DataFrame(data_list, columns = ["title", "genre","steamid", "votes_up", "review", "weighted_vote_score", "voted_up",
                                        "num_games_owned", "playtime_at_review", "num_reviews", "timestamp_created"])

# %%
df.sample(frac=0.3).head()
# Out:
#                title genre            steamid  votes_up  \
# 13301       RimWorld     S  76561198391625904         1
# 7636   Hotline Miami     A  76561198386185532         2
# 1453           Omori     R  76561199017407617         1
# 888            Omori     R  76561199187514816         2
# 14940         INSIDE     P  76561198070044538       614
#
#                                                   review  \
# 13301  This game is just simply one of the best colon...
# 7636     Accurate depiction of average night in Florida.
# 1453   I haven’t fully finished the game, but I would...
# 888                                    fun game :] baisl
# 14940           Stop playing outside and go play inside.
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 13301  0.523809552192687988      True                0               15548
# 7636   0.523809552192687988      True               55                 261
# 1453   0.523809552192687988      True                0                1452
# 888    0.523809552192687988      True                0                 862
# 14940  0.792268335819244385      True              198                 289
#
#        num_reviews  timestamp_created
# 13301            4         1669389556
# 7636            43         1687831241
# 1453             2         1666476655
# 888              3         1682169238
# 14940            7         1467978843

# %%
df['timestamp_created'] = pd.to_datetime(df['timestamp_created'], unit='s')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 1. Braki danych
# 2. Usunięcie duplikatów
# 4. Usunięcie recenzjii krótszych niż 3 słowa
# 9. Usunięcie znaków spcjalnych
# 10. "Text lowering"
# 6. Usunięcie znaków interpunkcyjnych i liczb
# 8. Usunięcie tytułów gier z recenzji
# 7. Tokenizacja
# 8. Part-of-speech tagging
# 9. Lematyzacja

# %% [markdown]
# #### Braki danych

# %%
df.isna().sum()
# Out:
# title                  0
# genre                  0
# steamid                0
# votes_up               0
# review                 0
# weighted_vote_score    0
# voted_up               0
# num_games_owned        0
# playtime_at_review     0
# num_reviews            0
# timestamp_created      0
# dtype: int64

# %% [markdown]
# #### Usunięcie duplikatów

# %%
df.duplicated(subset='review').sum()
# Out:
# 2580

# %%
df[df.duplicated(subset='review')].sample(20)
# Out:
#                    title genre            steamid  votes_up  \
# 22099      Left 4 Dead 2     A  76561199103795395         2
# 28600      Disco Elysium     R  76561198095572698         3
# 14281           RimWorld     S  76561198097137403         1
# 26368           Portal 2     P  76561199025795639         1
# 16810  Hearts of Iron IV     S  76561199005827155         1
# 20451           Factorio     S  76561197988634174         1
# 19458           Factorio     S  76561198072581212         2
# 20472           Factorio     S  76561198055428390         1
# 25583      Left 4 Dead 2     A  76561198920549948         1
# 24790      Left 4 Dead 2     A  76561198876913823         1
# 15552  Hearts of Iron IV     S  76561199014904431         2
# 26479           Portal 2     P  76561199195056929         1
# 18920             Portal     P  76561198027367698         1
# 21859      Left 4 Dead 2     A  76561198964545028        17
# 30228      Disco Elysium     R  76561198080296819       954
# 25399      Left 4 Dead 2     A  76561199169037271         1
# 21615        Katana ZERO     A  76561198069954191       181
# 22936      Left 4 Dead 2     A  76561198095164365         1
# 16311  Hearts of Iron IV     S  76561199221887571         1
# 31416        Baba Is You     P  76561198062247676         1
#
#                                                   review  \
# 22099                                          good game
# 28600                                       literally me
# 14281                                               good
# 26368                                                  .
# 16810                                      i hate myself
# 20451                                                yes
# 19458                              The factory must grow
# 20472                              The factory must grow
# 25583  Guys, help out, my wife said if there are 800 ...
# 24790                                          Good game
# 15552                                      i want to die
# 26479                                              potal
# 18920                                           fun game
# 21859                                          nice game
# 30228  >walking home at night\n>pass a group of youth...
# 25399                                                yes
# 21615                                        masterpiece
# 22936                                          Good game
# 16311                                                fun
# 31416                                                  S
#
#         weighted_vote_score  voted_up  num_games_owned  playtime_at_review  \
# 22099  0.545454561710357666      True                0                 258
# 28600  0.533018887042999268      True              377                 204
# 14281  0.504504501819610596      True                0                9694
# 26368  0.523809552192687988      True                0                 261
# 16810  0.519999980926513672      True                0                3634
# 20451   0.52173912525177002      True                0               10141
# 19458  0.545454561710357666      True              126                4861
# 20472   0.52173912525177002      True              201               10620
# 25583                   0.5      True               11                 529
# 24790   0.52173912525177002      True                0               58768
# 15552  0.524506211280822754      True               26               56082
# 26479  0.523809552192687988      True                6                 865
# 18920  0.518518567085266113      True              220                  80
# 21859  0.633136212825775146      True               57                 890
# 30228  0.911943614482879639      True              151                2740
# 25399  0.507042229175567627      True                0                 240
# 21615  0.905311226844787598      True              258                 543
# 22936  0.523809552192687988      True                0                2099
# 16311  0.523809552192687988      True               37                7290
# 31416   0.52173912525177002      True                0                 318
#
#        num_reviews   timestamp_created
# 22099            1 2022-12-20 20:01:08
# 28600            5 2023-07-04 06:56:32
# 14281            5 2023-04-12 08:33:08
# 26368            3 2023-06-23 14:43:11
# 16810           15 2023-05-22 20:41:24
# 20451            5 2023-09-10 12:48:43
# 19458            5 2023-05-14 01:53:03
# 20472            3 2023-06-26 19:57:02
# 25583            3 2023-03-24 20:44:40
# 24790            1 2023-03-18 05:43:33
# 15552           12 2022-11-05 04:12:44
# 26479            3 2023-05-07 22:39:53
# 18920          298 2023-02-10 04:04:30
# 21859           10 2023-05-15 10:54:12
# 30228            2 2022-03-23 00:11:41
# 25399            6 2023-03-25 20:59:49
# 21615           45 2020-06-18 10:44:01
# 22936           16 2023-06-27 08:55:09
# 16311            3 2022-12-11 19:02:33
# 31416            3 2023-05-18 17:44:10

# %%
(df.duplicated(subset='review') == False).sum()
# Out:
# 29492

# %%
df = df[df.duplicated(subset='review') == False]

# %%
df.duplicated(subset='review').sum()
# Out:
# 0

# %% [markdown]
# #### Długość recenzji

# %%
df["temp_review_len"] = df["review"].apply(lambda x: x.split(" ").__len__())
df["temp_review_len"].describe()
# Out:
# count    29492.000000
# mean        54.191984
# std        135.354534
# min          1.000000
# 25%          5.000000
# 50%         13.000000
# 75%         39.000000
# max       3997.000000
# Name: temp_review_len, dtype: float64

# %% [raw]
# df[df["temp_review_len"] == df["temp_review_len"].max()]['review'].values

# %%
df[df["temp_review_len"] < 4].groupby(by=["genre"]).count()
# Out:
#        title  steamid  votes_up  review  weighted_vote_score  voted_up  \
# genre
# A       1659     1659      1659    1659                 1659      1659
# P        852      852       852     852                  852       852
# R        798      798       798     798                  798       798
# S       1140     1140      1140    1140                 1140      1140
#
#        num_games_owned  playtime_at_review  num_reviews  timestamp_created  \
# genre
# A                 1659                1659         1659               1659
# P                  852                 852          852                852
# R                  798                 798          798                798
# S                 1140                1140         1140               1140
#
#        temp_review_len
# genre
# A                 1659
# P                  852
# R                  798
# S                 1140

# %%
df = df[df["temp_review_len"] >= 3]

# %%
suma = 0
for i in df["temp_review_len"]:
    suma += i

# %%
print("Ilość słów:", suma,
     "Ilość recenzji:", len(df["temp_review_len"]))
# Out:
# Ilość słów: 1593992 Ilość recenzji: 26663

# %%
df = df.drop(["temp_review_len"], axis=1)

# %% [markdown]
# ### Wordcloud

# %%
txt = ' '.join(i for i in df["review"])
wordcloud = WordCloud(max_font_size = 180,
                max_words = 120,
                width = 1200,
                height = 800,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "A"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "R"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "P"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
txt = ' '.join(i for i in df[df['genre'] == "S"]['review'])
wordcloud = WordCloud(max_font_size = 150,
                max_words = 30,
                width = 600,
                height = 400,
                background_color = "black",
                colormap='RdPu_r').generate(txt)

plt.figure(figsize=(12,6))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# #### Usunięcie znaków, text lowering

# %%
df["review"] = df["review"].str.replace(r"\[.*?\]|\n|[^\x00-\x7F]+", "", regex=True).str.lower()

# %%
df["review"].sample(10)
# Out:
# 21860                       too much hentai on workshop :(
# 11497    addictive, sat down, fired up the game, and be...
# 28436    what a bizarrely fun and engrossing game. i ac...
# 8425     awesome story, really liked how it all connect...
# 4696                                         is good game!
# 21274    rating: the game's story and storytelling plea...
# 24772    fun game. great to play with friends but can a...
# 4769     a game saved purely by the virtue of "its bett...
# 31786    a phenomenal game just like the first!! though...
# 6564     worth the wait, excellent game to play with yo...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie znaków interpunkcyjnych i liczb

# %%
df["review"] = df["review"].str.replace(r"[0-9]", "", regex=True)

# %%
df["review"] = df["review"].str.replace('['  + string.punctuation + ']', "", regex =True)

# %%
df["review"].sample(5)
# Out:
# 30865    very very good roguelike deckbuilder just one ...
# 29700    i played this game and i am now a depressed al...
# 16114    i gave myself brain damage getting  achievemen...
# 20971    crash land on a planetdrain all natural resour...
# 11671    underwhelming game with an unpleasant art dire...
# Name: review, dtype: object

# %% [markdown]
# #### Usunięcie tytułów gier z recenzji

# %%
for value in title_dict.values():
    df["review"] = df["review"].str.replace(value.lower(), "")

# %% [markdown]
# #### Tokenizacja

# %%
df["tokenized"] = df["review"].apply(nltk.word_tokenize)

# %%
df["tokenized"].sample(15)
# Out:
# 8148     [this, is, one, of, the, most, creative, games...
# 2728     [to, be, fair, the, fact, that, this, game, is...
# 4064     [its, a, pirate, game, expect, piracy, dont, c...
# 26668    [drois, gasayvanad, kaia, da, momentebshi, tvi...
# 6477     [they, made, progress, this, is, way, better, ...
# 10338    [stay, away, or, you, might, risk, spending, a...
# 21070    [crash, land, on, planetsteal, orekill, the, n...
# 30835    [im, too, stubborn, to, not, go, fully, into, ...
# 18802                        [i, like, going, into, holes]
# 7607     [if, the, russian, mob, invades, your, neighbo...
# 28024                     [super, secret, kim, sex, scene]
# 9948     [controversial, view, but, i, actually, like, ...
# 7132     [excellent, game, great, ambience, little, to,...
# 20538    [super, nerd, game, i, have, this, one, friend...
# 26691    [one, of, the, best, games, ever, play, with, ...
# Name: tokenized, dtype: object

# %% [markdown]
# ### Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
english_stopwords = stopwords.words('english')
english_stopwords_cleaned = [word.replace("'", "") for word in english_stopwords]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marty\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
new_column = []
for row in df["tokenized"]:
    new_row = [word for word in row if word[0] not in english_stopwords_cleaned]
    new_column.append(new_row)
df["final_review"] = new_column

# %% [markdown]
# ## Describe

# %%
df.dtypes
# Out:
# title                          object
# genre                          object
# steamid                        object
# votes_up                        int64
# review                         object
# weighted_vote_score            object
# voted_up                         bool
# num_games_owned                 int64
# playtime_at_review              int64
# num_reviews                     int64
# timestamp_created      datetime64[ns]
# tokenized                      object
# final_review                   object
# dtype: object

# %%
df["weighted_vote_score"] = pd.to_numeric(df["weighted_vote_score"])

# %%
df["voted_up"] = pd.to_numeric(df["voted_up"])

# %%
df.describe()
# Out:
#            votes_up  weighted_vote_score  num_games_owned  playtime_at_review  \
# count  26663.000000         26663.000000     26663.000000        2.666300e+04
# mean      31.715148             0.570098       140.866707        1.309372e+04
# std      173.097223             0.109932       538.652824        4.720263e+04
# min        0.000000             0.500000         0.000000        5.000000e+00
# 25%        1.000000             0.521739         0.000000        5.350000e+02
# 50%        1.000000             0.523810         0.000000        1.800000e+03
# 75%        3.000000             0.545180       113.000000        7.111500e+03
# max     9568.000000             0.987843     22780.000000        1.890626e+06
#
#         num_reviews
# count  26663.000000
# mean      21.467689
# std       59.809381
# min        1.000000
# 25%        3.000000
# 50%        8.000000
# 75%       20.000000
# max     3419.000000

# %%
corr = df.corr(method = "pearson")
plt.figure(figsize=(7,5))
sns.heatmap(corr, cmap=sns.cubehelix_palette(as_cmap=True),annot=True)
plt.show()
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_2228\2852639080.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method = "pearson")

# %% [markdown]
# ## Wykresy

# %%
value_counts_title = df["title"].value_counts()
genre_colors = {"A": sns.cubehelix_palette(4)[1], "R": sns.cubehelix_palette(4)[2], "P": sns.cubehelix_palette(4)[3], 
                "S": sns.cubehelix_palette(4)[0]}
df['color'] = df['genre'].map(genre_colors)
colors = [df.loc[df['title'] == title]['color'].iloc[0] for title in value_counts_title.index]

plt.figure(figsize=(12, 6))
x = value_counts_title.plot(kind = "bar", color = colors)
plt.ylabel("Ilość recenzji")
plt.xticks(rotation = 90)
for i, count in enumerate(value_counts_title):
    x.text(i, count, count, va = "bottom", ha = "center")

handles = [plt.Rectangle((0,0), 1,1, color=genre_colors[label]) for label in genre_colors]
plt.legend(handles, genre_colors.keys(), title="Gatunek", loc="upper right")


plt.show()
df = df.drop(["color"], axis=1)

# %%
value_counts_genre = df["genre"].value_counts()
colors = sns.cubehelix_palette(4)
x = plt.pie(value_counts_genre, labels = value_counts_genre.index, colors=colors, autopct='%1.2f%%')
plt.show()

# %%
value_counts_recommendation_genre = df.groupby('genre').voted_up.value_counts().unstack(0)
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 

total_count = percentage_pos + percentage_neg

def addlabels_neg(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] + 2, f"{x[i]:.2f}%",  ha = "center")

def addlabels_pos(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] - 6, f"{y[i]:.2f}%",  ha = "center")

fig, ax1 = plt.subplots(figsize=(7, 4))
ax2 = ax1.twinx()

total_count.plot(kind="bar", color="#95DBE5FF",  label="Recommended")
percentage_neg.plot(kind="bar", color="#078282FF", label="Not Recommended")

ax1.set_xlabel("Gatunki")
ax1.tick_params(axis="y", left=False, labelleft=False)
ax2.tick_params(axis="y", right=False, labelright=False)

addlabels_neg(percentage_neg, total_count) 
addlabels_pos(total_count, percentage_pos) 

plt.legend(bbox_to_anchor=(0.85, 1.15), ncol=2)
plt.show()

# %%
import numpy as np

value_counts_recommendation_genre = df.groupby('genre').voted_up.value_counts().unstack(0)
percentage_pos = value_counts_recommendation_genre.iloc[1] / (value_counts_recommendation_genre.iloc[1] + value_counts_recommendation_genre.iloc[0]) * 100 
percentage_neg = value_counts_recommendation_genre.iloc[0] / (value_counts_recommendation_genre.iloc[0] + value_counts_recommendation_genre.iloc[1]) * 100 

total_count = percentage_pos + percentage_neg

def addlabels_neg(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] + 2, f"{x[i]:.2f}%",  ha = "center")

def addlabels_pos(x,y):
    for i in range(len(y)):
        plt.text(i, x[i] - 6, f"{y[i]:.2f}%",  ha = "center")

fig, axs = plt.subplots(1, 2, figsize=(12, 4))

total_count.plot(kind="bar", color="#ffdaf6",  label="Recommended")
percentage_neg.plot(kind="bar", color="#b34a98", label="Not Recommended")

axs[1].set_xlabel("Gatunki")
addlabels_neg(percentage_neg, total_count) 
addlabels_pos(total_count, percentage_pos) 
axs[1].legend(loc=(1.04, 0))

value_counts_genre = df["genre"].value_counts()
colors = sns.cubehelix_palette(6)

axs[0].pie(value_counts_genre, labels = value_counts_genre.index,colors=colors, autopct='%1.1f%%', startangle=140)
plt.show()

# %% [markdown]
# ## Dependency parser test

# %%
test = [df["final_review"][6543], df["final_review"][4534], df["final_review"][12345], df["final_review"][12354],
        df["final_review"][1925], df["final_review"][1067],df["final_review"][22951],df["final_review"][2231],
       ["not","fun", "gameplay"], df["tokenized"][832], df["final_review"][21], df["tokenized"][27061],
       df["final_review"][11088], df["final_review"][3171], df["final_review"][7834], df["final_review"][20180],
       df["final_review"][6697], df["final_review"][893]]

# %%
import stanza
nlp = stanza.Pipeline('en', tokenize_pretokenized=True) 
doc = nlp(test)
# Out:
# 2024-08-27 00:47:47 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-08-27 00:47:48 INFO: Downloaded file to C:\Users\marty\stanza_resources\resources.json
# 2024-08-27 00:47:50 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-08-27 00:47:50 INFO: Using device: cuda
# 2024-08-27 00:47:50 INFO: Loading: tokenize
# 2024-08-27 00:47:50 INFO: Loading: mwt
# 2024-08-27 00:47:56 INFO: Loading: pos
# 2024-08-27 00:47:56 INFO: Loading: lemma
# 2024-08-27 00:47:56 INFO: Loading: constituency
# 2024-08-27 00:47:57 INFO: Loading: depparse
# 2024-08-27 00:47:57 INFO: Loading: sentiment
# 2024-08-27 00:47:58 INFO: Loading: ner
# 2024-08-27 00:47:58 INFO: Done loading processors!

# %%
dependency_list = []
for dependency in doc.sentences[13].dependencies:
    dependency_list.append([dependency[2].text, dependency[0].id, dependency[1]])
    
for i in range(0, len(dependency_list)):
    if (int(dependency_list[i][1]) != 0):
        dependency_list[i][1] = test[13][(int(dependency_list[i][1]) - 1)]

print(*dependency_list[:10], sep='\n')
# Out:
# ['crewing', 0, 'root']
# ['game', 'value', 'compound']
# ['value', 'crewing', 'obj']
# ['likely', 'crewing', 'advmod']
# ['worthless', 'crewing', 'xcomp']
# ['real', 'crewing', 'xcomp']
# ['but', 'play', 'cc']
# ['can', 'play', 'aux']
# ['play', 'crewing', 'conj']
# ['player', 'play', 'obj']

# %%
feature_list = []
feature_opinion_list = [] 

for dependency in doc.sentences[13].dependencies:
    if dependency[2].xpos == "RB":
        opinion_word = dependency[2]
        rb_adj = dependency[0]
        
    if (dependency[2].xpos in ["NN", "NNS","JJ", "JJS", "JJR"]) and (dependency[1] in ["amod"]):
        if dependency[0] == rb_adj or dependency[2] == rb_adj:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}     
        else:
            if dependency[2].xpos in ["JJS", "JJR"]:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
            else:
                result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}  

        feature_list.append(dependency[0].lemma)
        feature_opinion_list.append(result_dict)

print(f'Feature list: {feature_list}')
print(f'Feature-opinion list: {feature_opinion_list}')
# Out:
# Feature list: ['graphic', 'beauty', 'player', 'player', 'player', 'guide', 'reward', 'reward', 'reward']
# Feature-opinion list: [{'feature': 'graphic', 'opinion': 'fun'}, {'feature': 'beauty', 'opinion': 'real'}, {'feature': 'player', 'opinion': 'unbalanced'}, {'feature': 'player', 'opinion': 'janky'}, {'feature': 'player', 'opinion': 'human'}, {'feature': 'guide', 'opinion': 'necessary'}, {'feature': 'reward', 'opinion': 'risky'}, {'feature': 'reward', 'opinion': 'lowest'}, {'feature': 'reward', 'opinion': 'highest'}]

# %% [markdown]
# ## Dependency parser final

# %% [raw]
# feature_list_column = []
# feature_opinion_list_column = []
#
# for review in tqdm(df["final_review"]):
#     if isinstance(review, list):
#         review = " ".join(review)
#         doc = nlp(review)
#         feature_list = []
#         feature_opinion_list = []
#
#         if len(doc.sentences) == 0:
#             continue
#
#         for dependency in doc.sentences[0].dependencies:
#             if dependency[2].xpos == "RB":
#                 opinion_word = dependency[2]
#                 rb_adj = dependency[0]
#             if (dependency[2].xpos in ["JJ", "JJS"]) and (dependency[0].xpos in ["NN", "NNS"]) and (dependency[1] in ["amod"]):
#
#                 if dependency[0] == rb_adj or dependency[2] == rb_adj:
#                     if dependency[2].xpos in ["JJS", "JJR"]:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].text}
#                     else:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': opinion_word.text + " " + dependency[2].lemma}
#                 else:
#                     if dependency[2].xpos in ["JJS", "JJR"]:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].text}
#                     else:
#                         result_dict = {'feature': dependency[0].lemma, 'opinion': dependency[2].lemma}
#
#                 feature_list.append(dependency[0].lemma)
#                 feature_opinion_list.append(result_dict)
#
#     feature_list_column.append(feature_list)
#     feature_opinion_list_column.append([review, feature_opinion_list])
#
# df["feature"] = [feature_list_column]
# df["feature_opinion_list"] = [feature_opinion_list_column]

# %% [raw]
# new_df = pd.DataFrame([feature_list_column, feature_opinion_list_column])
# new_df.T
#
# non_empty_indexes = df[df["final_review"].apply(lambda x: len(x)!=0)].index
#
# import json
# opinions_dict = {k:v for k, v in zip(non_empty_indexes, feature_opinion_list_column)}
# out_file = open("opinions.json", "w")
#
# json.dump(opinions_dict, out_file, indent = 6)
#
# out_file.close()

# %%
with open('opinions.json', 'r') as file:
    dct = json.load(file)

# %%
feature_list = []

for i in range(len(df)):
    index = str(i)  
    feature = dct.get(index)
    if feature is None:
        feature_list.append([])
    else:
        feature_list.append(feature)

df["feature"] = feature_list

# %%
words = []
for i in df["feature"]:
    for j in i:
        words.append(j["feature"])

# %%
unique_words = list(set(words))

# %%
word_counts = pd.DataFrame([[i, len([q for q in words if q==i])] for i in unique_words], 
              columns=['word', 'count']).sort_values('count', ascending=False)

# %% [markdown]
# ## Dendrogram

# %%
popular_words = word_counts[word_counts['count']>= 15]["word"].to_list()
nlp = spacy.load('en_core_web_md')
tokens = [nlp(word) for word in popular_words]
word_vectors = pd.DataFrame([i.vector for i in tokens])

# %%
Z = linkage(word_vectors.values, method='ward')

plt.figure(figsize=(10,6))
dendrogram(Z, p = 5, truncate_mode = "level", orientation='top', labels = popular_words, leaf_font_size = 8)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Words')
plt.ylabel('Distance')
plt.show()

# %%
cluster_labels = fcluster(Z, t = 75,  criterion="distance")

clusters = {}
for word, label in zip(popular_words, cluster_labels):
    if label not in clusters:
        clusters[label] = [word]
    else:
        clusters[label].append(word)

for label, words in clusters.items():
    print(f"Cluster {label}: {', '.join(words)}")
# Out:
# Cluster 68: game, play, player, playing
# Cluster 57: puzzle, pirate, horror, zomby, zombie, pawn, wolf, franchise, coop, nightmare, gamei, pve, limbo, fable, glado, clue, eargasm, hacker, cannibal, chill
# Cluster 21: experience, community, work, environment, resource, workshop, focus, knowledge, research, project, practice, learning
# Cluster 75: gameplay, gamer, gaming, rng, bonus, replay, cue
# Cluster 99: way, pace
# Cluster 97: hour, week, night
# Cluster 12: price, cost
# Cluster 47: person, friend, boss, child, woman, family, partner
# Cluster 48: love, choice, voice, wish, reward, hope, enjoyment, pleasure, praise
# Cluster 62: character, hero, genre, plot, figure, episode, cutscene, lore, chapter, legend, protagonist, narrator, backstory
# Cluster 1: world, city, country, nation
# Cluster 54: fun
# Cluster 19: level, point, number, class, rating
# Cluster 72: review, note, view, guide
# Cluster 76: graphic, visual, video, pixel
# Cluster 18: content, quality, value, product
# Cluster 52: lot
# Cluster 4: part, event, place
# Cluster 50: life
# Cluster 25: challenge, problem, effect, reason, possibility, question, change, chance, balance, future, potential, purpose, factor
# Cluster 58: grind, luck, guess, hell, fuck, joke, cry, ruin, biter
# Cluster 53: bit
# Cluster 8: colony, quest, colonist, empire, journey, voyage, fortress
# Cluster 92: room, wall, floor
# Cluster 77: update, feature, version, release, entry, upgrade, launcher, patch
# Cluster 9: end
# Cluster 49: nothing, everything, feeling, everyone, emotion, kind, being, fear
# Cluster 63: bug, glitch
# Cluster 16: factory, base, unit, platformer, location, production, company, plant, equipment, network, facility, platform
# Cluster 78: NASA
# Cluster 64: civ, pvp, rpg
# Cluster 7: enemy, fight, battle, combat, campaign, effort, victory
# Cluster 51: guy, kid, boy, girl
# Cluster 85: line, curve, loop, button, edge, length, belt, hook
# Cluster 20: element, playthrough, ending, civilization, requirement, replayability, example, progress, form, complaint, conclusion, exploration, progression, period, customization, connection, combination, conversation, expansion, process, confession, relationship, beginning, portion, communication, recommendation, complexity, frustration, condition, cycle, presentation, comment, warning, experiment, component, execution
# Cluster 39: need, help, want
# Cluster 29: run
# Cluster 43: job
# Cluster 22: concept, history, narrative, writing, personality, nature, philosophy, language, reality, perspective, vision, behavior
# Cluster 15: building, builder, build
# Cluster 101: lake, water, boat
# Cluster 11: war
# Cluster 37: cant, havent
# Cluster 86: piece, pack, cake, layer, package
# Cluster 30: look, feel
# Cluster 69: fan
# Cluster 102: crew, crash, ride
# Cluster 5: control, force, power
# Cluster 3: leader, party, group, faction
# Cluster 35: use
# Cluster 26: fact, case, crime, error, flaw
# Cluster 89: hand, chamber, face, front, head, corner, chest, lobby, back
# Cluster 60: word, name
# Cluster 95: weapon, loot, gun, bomb
# Cluster 23: robot, usage, encounter, course, planet, landscape, computer, universe, cheater, cosmetic, background, creature, physics, library, formula
# Cluster 90: couple, half, winter, plenty
# Cluster 42: eye
# Cluster 28: wait, break, pass, finish, call, leave, kill, pick, beat
# Cluster 6: rule, plan, policy
# Cluster 61: book, novel
# Cluster 34: buy
# Cluster 40: heart, brain, blood, body, bone
# Cluster 24: worth, waste, purchase, payment, buying, credit
# Cluster 59: god
# Cluster 84: valve, engine
# Cluster 94: raid, raider
# Cluster 87: color, paint, light
# Cluster 45: care, health
# Cluster 100: goal
# Cluster 56: humor, classic, vibe, gem, quirk, hint, charm
# Cluster 17: variety, range
# Cluster 71: list, page
# Cluster 98: path, route, road
# Cluster 79: fps
# Cluster 46: food
# Cluster 55: joy
# Cluster 93: box
# Cluster 38: can, will
# Cluster 96: fire
# Cluster 80: leg
# Cluster 33: find, fix
# Cluster 10: era
# Cluster 65: pc
# Cluster 36: go
# Cluster 82: egg
# Cluster 83: cup
# Cluster 31: grow
# Cluster 70: hit
# Cluster 14: risk
# Cluster 27: lack
# Cluster 91: wave
# Cluster 103: race
# Cluster 66: ld
# Cluster 88: gold
# Cluster 81: hat
# Cluster 41: pain
# Cluster 32: fit
# Cluster 67: ui
# Cluster 13: rate
# Cluster 73: log
# Cluster 74: key
# Cluster 44: role
# Cluster 2: land

# %% [raw]
# clusters = {}
# for word, label in zip(popular_words, cluster_labels):
#     if label not in clusters:
#         clusters[label] = [word]
#     else:
#         clusters[label].append(word)
#
# with open('clusters.csv', 'w') as file:
#     file.write('Cluster,Words\n')
#     for label, words in clusters.items():
#         file.write(f"{label},{' '.join(words)}\n")
#         print(f"Cluster {label}: {', '.join(words)}")
#
# print("Clusters saved to clusters.csv")

# %%
def words_to_list(words_string):
    return words_string.split()

clusters_df = pd.read_csv('clusters.csv', converters={'Words': words_to_list})
clusters_df
# Out:
#      Cluster                                              Words
# 0         68                      [game, play, player, playing]
# 1         57  [puzzle, pirate, horror, zomby, pawn, zombie, ...
# 2         21  [experience, community, work, environment, res...
# 3         75  [gameplay, gamer, gaming, rng, bonus, replay, ...
# 4         99                                        [way, pace]
# ..       ...                                                ...
# 98        13                                             [rate]
# 99        74                                              [key]
# 100       44                                             [role]
# 101        2                                             [land]
# 102       73                                              [log]
#
# [103 rows x 2 columns]

# %%
clusters = {7: 'Combat',
    95: 'Combat',
    11: "Combat",
    75: 'Gameplay',
    19: 'Game Mechanics',
    99: 'Game Mechanics',
    25: 'Challenges',
    76: 'Visuals',
    87: 'Visuals',
    67: 'Visuals',
    56: 'Humor',
    62: 'Narrative and Story',
    22: 'Narrative and Story',
    63: 'Bugs and Glitches',
    77: 'Updates and Patches',
    21: 'Community and Collaboration',
    12: 'Cost',
    24: 'Cost',
    18: 'Content Quality',
    8: 'Quests and Adventures',
    16: 'Production and Development',
    72: 'User Feedback',
    48: 'Enjoyment and Reward'}

# %%
categories = clusters_df.groupby(clusters_df['Cluster'].map(clusters)).agg({'Words': 'sum'}).reset_index()
categories
# Out:
#                         Cluster  \
# 0             Bugs and Glitches
# 1                    Challenges
# 2                        Combat
# 3   Community and Collaboration
# 4               Content Quality
# 5                          Cost
# 6          Enjoyment and Reward
# 7                Game Mechanics
# 8                      Gameplay
# 9                         Humor
# 10          Narrative and Story
# 11   Production and Development
# 12        Quests and Adventures
# 13          Updates and Patches
# 14                User Feedback
# 15                      Visuals
#
#                                                 Words
# 0                                       [bug, glitch]
# 1   [challenge, problem, effect, reason, possibili...
# 2   [enemy, fight, battle, combat, campaign, effor...
# 3   [experience, community, work, environment, res...
# 4                  [content, quality, value, product]
# 5   [price, cost, worth, waste, purchase, payment,...
# 6   [love, choice, voice, wish, reward, hope, enjo...
# 7    [way, pace, level, point, number, class, rating]
# 8   [gameplay, gamer, gaming, rng, bonus, replay, ...
# 9     [humor, classic, vibe, gem, hint, quirk, charm]
# 10  [character, hero, genre, plot, figure, episode...
# 11  [factory, base, unit, platformer, location, pr...
# 12  [colony, quest, colonist, empire, journey, voy...
# 13  [update, feature, version, release, entry, upg...
# 14                        [review, note, view, guide]
# 15  [graphic, visual, video, pixel, color, paint, ...

# %%
categories["Words"][15]
# Out:
# ['graphic', 'visual', 'video', 'pixel', 'color', 'paint', 'light', 'ui']

# %% [markdown]
# ## Similarity

# %%
words = word_counts["word"].to_list()
nlp = spacy.load('en_core_web_md')
tokens = [nlp(word) for word in words]

# %%
categories['WordTokens'] = categories['Words'].apply(lambda words: [nlp(word) for word in words])
all_cluster_words = set(word for words in categories['Words'] for word in words)

for token in tokens:
    max_similarity = 0
    best_cluster = None
    
    for idx, row in categories.iterrows():
        for word_token in row['WordTokens']:
            similarity = token.similarity(word_token)
            if similarity > max_similarity:
                max_similarity = similarity
                best_cluster = idx
    
    if max_similarity > 0.75 and str(token) not in all_cluster_words:
        categories.at[best_cluster, 'Words'].append(str(token))
        all_cluster_words.add(token)

categories.drop(columns=['WordTokens'], inplace=True)
print(categories)
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_2228\1993302271.py:10: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = token.similarity(word_token)
#                         Cluster  \
# 0             Bugs and Glitches
# 1                    Challenges
# 2                        Combat
# 3   Community and Collaboration
# 4               Content Quality
# 5                          Cost
# 6          Enjoyment and Reward
# 7                Game Mechanics
# 8                      Gameplay
# 9                         Humor
# 10          Narrative and Story
# 11   Production and Development
# 12        Quests and Adventures
# 13          Updates and Patches
# 14                User Feedback
# 15                      Visuals
#
#                                                 Words
# 0                                       [bug, glitch]
# 1   [challenge, problem, effect, reason, possibili...
# 2   [enemy, fight, battle, combat, campaign, effor...
# 3   [experience, community, work, environment, res...
# 4           [content, quality, value, product, qualm]
# 5   [price, cost, worth, waste, purchase, payment,...
# 6   [love, choice, voice, wish, reward, hope, enjo...
# 7   [way, pace, level, point, number, class, ratin...
# 8   [gameplay, gamer, gaming, rng, bonus, replay, ...
# 9   [humor, classic, vibe, gem, hint, quirk, charm...
# 10  [character, hero, genre, plot, figure, episode...
# 11  [factory, base, unit, platformer, location, pr...
# 12  [colony, quest, colonist, empire, journey, voy...
# 13  [update, feature, version, release, entry, upg...
# 14   [review, note, view, guide, reviewer, viewpoint]
# 15  [graphic, visual, video, pixel, color, paint, ...

# %%
categories["Words"][15]
# Out:
# ['graphic',
#  'visual',
#  'video',
#  'pixel',
#  'color',
#  'paint',
#  'light',
#  'ui',
#  'colour',
#  'videogame',
#  'blight',
#  'lightbulb',
#  'gui',
#  'paintjob',
#  'colourblind',
#  'colorblind',
#  'lighting',
#  'colorblindness']

# %% [markdown]
# # Feature-opinion-category list

# %%
for i in df["feature"]:
    for j in i:
        for index, row in categories.iterrows():
            if j["feature"] in row["Words"]:
                j["category"] = row["Cluster"]

# %% [markdown]
# # Sentiment

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\marty\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
for i in df["feature"]:
    for j in i:
        expr = j["opinion"] #+ " " + j["feature"] 
        scores = analyzer.polarity_scores(expr)
        j["sentiment"] = scores["compound"]

# %% [markdown]
# ### Sentiment for each feature category for different genres

# %%
category_genre_sentiment_count = {}

for genre, features in zip(df["genre"], df["feature"]):

    if genre not in category_genre_sentiment_count:
        category_genre_sentiment_count[genre] = defaultdict(lambda: {"positive": 0, "negative": 0, "neutral": 0})
    
    for feature in features:
        if "category" in feature and "sentiment" in feature:
            category = feature["category"]
            sentiment = feature["sentiment"]
            
            if category not in category_genre_sentiment_count[genre]:
                category_genre_sentiment_count[genre][category] = {"positive": 0, "negative": 0, "neutral": 0}
            
            if sentiment > 0:
                category_genre_sentiment_count[genre][category]["positive"] += 1
            elif sentiment < 0:
                category_genre_sentiment_count[genre][category]["negative"] += 1
            else:
                category_genre_sentiment_count[genre][category]["neutral"] += 1
                
    for category in category_genre_sentiment_count[genre]:
        total = sum(category_genre_sentiment_count[genre][category].values())
        for sentiment in category_genre_sentiment_count[genre][category]:
            category_genre_sentiment_count[genre][category][sentiment] = \
                (category_genre_sentiment_count[genre][category][sentiment] / total) * 100
    
    category_genre_sentiment_count[genre] = dict(category_genre_sentiment_count[genre])

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle("Sentiment % by Category", fontsize=20)

def plot_genre_sentiments(ax, genre, title):
    categories = list(category_genre_sentiment_count[genre].keys())
    positive = np.array([category_genre_sentiment_count[genre][cat]["positive"] for cat in categories])
    negative = np.array([category_genre_sentiment_count[genre][cat]["negative"] for cat in categories])
    neutral = np.array([category_genre_sentiment_count[genre][cat]["neutral"] for cat in categories])

    ax.bar(categories, positive, color="g", label="Positive")
    ax.bar(categories, neutral, bottom=positive, color="b", label="Neutral")
    ax.bar(categories, negative, bottom=neutral + positive, color="r", label="Negative")
    ax.tick_params(axis="x", rotation=90)
    ax.set_title(title)
    
plot_genre_sentiments(axs[0, 0], "R", "RPG")
plot_genre_sentiments(axs[0, 1], "A", "Action")
plot_genre_sentiments(axs[1, 0], "P", "Puzzle")
plot_genre_sentiments(axs[1, 1], "S", "Strategy")


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature category significance analysis for different genres

# %%
genre_category = {}
for genre, features in zip(df["genre"], df["feature"]):
    if genre not in genre_category:
        genre_category[genre] = []
    for feature in features:
        if "category" in feature:
            genre_category[genre].append(feature["category"])

# %%
genre_category_counts = {genre: pd.Series(categories).value_counts() for genre, categories in genre_category.items()}

# %%
genre_category_counts = pd.DataFrame(genre_category_counts)

# %%
import matplotlib as mpl

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle("Feature Counts by Genre", fontsize=20)

values = genre_category_counts["R"].sort_values(ascending=False)[1:].keys()
cmap = mpl.colormaps["turbo"]
colors = cmap(np.linspace(0, 1, len(values)))
value_color_dict = dict(zip(values, colors))

categories_R = list(genre_category_counts["R"].sort_values(ascending=False)[1:].keys())
counts_R = list(genre_category_counts["R"].sort_values(ascending=False)[1:])
axs[0, 0].bar(categories_R, counts_R, color= [value_color_dict[category] for category in categories_R])
axs[0, 0].set_title("RPG")
axs[0, 0].set_ylabel("Count")
axs[0, 0].tick_params(axis="x", rotation=90)

categories_A = list(genre_category_counts["A"].sort_values(ascending=False)[1:].keys())
counts_A = list(genre_category_counts["A"].sort_values(ascending=False)[1:])
axs[0, 1].bar(categories_A, counts_A, color=[value_color_dict[category] for category in categories_A])
axs[0, 1].set_title("Action")
axs[0, 1].set_ylabel("Count")
axs[0, 1].tick_params(axis="x", rotation=90)

categories_P = list(genre_category_counts["P"].sort_values(ascending=False)[1:].keys())
counts_P = list(genre_category_counts["P"].sort_values(ascending=False)[1:])
axs[1, 0].bar(categories_P, counts_P, color=[value_color_dict[category] for category in categories_P])
axs[1, 0].set_title("Puzzle")
axs[1, 0].set_ylabel("Count")
axs[1, 0].tick_params(axis="x", rotation=90)

categories_S = list(genre_category_counts["S"].sort_values(ascending=False)[1:].keys())
counts_S = list(genre_category_counts["S"].sort_values(ascending=False)[1:])
axs[1, 1].bar(categories_S, counts_S, color= [value_color_dict[category] for category in categories_S])
axs[1, 1].set_title("Strategy")
axs[1, 1].set_ylabel("Count")
axs[1, 1].tick_params(axis="x", rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sentiment towards each aspect in aspect category

# %% [markdown]
# #### Feature: opinion, sentiment, catergory

# %%
sentiment_aspect = {}
for genre, features in zip(df["genre"], df["feature"]):
    if genre not in sentiment_aspect:
        sentiment_aspect[genre] = {}
    
    for feature in features:
        if "category" in feature and "sentiment" in feature and "feature" in feature:
            category = feature["category"]
            sentiment = feature["sentiment"]
            feature = feature["feature"]
            if category not in sentiment_aspect[genre]:
                sentiment_aspect[genre][category] = {}
            if feature not in sentiment_aspect[genre][category]:
                sentiment_aspect[genre][category][feature] = []
            sentiment_aspect[genre][category][feature].append(sentiment)

# %% [markdown]
# #### Mean, median, standard deviation, variance, minimum, maximum

# %%
data = []

for i,j in sentiment_aspect.items():
    for k, l in j.items():
        for m, n in l.items():
            data.append([i, k, m, len(n), np.mean(n), np.median(n), np.var(n), np.std(n), np.min(n), np.max(n)])

sentiment_aspect_df = pd.DataFrame(data, columns=["Genre", "Category", "Feature", "Count", "Mean", "Median", "Variance", "StdDev", "Min", "Max"])

sentiment_aspect_df
# Out:
#     Genre         Category   Feature  Count      Mean  Median  Variance  \
# 0       R         Gameplay      game   1914  0.289913  0.4404  0.102521
# 1       R         Gameplay  gameplay    147  0.170112  0.0000  0.139995
# 2       R         Gameplay       cue     12  0.029650  0.0000  0.062390
# 3       R         Gameplay     gamer      6  0.000000  0.0000  0.000000
# 4       R         Gameplay    replay      2  0.449600  0.4496  0.000085
# ..    ...              ...       ...    ...       ...     ...       ...
# 715     S  Content Quality   content     91  0.123224  0.0000  0.073775
# 716     S  Content Quality   quality     19 -0.010247  0.0000  0.032233
# 717     S  Content Quality     value     17  0.225265  0.2263  0.056113
# 718     S  Content Quality     qualm      3  0.146800  0.0000  0.043100
# 719     S  Content Quality   product      7  0.184414  0.0000  0.054711
#
#        StdDev     Min     Max
# 0    0.320188 -0.6597  0.8020
# 1    0.374159 -0.5423  0.7269
# 2    0.249780 -0.5423  0.6249
# 3    0.000000  0.0000  0.0000
# 4    0.009200  0.4404  0.4588
# ..        ...     ...     ...
# 715  0.271615 -0.5423  0.6249
# 716  0.179534 -0.2732  0.6249
# 717  0.236883  0.0000  0.6369
# 718  0.207607  0.0000  0.4404
# 719  0.233903  0.0000  0.5719
#
# [720 rows x 10 columns]

# %% [markdown]
# #### Frequency

# %% [raw]
# count_description = sentiment_aspect_df["Count"].describe()
# print(count_description)

# %% [raw]
# sentiment_aspect_df["Count"].quantile(0.7)

# %% [raw]
# sentiment_aspect_df["Log"] = sentiment_aspect_df["Count"].apply(lambda x: np.log(x+1))
#
# plt.figure(figsize=(12, 6))
# plt.hist(sentiment_aspect_df["Log"], bins=50, edgecolor="black", alpha=1)
# plt.title("Log Feature Counts")
# plt.xlabel("Log Count")
# plt.ylabel("Features Count")
# plt.show()

# %% [raw]
# log_thresh = sentiment_aspect_df["Log Count"].quantile([0,0.25, 0.5, 0.75, 0.90, 0.95, 0.99])
# print(log_thresh)

# %% [raw]
# sentiment_aspect_df[sentiment_aspect_df["Log Count"] > 2]

# %% [markdown]
# #### Most popular words in each category in genre

# %%
sentiment_aspect_df_sort= sentiment_aspect_df.sort_values(by="Count", ascending=False)
top_10_common = sentiment_aspect_df_sort.groupby("Genre", group_keys=False).apply(lambda x: x.head(10))
top_10_common
# Out:
#     Genre                     Category     Feature  Count      Mean   Median  \
# 164     A                     Gameplay        game   2669  0.265004  0.44040
# 172     A  Community and Collaboration  experience    273  0.171037  0.00000
# 166     A                     Gameplay    gameplay    209  0.147220  0.00000
# 276     A                         Cost       price    207  0.189603  0.22630
# 218     A               Game Mechanics         way    192  0.209522  0.00000
# 296     A   Production and Development     factory    128  0.085475  0.00000
# 331     A            Bugs and Glitches         bug     87 -0.051800  0.00000
# 219     A               Game Mechanics       level     84  0.124308  0.00000
# 262     A                User Feedback      review     82  0.082230  0.00000
# 322     A                      Visuals     graphic     82  0.296185  0.44040
# 333     P                     Gameplay        game   1799  0.266264  0.44040
# 335     P                     Gameplay    gameplay    197  0.154856  0.00000
# 344     P  Community and Collaboration  experience    186  0.157509  0.00000
# 383     P               Game Mechanics         way    156  0.203601  0.00000
# 427     P                         Cost       price     96  0.232865  0.22630
# 442     P          Narrative and Story   character     66  0.235673  0.00000
# 472     P              Content Quality     content     52  0.078917  0.00000
# 382     P               Game Mechanics       level     47  0.133855  0.00000
# 362     P                User Feedback      review     42 -0.036195  0.00000
# 476     P          Updates and Patches      update     41  0.091122  0.00000
# 0       R                     Gameplay        game   1914  0.289913  0.44040
# 84      R         Enjoyment and Reward        love    341 -0.226078  0.00000
# 111     R  Community and Collaboration  experience    172  0.229687  0.07655
# 1       R                     Gameplay    gameplay    147  0.170112  0.00000
# 48      R          Narrative and Story   character    143  0.248673  0.15310
# 37      R               Game Mechanics         way    131  0.220562  0.31820
# 92      R                         Cost       price     65  0.235823  0.22630
# 39      R               Game Mechanics       level     46  0.064272  0.00000
# 24      R                   Challenges   challenge     38  0.164971  0.00000
# 101     R                      Visuals     graphic     38  0.286621  0.44040
# 512     S                     Gameplay        game   3026  0.227712  0.15310
# 568     S               Game Mechanics         way    260  0.138947  0.00000
# 648     S  Community and Collaboration  experience    236  0.206847  0.00000
# 513     S                     Gameplay    gameplay    231  0.139409  0.00000
# 636     S                         Cost       price    179  0.162679  0.00000
# 597     S          Narrative and Story   character    171  0.168781  0.00000
# 712     S        Quests and Adventures      colony    146  0.132835  0.00000
# 566     S               Game Mechanics       level    117  0.032750  0.00000
# 682     S                User Feedback      review    109 -0.024739  0.00000
# 584     S                      Visuals     graphic     99  0.194473  0.00000
#
#      Variance    StdDev     Min     Max
# 164  0.106782  0.326775 -0.6249  0.8074
# 172  0.105222  0.324379 -0.6249  0.7845
# 166  0.156314  0.395366 -0.5423  0.6369
# 276  0.073508  0.271124 -0.5719  0.6369
# 218  0.095509  0.309046 -0.5849  0.7579
# 296  0.058899  0.242690 -0.6597  0.6705
# 331  0.115684  0.340123 -0.5719  0.7579
# 219  0.062707  0.250414 -0.4847  0.6369
# 262  0.165174  0.406416 -0.5719  0.5574
# 322  0.093014  0.304982 -0.5423  0.6369
# 333  0.107460  0.327811 -0.6249  0.8176
# 335  0.146124  0.382262 -0.6249  0.7579
# 344  0.094499  0.307406 -0.6249  0.8020
# 383  0.097896  0.312883 -0.6249  0.6369
# 427  0.045283  0.212799 -0.3612  0.6249
# 442  0.085104  0.291725 -0.4767  0.7351
# 472  0.073140  0.270444 -0.5574  0.6369
# 382  0.076919  0.277343 -0.4404  0.7269
# 362  0.185768  0.431008 -0.6249  0.6369
# 476  0.057738  0.240288 -0.5719  0.6249
# 0    0.102521  0.320188 -0.6597  0.8020
# 84   0.098181  0.313338 -0.5719  0.6369
# 111  0.097035  0.311505 -0.5423  0.7579
# 1    0.139995  0.374159 -0.5423  0.7269
# 48   0.087592  0.295959 -0.6597  0.7269
# 37   0.121371  0.348384 -0.6597  0.6369
# 92   0.055647  0.235895 -0.5256  0.6249
# 39   0.061578  0.248149 -0.5423  0.7269
# 24   0.071079  0.266606 -0.3400  0.6249
# 101  0.148919  0.385900 -0.6249  0.7351
# 512  0.111386  0.333745 -0.7579  0.8074
# 568  0.107815  0.328353 -0.6597  0.7717
# 648  0.097331  0.311980 -0.5849  0.8074
# 513  0.154856  0.393518 -0.5719  0.6369
# 636  0.059338  0.243595 -0.6249  0.6249
# 597  0.092406  0.303983 -0.6597  0.6369
# 712  0.102646  0.320385 -0.6597  0.6369
# 566  0.050640  0.225033 -0.5719  0.6249
# 682  0.176491  0.420109 -0.5719  0.7096
# 584  0.097492  0.312238 -0.5423  0.7269

# %% [markdown]
# #### higher variance vs sentiment

# %%
plt.scatter(sentiment_aspect_df["Mean"], sentiment_aspect_df["Variance"], alpha = 0.7)
plt.title("Sentiment mean vs. Variance")
plt.xlabel("Sentiment mean")
plt.ylabel("Variance")
plt.show()

# %%
corr_mean_variance = sentiment_aspect_df[["Mean", "Variance"]].corr().iloc[0, 1]
corr_mean_variance
# Out:
# 0.18323278636721493
